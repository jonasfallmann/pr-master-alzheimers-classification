# %% [markdown]
# ### MR files are nested in directories, make the structure flat

# %%
import glob

# Get all the MR files
mr_input_files = glob.glob('data_input/**/*.nii', recursive=True)

# %%
## are there any directories with multiple files?
from collections import defaultdict
import os

dir_files = defaultdict(list)
for file in mr_input_files:
    dir_files[os.path.dirname(file)].append(file)

for k, v in dir_files.items():
    if len(v) > 1:
        print(k, v)

print("Done")
# Out:
# Done

# %%
# create a bids dataset in data/mri
# folder structure should be data/mri/adni_thesis/sub-<subject_id>/ses-<session_id>

if not os.path.exists('data/mri/adni_thesis'):
    os.makedirs('data/mri/adni_thesis')

for file in mr_input_files:
    file_splits = file.split('/')

    adni_index = file_splits.index('ADNI')

    subject_id = file_splits[adni_index + 1].replace("_", "").replace(".", "").replace("-", "")
    session_id =  file_splits[adni_index + 3].replace("_", "").replace(".", "").replace("-", "")

    folder = f'data/mri/adni_thesis/sub-{subject_id}/ses-{session_id}/anat'
    if not os.path.exists(folder):
        os.makedirs(folder)

    new_file = f'{folder}/sub-{subject_id}_ses-{session_id}_T1w.nii'
    os.rename(file, new_file)

# %% [markdown]
# ### Filter subjects where MR is available but no genome or vice vers

# %%
import re
mr_files = glob.glob('data/mri/*.nii')
genome_files = glob.glob('data/snps/*.vcf')

# mr subject name is between "ADNI_" and "_MR"
mr_split_regex = r'ADNI_(.*)_MR'
mr_subjects = [re.search(mr_split_regex, os.path.basename(file)).group(1) for file in mr_files]

# genome subject name is before "_SNPs"
genome_split_regex = r'(.*)_SNPs'
genome_subjects = [re.search(genome_split_regex, os.path.basename(file)).group(1) for file in genome_files]

mr_subjects = set(mr_subjects)
genome_subjects = set(genome_subjects)

# subjects with both MR and genome
both = mr_subjects.intersection(genome_subjects)

# %%
both
# Out:
# set()

# %%
# Run preprocessing pipeline
! smriprep-docker ./data/mri/adni_thesis ./data_processed/mri participant --fs-license-file ./license.txt --ncpus 4 --fs-no-reconall
# Out:
# RUNNING: docker run --rm -e DOCKER_VERSION_8395080871=27.0.2 -it -v /home/jfallmann/userdata/Master/Thesis/master-thesis-alzheimers/license.txt:/opt/freesurfer/license.txt:ro -v /home/jfallmann/userdata/Master/Thesis/master-thesis-alzheimers/data/mri/adni_thesis:/data:ro -v /home/jfallmann/userdata/Master/Thesis/master-thesis-alzheimers/data_processed/mri:/out nipreps/smriprep:0.16.1 /data /out participant --ncpus 4 --fs-no-reconall
# 241125-21:59:29,285 nipype.workflow Level 25:
#
#     Running sMRIPrep version 0.16.1:
#       * BIDS dataset path: /data.
#       * Participant list: ['002S0413', '002S0729', '002S1261'].
#       * Run identifier: 20241125-215929_416487fe-dd81-412b-a327-56b104b388c7.
#
#     Spatial References: <none>.
#
# 241125-21:59:30,110 nipype.workflow INFO:
# 	 ANAT Stage 1: Adding template workflow
# 241125-21:59:30,247 nipype.workflow INFO:
# 	 ANAT Stage 2: Preparing brain extraction workflow
# 241125-21:59:30,515 nipype.workflow INFO:
# 	 ANAT Stage 3: Preparing segmentation workflow
# 241125-21:59:30,518 nipype.workflow INFO:
# 	 ANAT Skipping Stages 5+
# 241125-21:59:30,571 nipype.workflow INFO:
# 	 ANAT Stage 1: Adding template workflow
# 241125-21:59:30,574 nipype.workflow INFO:
# 	 ANAT Stage 2: Preparing brain extraction workflow
# 241125-21:59:30,900 nipype.workflow INFO:
# 	 ANAT Stage 3: Preparing segmentation workflow
# 241125-21:59:30,903 nipype.workflow INFO:
# 	 ANAT Skipping Stages 5+
# 241125-21:59:30,965 nipype.workflow INFO:
# 	 ANAT Stage 1: Adding template workflow
# 241125-21:59:30,967 nipype.workflow INFO:
# 	 ANAT Stage 2: Preparing brain extraction workflow
# 241125-21:59:31,171 nipype.workflow INFO:
# 	 ANAT Stage 2: Skipping skull-strip, INU-correction only
# 241125-21:59:31,183 nipype.workflow INFO:
# 	 ANAT Stage 3: Preparing segmentation workflow
# 241125-21:59:31,186 nipype.workflow INFO:
# 	 ANAT Skipping Stages 5+
# 241125-21:59:34,710 nipype.workflow Level 25:
# 	 Works derived from this sMRIPrep execution should include the following boilerplate:
#
#
# Results included in this manuscript come from preprocessing
# performed using *sMRIPprep* 0.16.1
# (@fmriprep1; @fmriprep2; RRID:SCR_016216),
# which is based on *Nipype* 1.8.6
# (@nipype1; @nipype2; RRID:SCR_002502).
#
#
# Anatomical data preprocessing
#
# : A total of 1 T1-weighted (T1w) images were found within the input
# BIDS dataset. The T1w image was corrected for intensity
# non-uniformity (INU) with `N4BiasFieldCorrection` [@n4], distributed with ANTs 2.5.3
# [@ants, RRID:SCR_004757], and used as T1w-reference throughout the workflow.
# The T1w-reference was then skull-stripped with a *Nipype* implementation of
# the `antsBrainExtraction.sh` workflow (from ANTs), using OASIS30ANTs
# as target template.
# Brain tissue segmentation of cerebrospinal fluid (CSF),
# white-matter (WM) and gray-matter (GM) was performed on
# the brain-extracted T1w using `fast` [FSL (version unknown), RRID:SCR_002823, @fsl_fast].
#
#
# For more details of the pipeline, see [the section corresponding
# to workflows in *sMRIPrep*'s documentation](https://smriprep.readthedocs.io/en/latest/workflows.html "sMRIPrep's documentation").
#
#
# ### References
#
#
# Results included in this manuscript come from preprocessing
# performed using *sMRIPprep* 0.16.1
# (@fmriprep1; @fmriprep2; RRID:SCR_016216),
# which is based on *Nipype* 1.8.6
# (@nipype1; @nipype2; RRID:SCR_002502).
#
#
# Anatomical data preprocessing
#
# : A total of 1 T1-weighted (T1w) images were found within the input
# BIDS dataset. The T1w image was corrected for intensity
# non-uniformity (INU) with `N4BiasFieldCorrection` [@n4], distributed with ANTs 2.5.3
# [@ants, RRID:SCR_004757], and used as T1w-reference throughout the workflow.
# The provided T1w image was previously skull-stripped; a brain mask was
# derived from the input image.
# Brain tissue segmentation of cerebrospinal fluid (CSF),
# white-matter (WM) and gray-matter (GM) was performed on
# the brain-extracted T1w using `fast` [FSL (version unknown), RRID:SCR_002823, @fsl_fast].
#
#
# For more details of the pipeline, see [the section corresponding
# to workflows in *sMRIPrep*'s documentation](https://smriprep.readthedocs.io/en/latest/workflows.html "sMRIPrep's documentation").
#
#
# ### References
#
#
# 241125-21:59:37,569 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0413_wf.anat_preproc_wf.anat_fit_wf.anat2std_buffer" in "/tmp/work/smriprep_wf/single_subject_002S0413_wf/anat_preproc_wf/anat_fit_wf/anat2std_buffer".
# 241125-21:59:37,569 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0413_wf.anat_preproc_wf.anat_fit_wf.std2anat_buffer" in "/tmp/work/smriprep_wf/single_subject_002S0413_wf/anat_preproc_wf/anat_fit_wf/std2anat_buffer".
# 241125-21:59:37,570 nipype.workflow INFO:
# 	 [Node] Executing "anat2std_buffer" <nipype.interfaces.utility.base.Merge>
# 241125-21:59:37,571 nipype.workflow INFO:
# 	 [Node] Executing "std2anat_buffer" <nipype.interfaces.utility.base.Merge>
# 241125-21:59:37,572 nipype.workflow INFO:
# 	 [Node] Finished "anat2std_buffer", elapsed time 0.000115s.
# 241125-21:59:37,572 nipype.workflow INFO:
# 	 [Node] Finished "std2anat_buffer", elapsed time 0.00011s.
# 241125-21:59:37,574 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0413_wf.anat_preproc_wf.anat_fit_wf.template_buffer" in "/tmp/work/smriprep_wf/single_subject_002S0413_wf/anat_preproc_wf/anat_fit_wf/template_buffer".
# 241125-21:59:37,575 nipype.workflow INFO:
# 	 [Node] Executing "template_buffer" <nipype.interfaces.utility.base.Merge>
# 241125-21:59:37,575 nipype.workflow INFO:
# 	 [Node] Finished "template_buffer", elapsed time 8.6e-05s.
# 241125-21:59:39,127 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0413_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.full_wm" in "/tmp/work/smriprep_wf/single_subject_002S0413_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/full_wm".
# 241125-21:59:39,128 nipype.workflow INFO:
# 	 [Node] Executing "full_wm" <nipype.interfaces.utility.wrappers.Function>
# 241125-21:59:39,164 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0413_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.lap_tmpl" in "/tmp/work/smriprep_wf/single_subject_002S0413_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/lap_tmpl".
# 241125-21:59:39,166 nipype.workflow INFO:
# 	 [Node] Executing "lap_tmpl" <nipype.interfaces.ants.utils.ImageMath>
# 241125-21:59:39,227 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0413_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.res_tmpl" in "/tmp/work/smriprep_wf/single_subject_002S0413_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/res_tmpl".
# 241125-21:59:39,228 nipype.workflow INFO:
# 	 [Node] Executing "res_tmpl" <niworkflows.interfaces.nibabel.RegridToZooms>
# 241125-21:59:39,496 nipype.workflow INFO:
# 	 [Node] Finished "full_wm", elapsed time 0.36769s.
# 241125-21:59:40,144 nipype.workflow INFO:
# 	 [Node] Finished "res_tmpl", elapsed time 0.915299s.
# 241125-21:59:40,259 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0413_wf.bidssrc" in "/tmp/work/smriprep_wf/single_subject_002S0413_wf/bidssrc".
# 241125-21:59:40,260 nipype.workflow INFO:
# 	 [Node] Executing "bidssrc" <niworkflows.interfaces.bids.BIDSDataGrabber>
# 241125-21:59:40,262 nipype.interface INFO:
# 	 No "bold" images found for sub-<undefined>
# 241125-21:59:40,262 nipype.interface INFO:
# 	 No "t2w" images found for sub-<undefined>
# 241125-21:59:40,262 nipype.interface INFO:
# 	 No "flair" images found for sub-<undefined>
# 241125-21:59:40,262 nipype.interface INFO:
# 	 No "fmap" images found for sub-<undefined>
# 241125-21:59:40,262 nipype.interface INFO:
# 	 No "sbref" images found for sub-<undefined>
# 241125-21:59:40,262 nipype.interface INFO:
# 	 No "roi" images found for sub-<undefined>
# 241125-21:59:40,263 nipype.interface INFO:
# 	 No "pet" images found for sub-<undefined>
# 241125-21:59:40,263 nipype.interface INFO:
# 	 No "asl" images found for sub-<undefined>
# 241125-21:59:40,263 nipype.workflow INFO:
# 	 [Node] Finished "bidssrc", elapsed time 0.000669s.
# 241125-21:59:41,217 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0729_wf.anat_preproc_wf.anat_fit_wf.anat2std_buffer" in "/tmp/work/smriprep_wf/single_subject_002S0729_wf/anat_preproc_wf/anat_fit_wf/anat2std_buffer".
# 241125-21:59:41,217 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0729_wf.anat_preproc_wf.anat_fit_wf.std2anat_buffer" in "/tmp/work/smriprep_wf/single_subject_002S0729_wf/anat_preproc_wf/anat_fit_wf/std2anat_buffer".
# 241125-21:59:41,218 nipype.workflow INFO:
# 	 [Node] Executing "anat2std_buffer" <nipype.interfaces.utility.base.Merge>
# 241125-21:59:41,218 nipype.workflow INFO:
# 	 [Node] Executing "std2anat_buffer" <nipype.interfaces.utility.base.Merge>
# 241125-21:59:41,218 nipype.workflow INFO:
# 	 [Node] Finished "anat2std_buffer", elapsed time 0.000115s.
# 241125-21:59:41,219 nipype.workflow INFO:
# 	 [Node] Finished "std2anat_buffer", elapsed time 0.000143s.
# 241125-21:59:43,128 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0729_wf.anat_preproc_wf.anat_fit_wf.template_buffer" in "/tmp/work/smriprep_wf/single_subject_002S0729_wf/anat_preproc_wf/anat_fit_wf/template_buffer".
# 241125-21:59:43,130 nipype.workflow INFO:
# 	 [Node] Executing "template_buffer" <nipype.interfaces.utility.base.Merge>
# 241125-21:59:43,130 nipype.workflow INFO:
# 	 [Node] Finished "template_buffer", elapsed time 0.000112s.
# 241125-21:59:43,131 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0729_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.res_tmpl" in "/tmp/work/smriprep_wf/single_subject_002S0729_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/res_tmpl".
# 241125-21:59:43,132 nipype.workflow INFO:
# 	 [Node] Executing "res_tmpl" <niworkflows.interfaces.nibabel.RegridToZooms>
# 241125-21:59:43,889 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0729_wf.bidssrc" in "/tmp/work/smriprep_wf/single_subject_002S0729_wf/bidssrc".
# 241125-21:59:43,890 nipype.workflow INFO:
# 	 [Node] Executing "bidssrc" <niworkflows.interfaces.bids.BIDSDataGrabber>
# 241125-21:59:43,890 nipype.interface INFO:
# 	 No "bold" images found for sub-<undefined>
# 241125-21:59:43,890 nipype.interface INFO:
# 	 No "t2w" images found for sub-<undefined>
# 241125-21:59:43,890 nipype.interface INFO:
# 	 No "flair" images found for sub-<undefined>
# 241125-21:59:43,890 nipype.interface INFO:
# 	 No "fmap" images found for sub-<undefined>
# 241125-21:59:43,890 nipype.interface INFO:
# 	 No "sbref" images found for sub-<undefined>
# 241125-21:59:43,890 nipype.interface INFO:
# 	 No "roi" images found for sub-<undefined>
# 241125-21:59:43,890 nipype.interface INFO:
# 	 No "pet" images found for sub-<undefined>
# 241125-21:59:43,890 nipype.interface INFO:
# 	 No "asl" images found for sub-<undefined>
# 241125-21:59:43,891 nipype.workflow INFO:
# 	 [Node] Finished "bidssrc", elapsed time 0.000399s.
# 241125-21:59:44,45 nipype.workflow INFO:
# 	 [Node] Finished "res_tmpl", elapsed time 0.911926s.
# 241125-21:59:45,128 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0729_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.full_wm" in "/tmp/work/smriprep_wf/single_subject_002S0729_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/full_wm".
# 241125-21:59:45,128 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S1261_wf.bidssrc" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/bidssrc".
# 241125-21:59:45,130 nipype.workflow INFO:
# 	 [Node] Executing "full_wm" <nipype.interfaces.utility.wrappers.Function>
# 241125-21:59:45,130 nipype.workflow INFO:
# 	 [Node] Executing "bidssrc" <niworkflows.interfaces.bids.BIDSDataGrabber>
# 241125-21:59:45,130 nipype.interface INFO:
# 	 No "bold" images found for sub-<undefined>
# 241125-21:59:45,130 nipype.interface INFO:
# 	 No "t2w" images found for sub-<undefined>
# 241125-21:59:45,130 nipype.interface INFO:
# 	 No "flair" images found for sub-<undefined>
# 241125-21:59:45,130 nipype.interface INFO:
# 	 No "fmap" images found for sub-<undefined>
# 241125-21:59:45,130 nipype.interface INFO:
# 	 No "sbref" images found for sub-<undefined>
# 241125-21:59:45,130 nipype.interface INFO:
# 	 No "roi" images found for sub-<undefined>
# 241125-21:59:45,130 nipype.interface INFO:
# 	 No "pet" images found for sub-<undefined>
# 241125-21:59:45,130 nipype.interface INFO:
# 	 No "asl" images found for sub-<undefined>
# 241125-21:59:45,130 nipype.workflow INFO:
# 	 [Node] Finished "bidssrc", elapsed time 0.000353s.
# 241125-21:59:45,142 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0729_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.lap_tmpl" in "/tmp/work/smriprep_wf/single_subject_002S0729_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/lap_tmpl".
# 241125-21:59:45,143 nipype.workflow INFO:
# 	 [Node] Executing "lap_tmpl" <nipype.interfaces.ants.utils.ImageMath>
# 241125-21:59:45,483 nipype.workflow INFO:
# 	 [Node] Finished "full_wm", elapsed time 0.352716s.
# 241125-21:59:45,977 nipype.workflow INFO:
# 	 [Node] Finished "lap_tmpl", elapsed time 6.705705s.
# 241125-21:59:47,210 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S1261_wf.anat_preproc_wf.anat_fit_wf.anat2std_buffer" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/anat2std_buffer".
# 241125-21:59:47,210 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S1261_wf.anat_preproc_wf.anat_fit_wf.std2anat_buffer" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/std2anat_buffer".
# 241125-21:59:47,211 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S1261_wf.anat_preproc_wf.anat_fit_wf.template_buffer" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/template_buffer".
# 241125-21:59:47,211 nipype.workflow INFO:
# 	 [Node] Executing "anat2std_buffer" <nipype.interfaces.utility.base.Merge>
# 241125-21:59:47,211 nipype.workflow INFO:
# 	 [Node] Executing "std2anat_buffer" <nipype.interfaces.utility.base.Merge>
# 241125-21:59:47,212 nipype.workflow INFO:
# 	 [Node] Finished "anat2std_buffer", elapsed time 0.000102s.
# 241125-21:59:47,212 nipype.workflow INFO:
# 	 [Node] Finished "std2anat_buffer", elapsed time 9.6e-05s.
# 241125-21:59:47,212 nipype.workflow INFO:
# 	 [Node] Executing "template_buffer" <nipype.interfaces.utility.base.Merge>
# 241125-21:59:47,212 nipype.workflow INFO:
# 	 [Node] Finished "template_buffer", elapsed time 0.000118s.
# 241125-21:59:49,212 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0413_wf.anat_preproc_wf.anat_fit_wf.anat_template_wf.anat_ref_dimensions" in "/tmp/work/smriprep_wf/single_subject_002S0413_wf/anat_preproc_wf/anat_fit_wf/anat_template_wf/anat_ref_dimensions".
# 241125-21:59:49,214 nipype.workflow INFO:
# 	 [Node] Executing "anat_ref_dimensions" <niworkflows.interfaces.images.TemplateDimensions>
# 241125-21:59:49,218 nipype.workflow INFO:
# 	 [Node] Finished "anat_ref_dimensions", elapsed time 0.002709s.
# 241125-21:59:49,292 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0413_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.mrg_tmpl" in "/tmp/work/smriprep_wf/single_subject_002S0413_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/mrg_tmpl".
# 241125-21:59:49,325 nipype.workflow INFO:
# 	 [Node] Executing "mrg_tmpl" <nipype.interfaces.utility.base.Merge>
# 241125-21:59:49,326 nipype.workflow INFO:
# 	 [Node] Finished "mrg_tmpl", elapsed time 0.000175s.
# 241125-21:59:49,435 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0729_wf.anat_preproc_wf.anat_fit_wf.anat_template_wf.anat_ref_dimensions" in "/tmp/work/smriprep_wf/single_subject_002S0729_wf/anat_preproc_wf/anat_fit_wf/anat_template_wf/anat_ref_dimensions".
# 241125-21:59:51,295 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S1261_wf.anat_preproc_wf.anat_fit_wf.anat_template_wf.anat_ref_dimensions" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/anat_template_wf/anat_ref_dimensions".
# 241125-21:59:51,298 nipype.workflow INFO:
# 	 [Node] Executing "anat_ref_dimensions" <niworkflows.interfaces.images.TemplateDimensions>
# 241125-21:59:51,300 nipype.workflow INFO:
# 	 [Node] Finished "anat_ref_dimensions", elapsed time 0.002324s.
# 241125-21:59:51,462 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0413_wf.anat_preproc_wf.anat_fit_wf.ds_t1w_mask_wf.raw_sources" in "/tmp/work/smriprep_wf/single_subject_002S0413_wf/anat_preproc_wf/anat_fit_wf/ds_t1w_mask_wf/raw_sources".
# 241125-21:59:51,466 nipype.workflow INFO:
# 	 [Node] Executing "raw_sources" <nipype.interfaces.utility.wrappers.Function>
# 241125-21:59:51,467 nipype.workflow INFO:
# 	 [Node] Finished "raw_sources", elapsed time 0.000276s.
# 241125-21:59:52,36 nipype.workflow INFO:
# 	 [Node] Executing "anat_ref_dimensions" <niworkflows.interfaces.images.TemplateDimensions>
# 241125-21:59:52,39 nipype.workflow INFO:
# 	 [Node] Finished "anat_ref_dimensions", elapsed time 0.002013s.
# 241125-21:59:52,64 nipype.workflow INFO:
# 	 [Node] Finished "lap_tmpl", elapsed time 6.7224129999999995s.
# 241125-21:59:53,130 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0729_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.mrg_tmpl" in "/tmp/work/smriprep_wf/single_subject_002S0729_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/mrg_tmpl".
# 241125-21:59:53,133 nipype.workflow INFO:
# 	 [Node] Setting-up "_denoise0" in "/tmp/work/smriprep_wf/single_subject_002S0413_wf/anat_preproc_wf/anat_fit_wf/anat_template_wf/denoise/mapflow/_denoise0".
# 241125-21:59:53,134 nipype.workflow INFO:
# 	 [Node] Executing "_denoise0" <nipype.interfaces.ants.segmentation.DenoiseImage>
# 241125-21:59:53,146 nipype.workflow INFO:
# 	 [Node] Executing "mrg_tmpl" <nipype.interfaces.utility.base.Merge>
# 241125-21:59:53,146 nipype.workflow INFO:
# 	 [Node] Finished "mrg_tmpl", elapsed time 0.000103s.
# 241125-21:59:55,286 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0729_wf.anat_preproc_wf.anat_fit_wf.ds_t1w_mask_wf.raw_sources" in "/tmp/work/smriprep_wf/single_subject_002S0729_wf/anat_preproc_wf/anat_fit_wf/ds_t1w_mask_wf/raw_sources".
# 241125-21:59:55,288 nipype.workflow INFO:
# 	 [Node] Executing "raw_sources" <nipype.interfaces.utility.wrappers.Function>
# 241125-21:59:55,288 nipype.workflow INFO:
# 	 [Node] Finished "raw_sources", elapsed time 0.000278s.
# 241125-21:59:57,299 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S1261_wf.anat_preproc_wf.anat_fit_wf.ds_t1w_mask_wf.raw_sources" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/ds_t1w_mask_wf/raw_sources".
# 241125-21:59:57,303 nipype.workflow INFO:
# 	 [Node] Executing "raw_sources" <nipype.interfaces.utility.wrappers.Function>
# 241125-21:59:57,303 nipype.workflow INFO:
# 	 [Node] Finished "raw_sources", elapsed time 0.00025s.
# 241125-22:00:23,105 nipype.workflow INFO:
# 	 [Node] Finished "_denoise0", elapsed time 29.875033s.
# 241125-22:00:25,132 nipype.workflow INFO:
# 	 [Node] Setting-up "_denoise0" in "/tmp/work/smriprep_wf/single_subject_002S0729_wf/anat_preproc_wf/anat_fit_wf/anat_template_wf/denoise/mapflow/_denoise0".
# 241125-22:00:25,132 nipype.workflow INFO:
# 	 [Node] Setting-up "_anat_conform0" in "/tmp/work/smriprep_wf/single_subject_002S0413_wf/anat_preproc_wf/anat_fit_wf/anat_template_wf/anat_conform/mapflow/_anat_conform0".
# 241125-22:00:25,133 nipype.workflow INFO:
# 	 [Node] Executing "_denoise0" <nipype.interfaces.ants.segmentation.DenoiseImage>
# 241125-22:00:25,133 nipype.workflow INFO:
# 	 [Node] Executing "_anat_conform0" <niworkflows.interfaces.images.Conform>
# 241125-22:00:25,135 nipype.workflow INFO:
# 	 [Node] Finished "_anat_conform0", elapsed time 0.001423s.
# 241125-22:00:27,143 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0413_wf.anat_preproc_wf.anat_fit_wf.anat_template_wf.get1st" in "/tmp/work/smriprep_wf/single_subject_002S0413_wf/anat_preproc_wf/anat_fit_wf/anat_template_wf/get1st".
# 241125-22:00:27,145 nipype.workflow INFO:
# 	 [Node] Executing "get1st" <nipype.interfaces.utility.base.Select>
# 241125-22:00:27,145 nipype.workflow INFO:
# 	 [Node] Finished "get1st", elapsed time 0.000174s.
# 241125-22:00:31,133 nipype.workflow INFO:
# 	 [Node] Setting-up "_truncate_images0" in "/tmp/work/smriprep_wf/single_subject_002S0413_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/truncate_images/mapflow/_truncate_images0".
# 241125-22:00:31,135 nipype.workflow INFO:
# 	 [Node] Executing "_truncate_images0" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:00:31,783 nipype.workflow INFO:
# 	 [Node] Finished "_truncate_images0", elapsed time 0.647954s.
# 241125-22:00:57,479 nipype.workflow INFO:
# 	 [Node] Finished "_denoise0", elapsed time 32.163169s.
# 241125-22:00:59,137 nipype.workflow INFO:
# 	 [Node] Setting-up "_denoise0" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/anat_template_wf/denoise/mapflow/_denoise0".
# 241125-22:00:59,138 nipype.workflow INFO:
# 	 [Node] Executing "_denoise0" <nipype.interfaces.ants.segmentation.DenoiseImage>
# 241125-22:00:59,139 nipype.workflow INFO:
# 	 [Node] Setting-up "_anat_conform0" in "/tmp/work/smriprep_wf/single_subject_002S0729_wf/anat_preproc_wf/anat_fit_wf/anat_template_wf/anat_conform/mapflow/_anat_conform0".
# 241125-22:00:59,140 nipype.workflow INFO:
# 	 [Node] Executing "_anat_conform0" <niworkflows.interfaces.images.Conform>
# 241125-22:00:59,144 nipype.workflow INFO:
# 	 [Node] Finished "_anat_conform0", elapsed time 0.002941s.
# 241125-22:01:01,133 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0729_wf.anat_preproc_wf.anat_fit_wf.anat_template_wf.get1st" in "/tmp/work/smriprep_wf/single_subject_002S0729_wf/anat_preproc_wf/anat_fit_wf/anat_template_wf/get1st".
# 241125-22:01:01,134 nipype.workflow INFO:
# 	 [Node] Executing "get1st" <nipype.interfaces.utility.base.Select>
# 241125-22:01:01,135 nipype.workflow INFO:
# 	 [Node] Finished "get1st", elapsed time 0.00015s.
# 241125-22:01:01,871 nipype.workflow INFO:
# 	 [Node] Finished "_denoise0", elapsed time 2.732745s.
# 241125-22:01:03,135 nipype.workflow INFO:
# 	 [Node] Setting-up "_anat_conform0" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/anat_template_wf/anat_conform/mapflow/_anat_conform0".
# 241125-22:01:03,137 nipype.workflow INFO:
# 	 [Node] Executing "_anat_conform0" <niworkflows.interfaces.images.Conform>
# 241125-22:01:03,139 nipype.workflow INFO:
# 	 [Node] Finished "_anat_conform0", elapsed time 0.001905s.
# 241125-22:01:03,221 nipype.workflow INFO:
# 	 [Node] Setting-up "_inu_n40" in "/tmp/work/smriprep_wf/single_subject_002S0413_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/inu_n4/mapflow/_inu_n40".
# 241125-22:01:03,223 nipype.workflow INFO:
# 	 [Node] Executing "_inu_n40" <nipype.interfaces.ants.segmentation.N4BiasFieldCorrection>
# 241125-22:01:05,133 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S1261_wf.anat_preproc_wf.anat_fit_wf.anat_template_wf.get1st" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/anat_template_wf/get1st".
# 241125-22:01:05,134 nipype.workflow INFO:
# 	 [Node] Executing "get1st" <nipype.interfaces.utility.base.Select>
# 241125-22:01:05,135 nipype.workflow INFO:
# 	 [Node] Finished "get1st", elapsed time 0.000141s.
# 241125-22:01:07,225 nipype.workflow INFO:
# 	 [Node] Setting-up "_truncate_images0" in "/tmp/work/smriprep_wf/single_subject_002S0729_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/truncate_images/mapflow/_truncate_images0".
# 241125-22:01:07,226 nipype.workflow INFO:
# 	 [Node] Executing "_truncate_images0" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:01:07,987 nipype.workflow INFO:
# 	 [Node] Finished "_truncate_images0", elapsed time 0.760714s.
# 241125-22:01:09,138 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S1261_wf.anat_preproc_wf.anat_fit_wf.n4_only_wf.binarize" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/n4_only_wf/binarize".
# 241125-22:01:09,143 nipype.workflow INFO:
# 	 [Node] Executing "binarize" <niworkflows.interfaces.nibabel.Binarize>
# 241125-22:01:09,316 nipype.workflow INFO:
# 	 [Node] Finished "binarize", elapsed time 0.172856s.
# 241125-22:01:11,135 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S1261_wf.anat_preproc_wf.anat_fit_wf.n4_only_wf.atropos_wf.dil_brainmask" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/n4_only_wf/atropos_wf/dil_brainmask".
# 241125-22:01:11,137 nipype.workflow INFO:
# 	 [Node] Executing "dil_brainmask" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:01:11,760 nipype.workflow INFO:
# 	 [Node] Finished "dil_brainmask", elapsed time 0.622319s.
# 241125-22:01:13,133 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S1261_wf.anat_preproc_wf.anat_fit_wf.n4_only_wf.atropos_wf.03_pad_mask" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/n4_only_wf/atropos_wf/03_pad_mask".
# 241125-22:01:13,137 nipype.workflow INFO:
# 	 [Node] Executing "03_pad_mask" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:01:13,431 nipype.workflow INFO:
# 	 [Node] Finished "03_pad_mask", elapsed time 0.293605s.
# 241125-22:01:15,497 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S1261_wf.anat_preproc_wf.anat_fit_wf.n4_only_wf.atropos_wf.get_brainmask" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/n4_only_wf/atropos_wf/get_brainmask".
# 241125-22:01:15,499 nipype.workflow INFO:
# 	 [Node] Executing "get_brainmask" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:01:16,156 nipype.workflow INFO:
# 	 [Node] Finished "get_brainmask", elapsed time 0.657296s.
# 241125-22:01:42,742 nipype.workflow INFO:
# 	 [Node] Finished "_inu_n40", elapsed time 39.518374s.
# 241125-22:01:43,138 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0413_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.res_target" in "/tmp/work/smriprep_wf/single_subject_002S0413_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/res_target".
# 241125-22:01:43,140 nipype.workflow INFO:
# 	 [Node] Executing "res_target" <niworkflows.interfaces.nibabel.RegridToZooms>
# 241125-22:01:43,142 nipype.workflow INFO:
# 	 [Node] Setting-up "_inu_n4_final0" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/n4_only_wf/inu_n4_final/mapflow/_inu_n4_final0".
# 241125-22:01:43,144 nipype.workflow INFO:
# 	 [Node] Executing "_inu_n4_final0" <nipype.interfaces.ants.segmentation.N4BiasFieldCorrection>
# 241125-22:01:43,784 nipype.workflow INFO:
# 	 [Node] Finished "res_target", elapsed time 0.643026s.
# 241125-22:01:45,135 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0413_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.lap_target" in "/tmp/work/smriprep_wf/single_subject_002S0413_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/lap_target".
# 241125-22:01:45,137 nipype.workflow INFO:
# 	 [Node] Executing "lap_target" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:01:47,237 nipype.workflow INFO:
# 	 [Node] Finished "lap_target", elapsed time 2.100431s.
# 241125-22:01:49,140 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0413_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.mrg_target" in "/tmp/work/smriprep_wf/single_subject_002S0413_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/mrg_target".
# 241125-22:01:49,142 nipype.workflow INFO:
# 	 [Node] Executing "mrg_target" <nipype.interfaces.utility.base.Merge>
# 241125-22:01:49,142 nipype.workflow INFO:
# 	 [Node] Finished "mrg_target", elapsed time 0.000101s.
# 241125-22:02:27,652 nipype.workflow INFO:
# 	 [Node] Finished "_inu_n4_final0", elapsed time 44.507824s.
# 241125-22:02:29,140 nipype.workflow INFO:
# 	 [Node] Setting-up "_inu_n40" in "/tmp/work/smriprep_wf/single_subject_002S0729_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/inu_n4/mapflow/_inu_n40".
# 241125-22:02:29,141 nipype.workflow INFO:
# 	 [Node] Executing "_inu_n40" <nipype.interfaces.ants.segmentation.N4BiasFieldCorrection>
# 241125-22:03:08,274 nipype.workflow INFO:
# 	 [Node] Finished "_inu_n40", elapsed time 39.132902s.
# 241125-22:03:09,140 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0729_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.res_target" in "/tmp/work/smriprep_wf/single_subject_002S0729_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/res_target".
# 241125-22:03:09,140 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0729_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.lap_target" in "/tmp/work/smriprep_wf/single_subject_002S0729_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/lap_target".
# 241125-22:03:09,141 nipype.workflow INFO:
# 	 [Node] Executing "res_target" <niworkflows.interfaces.nibabel.RegridToZooms>
# 241125-22:03:09,142 nipype.workflow INFO:
# 	 [Node] Executing "lap_target" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:03:09,668 nipype.workflow INFO:
# 	 [Node] Finished "res_target", elapsed time 0.526234s.
# 241125-22:03:11,144 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0413_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.init_aff" in "/tmp/work/smriprep_wf/single_subject_002S0413_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/init_aff".
# 241125-22:03:11,146 nipype.workflow INFO:
# 	 [Node] Executing "init_aff" <nipype.interfaces.ants.utils.AI>
# 241125-22:03:11,196 nipype.workflow INFO:
# 	 [Node] Finished "lap_target", elapsed time 2.053083s.
# 241125-22:03:13,143 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0729_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.mrg_target" in "/tmp/work/smriprep_wf/single_subject_002S0729_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/mrg_target".
# 241125-22:03:13,144 nipype.workflow INFO:
# 	 [Node] Executing "mrg_target" <nipype.interfaces.utility.base.Merge>
# 241125-22:03:13,145 nipype.workflow INFO:
# 	 [Node] Finished "mrg_target", elapsed time 0.000105s.
# 241125-22:03:35,532 nipype.workflow INFO:
# 	 [Node] Finished "init_aff", elapsed time 24.385471s.
# 241125-22:03:37,145 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0729_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.init_aff" in "/tmp/work/smriprep_wf/single_subject_002S0729_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/init_aff".
# 241125-22:03:37,147 nipype.workflow INFO:
# 	 [Node] Executing "init_aff" <nipype.interfaces.ants.utils.AI>
# 241125-22:04:01,710 nipype.workflow INFO:
# 	 [Node] Finished "init_aff", elapsed time 24.562247s.
# 241125-22:04:03,142 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S1261_wf.anat_preproc_wf.anat_fit_wf.n4_only_wf.atropos_wf.01_atropos" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/n4_only_wf/atropos_wf/01_atropos".
# 241125-22:04:03,144 nipype.workflow INFO:
# 	 [Node] Executing "01_atropos" <nipype.interfaces.ants.segmentation.Atropos>
# 241125-22:04:29,457 nipype.workflow INFO:
# 	 [Node] Finished "01_atropos", elapsed time 26.313157s.
# 241125-22:04:31,146 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S1261_wf.anat_preproc_wf.anat_fit_wf.n4_only_wf.atropos_wf.02_pad_segm" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/n4_only_wf/atropos_wf/02_pad_segm".
# 241125-22:04:31,147 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0413_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.norm" in "/tmp/work/smriprep_wf/single_subject_002S0413_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/norm".
# 241125-22:04:31,149 nipype.workflow INFO:
# 	 [Node] Executing "02_pad_segm" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:04:31,153 nipype.workflow INFO:
# 	 [Node] Executing "norm" <niworkflows.interfaces.fixes.FixHeaderRegistration>
# 241125-22:04:31,475 nipype.workflow INFO:
# 	 [Node] Finished "02_pad_segm", elapsed time 0.325867s.
# 241125-22:04:33,230 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S1261_wf.anat_preproc_wf.anat_fit_wf.n4_only_wf.atropos_wf.04_sel_labels" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/n4_only_wf/atropos_wf/04_sel_labels".
# 241125-22:04:33,232 nipype.workflow INFO:
# 	 [Node] Executing "04_sel_labels" <nipype.interfaces.utility.wrappers.Function>
# 241125-22:04:33,323 nipype.workflow INFO:
# 	 [Node] Finished "04_sel_labels", elapsed time 0.090497s.
# 241125-22:04:35,584 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S1261_wf.anat_preproc_wf.anat_fit_wf.n4_only_wf.atropos_wf.05_get_wm" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/n4_only_wf/atropos_wf/05_get_wm".
# 241125-22:04:35,586 nipype.workflow INFO:
# 	 [Node] Executing "05_get_wm" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:04:36,384 nipype.workflow INFO:
# 	 [Node] Finished "05_get_wm", elapsed time 0.79769s.
# 241125-22:04:37,153 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S1261_wf.anat_preproc_wf.anat_fit_wf.n4_only_wf.atropos_wf.06_get_gm" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/n4_only_wf/atropos_wf/06_get_gm".
# 241125-22:04:37,156 nipype.workflow INFO:
# 	 [Node] Executing "06_get_gm" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:04:37,953 nipype.workflow INFO:
# 	 [Node] Finished "06_get_gm", elapsed time 0.796829s.
# 241125-22:04:39,153 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S1261_wf.anat_preproc_wf.anat_fit_wf.n4_only_wf.atropos_wf.10_me_csf" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/n4_only_wf/atropos_wf/10_me_csf".
# 241125-22:04:39,154 nipype.workflow INFO:
# 	 [Node] Executing "10_me_csf" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:04:41,507 nipype.workflow INFO:
# 	 [Node] Finished "10_me_csf", elapsed time 2.352094s.
# 241125-22:04:43,157 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S1261_wf.anat_preproc_wf.anat_fit_wf.n4_only_wf.atropos_wf.27_depad_csf" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/n4_only_wf/atropos_wf/27_depad_csf".
# 241125-22:04:43,158 nipype.workflow INFO:
# 	 [Node] Executing "27_depad_csf" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:04:43,475 nipype.workflow INFO:
# 	 [Node] Finished "27_depad_csf", elapsed time 0.31633s.
# 241125-22:04:45,157 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S1261_wf.anat_preproc_wf.anat_fit_wf.n4_only_wf.atropos_wf.09_relabel_wm" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/n4_only_wf/atropos_wf/09_relabel_wm".
# 241125-22:04:45,159 nipype.workflow INFO:
# 	 [Node] Executing "09_relabel_wm" <nipype.interfaces.ants.utils.MultiplyImages>
# 241125-22:04:45,593 nipype.workflow INFO:
# 	 [Node] Finished "09_relabel_wm", elapsed time 0.433855s.
# 241125-22:04:47,158 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S1261_wf.anat_preproc_wf.anat_fit_wf.n4_only_wf.atropos_wf.07_fill_gm" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/n4_only_wf/atropos_wf/07_fill_gm".
# 241125-22:04:47,160 nipype.workflow INFO:
# 	 [Node] Executing "07_fill_gm" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:04:55,18 nipype.workflow INFO:
# 	 [Node] Finished "07_fill_gm", elapsed time 7.85827s.
# 241125-22:04:55,176 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S1261_wf.anat_preproc_wf.anat_fit_wf.n4_only_wf.atropos_wf.26_depad_wm" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/n4_only_wf/atropos_wf/26_depad_wm".
# 241125-22:04:55,178 nipype.workflow INFO:
# 	 [Node] Executing "26_depad_wm" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:04:55,754 nipype.workflow INFO:
# 	 [Node] Finished "26_depad_wm", elapsed time 0.576158s.
# 241125-22:04:57,152 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S1261_wf.anat_preproc_wf.anat_fit_wf.n4_only_wf.atropos_wf.08_mult_gm" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/n4_only_wf/atropos_wf/08_mult_gm".
# 241125-22:04:57,154 nipype.workflow INFO:
# 	 [Node] Executing "08_mult_gm" <nipype.interfaces.ants.utils.MultiplyImages>
# 241125-22:04:57,703 nipype.workflow INFO:
# 	 [Node] Finished "08_mult_gm", elapsed time 0.548851s.
# 241125-22:04:59,159 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S1261_wf.anat_preproc_wf.anat_fit_wf.n4_only_wf.atropos_wf.11_add_gm" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/n4_only_wf/atropos_wf/11_add_gm".
# 241125-22:04:59,161 nipype.workflow INFO:
# 	 [Node] Executing "11_add_gm" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:05:00,323 nipype.workflow INFO:
# 	 [Node] Finished "11_add_gm", elapsed time 1.160845s.
# 241125-22:05:01,151 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S1261_wf.anat_preproc_wf.anat_fit_wf.n4_only_wf.atropos_wf.12_relabel_gm" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/n4_only_wf/atropos_wf/12_relabel_gm".
# 241125-22:05:01,153 nipype.workflow INFO:
# 	 [Node] Executing "12_relabel_gm" <nipype.interfaces.ants.utils.MultiplyImages>
# 241125-22:05:01,626 nipype.workflow INFO:
# 	 [Node] Finished "12_relabel_gm", elapsed time 0.473265s.
# 241125-22:05:03,156 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S1261_wf.anat_preproc_wf.anat_fit_wf.n4_only_wf.atropos_wf.13_add_gm_wm" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/n4_only_wf/atropos_wf/13_add_gm_wm".
# 241125-22:05:03,158 nipype.workflow INFO:
# 	 [Node] Executing "13_add_gm_wm" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:05:04,342 nipype.workflow INFO:
# 	 [Node] Finished "13_add_gm_wm", elapsed time 1.183264s.
# 241125-22:05:05,154 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S1261_wf.anat_preproc_wf.anat_fit_wf.n4_only_wf.atropos_wf.25_depad_gm" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/n4_only_wf/atropos_wf/25_depad_gm".
# 241125-22:05:05,156 nipype.workflow INFO:
# 	 [Node] Executing "25_depad_gm" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:05:05,738 nipype.workflow INFO:
# 	 [Node] Finished "25_depad_gm", elapsed time 0.581292s.
# 241125-22:05:07,153 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S1261_wf.anat_preproc_wf.anat_fit_wf.n4_only_wf.atropos_wf.14_sel_labels2" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/n4_only_wf/atropos_wf/14_sel_labels2".
# 241125-22:05:07,155 nipype.workflow INFO:
# 	 [Node] Executing "14_sel_labels2" <nipype.interfaces.utility.wrappers.Function>
# 241125-22:05:07,285 nipype.workflow INFO:
# 	 [Node] Finished "14_sel_labels2", elapsed time 0.12981s.
# 241125-22:05:09,159 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S1261_wf.anat_preproc_wf.anat_fit_wf.n4_only_wf.atropos_wf.24_depad_segm" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/n4_only_wf/atropos_wf/24_depad_segm".
# 241125-22:05:09,161 nipype.workflow INFO:
# 	 [Node] Executing "24_depad_segm" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:05:09,667 nipype.workflow INFO:
# 	 [Node] Finished "24_depad_segm", elapsed time 0.50597s.
# 241125-22:05:11,153 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S1261_wf.anat_preproc_wf.anat_fit_wf.n4_only_wf.atropos_wf.merge_tpms" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/n4_only_wf/atropos_wf/merge_tpms".
# 241125-22:05:11,157 nipype.workflow INFO:
# 	 [Node] Executing "merge_tpms" <nipype.interfaces.utility.base.Merge>
# 241125-22:05:11,158 nipype.workflow INFO:
# 	 [Node] Finished "merge_tpms", elapsed time 0.000147s.
# 241125-22:05:13,158 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S1261_wf.anat_preproc_wf.anat_fit_wf.n4_only_wf.atropos_wf.15_add_7" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/n4_only_wf/atropos_wf/15_add_7".
# 241125-22:05:13,159 nipype.workflow INFO:
# 	 [Node] Executing "15_add_7" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:05:14,71 nipype.workflow INFO:
# 	 [Node] Finished "15_add_7", elapsed time 0.910895s.
# 241125-22:05:15,153 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S1261_wf.anat_preproc_wf.anat_fit_wf.n4_only_wf.atropos_wf.16_me_7" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/n4_only_wf/atropos_wf/16_me_7".
# 241125-22:05:15,155 nipype.workflow INFO:
# 	 [Node] Executing "16_me_7" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:05:16,971 nipype.workflow INFO:
# 	 [Node] Finished "16_me_7", elapsed time 1.816235s.
# 241125-22:05:17,156 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S1261_wf.anat_preproc_wf.anat_fit_wf.n4_only_wf.atropos_wf.17_comp_7" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/n4_only_wf/atropos_wf/17_comp_7".
# 241125-22:05:17,158 nipype.workflow INFO:
# 	 [Node] Executing "17_comp_7" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:05:18,319 nipype.workflow INFO:
# 	 [Node] Finished "17_comp_7", elapsed time 1.1599s.
# 241125-22:05:19,150 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S1261_wf.anat_preproc_wf.anat_fit_wf.n4_only_wf.atropos_wf.18_md_7" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/n4_only_wf/atropos_wf/18_md_7".
# 241125-22:05:19,152 nipype.workflow INFO:
# 	 [Node] Executing "18_md_7" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:05:20,222 nipype.workflow INFO:
# 	 [Node] Finished "18_md_7", elapsed time 1.070427s.
# 241125-22:05:21,154 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S1261_wf.anat_preproc_wf.anat_fit_wf.n4_only_wf.atropos_wf.19_fill_7" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/n4_only_wf/atropos_wf/19_fill_7".
# 241125-22:05:21,156 nipype.workflow INFO:
# 	 [Node] Executing "19_fill_7" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:05:28,534 nipype.workflow INFO:
# 	 [Node] Finished "19_fill_7", elapsed time 7.378084s.
# 241125-22:05:29,162 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S1261_wf.anat_preproc_wf.anat_fit_wf.n4_only_wf.atropos_wf.20_add_7_2" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/n4_only_wf/atropos_wf/20_add_7_2".
# 241125-22:05:29,164 nipype.workflow INFO:
# 	 [Node] Executing "20_add_7_2" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:05:30,221 nipype.workflow INFO:
# 	 [Node] Finished "20_add_7_2", elapsed time 1.057317s.
# 241125-22:05:31,152 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S1261_wf.anat_preproc_wf.anat_fit_wf.n4_only_wf.atropos_wf.21_md_7_2" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/n4_only_wf/atropos_wf/21_md_7_2".
# 241125-22:05:31,154 nipype.workflow INFO:
# 	 [Node] Executing "21_md_7_2" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:05:32,294 nipype.workflow INFO:
# 	 [Node] Finished "21_md_7_2", elapsed time 1.140307s.
# 241125-22:05:33,151 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S1261_wf.anat_preproc_wf.anat_fit_wf.n4_only_wf.atropos_wf.22_me_7_2" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/n4_only_wf/atropos_wf/22_me_7_2".
# 241125-22:05:33,153 nipype.workflow INFO:
# 	 [Node] Executing "22_me_7_2" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:05:34,978 nipype.workflow INFO:
# 	 [Node] Finished "22_me_7_2", elapsed time 1.824441s.
# 241125-22:05:35,153 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S1261_wf.anat_preproc_wf.anat_fit_wf.n4_only_wf.atropos_wf.23_depad_mask" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/n4_only_wf/atropos_wf/23_depad_mask".
# 241125-22:05:35,155 nipype.workflow INFO:
# 	 [Node] Executing "23_depad_mask" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:05:35,686 nipype.workflow INFO:
# 	 [Node] Finished "23_depad_mask", elapsed time 0.530881s.
# 241125-22:05:37,153 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S1261_wf.anat_preproc_wf.anat_fit_wf.n4_only_wf.atropos_wf.msk_conform" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/n4_only_wf/atropos_wf/msk_conform".
# 241125-22:05:37,157 nipype.workflow INFO:
# 	 [Node] Executing "msk_conform" <nipype.interfaces.utility.wrappers.Function>
# 241125-22:05:37,311 nipype.workflow INFO:
# 	 [Node] Finished "msk_conform", elapsed time 0.153464s.
# 241125-22:15:28,359 nipype.workflow INFO:
# 	 [Node] Finished "norm", elapsed time 657.205503s.
# 241125-22:15:29,189 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0729_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.norm" in "/tmp/work/smriprep_wf/single_subject_002S0729_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/norm".
# 241125-22:15:29,190 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0413_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.map_brainmask" in "/tmp/work/smriprep_wf/single_subject_002S0413_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/map_brainmask".
# 241125-22:15:29,193 nipype.workflow INFO:
# 	 [Node] Executing "map_brainmask" <niworkflows.interfaces.fixes.FixHeaderApplyTransforms>
# 241125-22:15:29,194 nipype.workflow INFO:
# 	 [Node] Executing "norm" <niworkflows.interfaces.fixes.FixHeaderRegistration>
# 241125-22:15:43,376 nipype.workflow INFO:
# 	 [Node] Finished "map_brainmask", elapsed time 14.182804s.
# 241125-22:15:45,210 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0413_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.map_wmmask" in "/tmp/work/smriprep_wf/single_subject_002S0413_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/map_wmmask".
# 241125-22:15:45,216 nipype.workflow INFO:
# 	 [Node] Executing "map_wmmask" <niworkflows.interfaces.fixes.FixHeaderApplyTransforms>
# 241125-22:15:59,535 nipype.workflow INFO:
# 	 [Node] Finished "map_wmmask", elapsed time 14.317471s.
# 241125-22:16:01,199 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0413_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.thr_brainmask" in "/tmp/work/smriprep_wf/single_subject_002S0413_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/thr_brainmask".
# 241125-22:16:01,201 nipype.workflow INFO:
# 	 [Node] Executing "thr_brainmask" <nipype.interfaces.ants.utils.ThresholdImage>
# 241125-22:16:01,918 nipype.workflow INFO:
# 	 [Node] Finished "thr_brainmask", elapsed time 0.717161s.
# 241125-22:16:03,194 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0413_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.dil_brainmask" in "/tmp/work/smriprep_wf/single_subject_002S0413_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/dil_brainmask".
# 241125-22:16:03,195 nipype.workflow INFO:
# 	 [Node] Executing "dil_brainmask" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:16:04,53 nipype.workflow INFO:
# 	 [Node] Finished "dil_brainmask", elapsed time 0.857668s.
# 241125-22:16:05,196 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0413_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.03_pad_mask" in "/tmp/work/smriprep_wf/single_subject_002S0413_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/03_pad_mask".
# 241125-22:16:05,197 nipype.workflow INFO:
# 	 [Node] Executing "03_pad_mask" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:16:05,684 nipype.workflow INFO:
# 	 [Node] Finished "03_pad_mask", elapsed time 0.486218s.
# 241125-22:16:07,195 nipype.workflow INFO:
# ...
# 241125-22:29:01,237 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0413_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.15_add_7" in "/tmp/work/smriprep_wf/single_subject_002S0413_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/15_add_7".
# 241125-22:29:01,238 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S1261_wf.anat_preproc_wf.anat_fit_wf.lut_t1w_dseg" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/lut_t1w_dseg".
# 241125-22:29:01,239 nipype.workflow INFO:
# 	 [Node] Executing "15_add_7" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:29:01,239 nipype.workflow INFO:
# 	 [Node] Executing "15_add_7" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:29:01,239 nipype.workflow INFO:
# 	 [Node] Executing "merge_tpms" <nipype.interfaces.utility.base.Merge>
# 241125-22:29:01,240 nipype.workflow INFO:
# 	 [Node] Finished "merge_tpms", elapsed time 0.000144s.
# 241125-22:29:01,277 nipype.workflow INFO:
# 	 [Node] Executing "lut_t1w_dseg" <nipype.interfaces.utility.wrappers.Function>
# 241125-22:29:01,462 nipype.workflow INFO:
# 	 [Node] Finished "lut_t1w_dseg", elapsed time 0.184881s.
# 241125-22:29:02,225 nipype.workflow INFO:
# 	 [Node] Finished "15_add_7", elapsed time 0.985383s.
# 241125-22:29:02,347 nipype.workflow INFO:
# 	 [Node] Finished "15_add_7", elapsed time 1.108193s.
# 241125-22:29:03,238 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0413_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.16_me_7" in "/tmp/work/smriprep_wf/single_subject_002S0413_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/16_me_7".
# 241125-22:29:03,238 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0729_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.16_me_7" in "/tmp/work/smriprep_wf/single_subject_002S0729_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/16_me_7".
# 241125-22:29:03,239 nipype.workflow INFO:
# 	 [Node] Executing "16_me_7" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:29:03,240 nipype.workflow INFO:
# 	 [Node] Executing "16_me_7" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:29:05,95 nipype.workflow INFO:
# 	 [Node] Finished "16_me_7", elapsed time 1.854741s.
# 241125-22:29:05,150 nipype.workflow INFO:
# 	 [Node] Finished "16_me_7", elapsed time 1.909112s.
# 241125-22:29:05,237 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0413_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.17_comp_7" in "/tmp/work/smriprep_wf/single_subject_002S0413_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/17_comp_7".
# 241125-22:29:05,238 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0729_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.17_comp_7" in "/tmp/work/smriprep_wf/single_subject_002S0729_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/17_comp_7".
# 241125-22:29:05,239 nipype.workflow INFO:
# 	 [Node] Executing "17_comp_7" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:29:05,239 nipype.workflow INFO:
# 	 [Node] Executing "17_comp_7" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:29:06,414 nipype.workflow INFO:
# 	 [Node] Finished "17_comp_7", elapsed time 1.1745s.
# 241125-22:29:06,429 nipype.workflow INFO:
# 	 [Node] Finished "17_comp_7", elapsed time 1.189556s.
# 241125-22:29:06,775 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S1261_wf.anat_preproc_wf.anat_fit_wf.anat_reports_wf.seg_rpt" in "/tmp/work/smriprep_wf/single_subject_002S1261_wf/anat_preproc_wf/anat_fit_wf/anat_reports_wf/seg_rpt".
# 241125-22:29:06,777 nipype.workflow INFO:
# 	 [Node] Executing "seg_rpt" <niworkflows.interfaces.reportlets.masks.ROIsPlot>
# 241125-22:29:07,247 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0413_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.18_md_7" in "/tmp/work/smriprep_wf/single_subject_002S0413_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/18_md_7".
# 241125-22:29:07,247 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0729_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.18_md_7" in "/tmp/work/smriprep_wf/single_subject_002S0729_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/18_md_7".
# 241125-22:29:07,249 nipype.workflow INFO:
# 	 [Node] Executing "18_md_7" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:29:07,249 nipype.workflow INFO:
# 	 [Node] Executing "18_md_7" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:29:08,321 nipype.workflow INFO:
# 	 [Node] Finished "18_md_7", elapsed time 1.071219s.
# 241125-22:29:08,356 nipype.workflow INFO:
# 	 [Node] Finished "18_md_7", elapsed time 1.106646s.
# 241125-22:29:09,248 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0413_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.19_fill_7" in "/tmp/work/smriprep_wf/single_subject_002S0413_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/19_fill_7".
# 241125-22:29:09,248 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0729_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.19_fill_7" in "/tmp/work/smriprep_wf/single_subject_002S0729_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/19_fill_7".
# 241125-22:29:09,249 nipype.workflow INFO:
# 	 [Node] Executing "19_fill_7" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:29:09,250 nipype.workflow INFO:
# 	 [Node] Executing "19_fill_7" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:29:16,818 nipype.workflow INFO:
# 	 [Node] Finished "seg_rpt", elapsed time 10.04017s.
# 241125-22:29:17,132 nipype.workflow INFO:
# 	 [Node] Finished "19_fill_7", elapsed time 7.88193s.
# 241125-22:29:17,217 nipype.workflow INFO:
# 	 [Node] Finished "19_fill_7", elapsed time 7.967136s.
# 241125-22:29:17,248 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0413_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.20_add_7_2" in "/tmp/work/smriprep_wf/single_subject_002S0413_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/20_add_7_2".
# 241125-22:29:17,250 nipype.workflow INFO:
# 	 [Node] Executing "20_add_7_2" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:29:18,345 nipype.workflow INFO:
# 	 [Node] Finished "20_add_7_2", elapsed time 1.095101s.
# 241125-22:29:19,238 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0729_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.20_add_7_2" in "/tmp/work/smriprep_wf/single_subject_002S0729_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/20_add_7_2".
# 241125-22:29:19,238 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0413_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.21_md_7_2" in "/tmp/work/smriprep_wf/single_subject_002S0413_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/21_md_7_2".
# 241125-22:29:19,240 nipype.workflow INFO:
# 	 [Node] Executing "21_md_7_2" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:29:19,240 nipype.workflow INFO:
# 	 [Node] Executing "20_add_7_2" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:29:20,318 nipype.workflow INFO:
# 	 [Node] Finished "21_md_7_2", elapsed time 1.077371s.
# 241125-22:29:20,441 nipype.workflow INFO:
# 	 [Node] Finished "20_add_7_2", elapsed time 1.200247s.
# 241125-22:29:21,238 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0729_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.21_md_7_2" in "/tmp/work/smriprep_wf/single_subject_002S0729_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/21_md_7_2".
# 241125-22:29:21,238 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0413_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.22_me_7_2" in "/tmp/work/smriprep_wf/single_subject_002S0413_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/22_me_7_2".
# 241125-22:29:21,239 nipype.workflow INFO:
# 	 [Node] Executing "21_md_7_2" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:29:21,239 nipype.workflow INFO:
# 	 [Node] Executing "22_me_7_2" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:29:22,298 nipype.workflow INFO:
# 	 [Node] Finished "21_md_7_2", elapsed time 1.058157s.
# 241125-22:29:23,100 nipype.workflow INFO:
# 	 [Node] Finished "22_me_7_2", elapsed time 1.860201s.
# 241125-22:29:23,241 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0729_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.22_me_7_2" in "/tmp/work/smriprep_wf/single_subject_002S0729_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/22_me_7_2".
# 241125-22:29:23,241 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0413_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.23_depad_mask" in "/tmp/work/smriprep_wf/single_subject_002S0413_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/23_depad_mask".
# 241125-22:29:23,242 nipype.workflow INFO:
# 	 [Node] Executing "22_me_7_2" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:29:23,242 nipype.workflow INFO:
# 	 [Node] Executing "23_depad_mask" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:29:23,872 nipype.workflow INFO:
# 	 [Node] Finished "23_depad_mask", elapsed time 0.629141s.
# 241125-22:29:25,159 nipype.workflow INFO:
# 	 [Node] Finished "22_me_7_2", elapsed time 1.9167459999999998s.
# 241125-22:29:25,241 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0729_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.23_depad_mask" in "/tmp/work/smriprep_wf/single_subject_002S0729_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/23_depad_mask".
# 241125-22:29:25,241 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0413_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.msk_conform" in "/tmp/work/smriprep_wf/single_subject_002S0413_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/msk_conform".
# 241125-22:29:25,243 nipype.workflow INFO:
# 	 [Node] Executing "msk_conform" <nipype.interfaces.utility.wrappers.Function>
# 241125-22:29:25,243 nipype.workflow INFO:
# 	 [Node] Executing "23_depad_mask" <nipype.interfaces.ants.utils.ImageMath>
# 241125-22:29:25,401 nipype.workflow INFO:
# 	 [Node] Finished "msk_conform", elapsed time 0.157321s.
# 241125-22:29:25,723 nipype.workflow INFO:
# 	 [Node] Finished "23_depad_mask", elapsed time 0.478979s.
# 241125-22:29:27,241 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0729_wf.anat_preproc_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.msk_conform" in "/tmp/work/smriprep_wf/single_subject_002S0729_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/msk_conform".
# 241125-22:29:27,247 nipype.workflow INFO:
# 	 [Node] Executing "msk_conform" <nipype.interfaces.utility.wrappers.Function>
# 241125-22:29:27,406 nipype.workflow INFO:
# 	 [Node] Finished "msk_conform", elapsed time 0.158829s.
# 241125-22:29:30,373 nipype.workflow INFO:
# 	 [Node] Setting-up "_apply_mask0" in "/tmp/work/smriprep_wf/single_subject_002S0413_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/apply_mask/mapflow/_apply_mask0".
# 241125-22:29:30,374 nipype.workflow INFO:
# 	 [Node] Executing "_apply_mask0" <niworkflows.interfaces.nibabel.ApplyMask>
# 241125-22:29:30,469 nipype.workflow INFO:
# 	 [Node] Finished "_apply_mask0", elapsed time 0.094971s.
# 241125-22:29:33,4 nipype.interface WARNING:
# 	 Changing /out/smriprep/sub-002S0413/ses-201205151642320/anat/sub-002S0413_ses-201205151642320_desc-brain_mask.nii.gz dtype from int16 to uint8
# 241125-22:29:33,446 nipype.workflow INFO:
# 	 [Node] Setting-up "_apply_mask0" in "/tmp/work/smriprep_wf/single_subject_002S0729_wf/anat_preproc_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/apply_mask/mapflow/_apply_mask0".
# 241125-22:29:33,446 nipype.workflow INFO:
# 	 [Node] Executing "_apply_mask0" <niworkflows.interfaces.nibabel.ApplyMask>
# 241125-22:29:33,533 nipype.workflow INFO:
# 	 [Node] Finished "_apply_mask0", elapsed time 0.086751s.
# 241125-22:29:36,260 nipype.interface WARNING:
# 	 Changing /out/smriprep/sub-002S0729/ses-201208070724400/anat/sub-002S0729_ses-201208070724400_desc-brain_mask.nii.gz dtype from int16 to uint8
# 241125-22:29:36,678 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0413_wf.anat_preproc_wf.ds_anat_volumes_wf.mask_anat" in "/tmp/work/smriprep_wf/single_subject_002S0413_wf/anat_preproc_wf/ds_anat_volumes_wf/mask_anat".
# 241125-22:29:36,679 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0729_wf.anat_preproc_wf.anat_fit_wf.fast" in "/tmp/work/smriprep_wf/single_subject_002S0729_wf/anat_preproc_wf/anat_fit_wf/fast".
# 241125-22:29:36,679 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0729_wf.anat_preproc_wf.ds_anat_volumes_wf.mask_anat" in "/tmp/work/smriprep_wf/single_subject_002S0729_wf/anat_preproc_wf/ds_anat_volumes_wf/mask_anat".
# 241125-22:29:36,680 nipype.workflow INFO:
# 	 [Node] Executing "mask_anat" <niworkflows.interfaces.nibabel.ApplyMask>
# 241125-22:29:36,682 nipype.workflow INFO:
# 	 [Node] Executing "fast" <nipype.interfaces.fsl.preprocess.FAST>
# 241125-22:29:36,682 nipype.workflow INFO:
# 	 [Node] Executing "mask_anat" <niworkflows.interfaces.nibabel.ApplyMask>
# 241125-22:29:36,747 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0413_wf.anat_preproc_wf.anat_fit_wf.fast" in "/tmp/work/smriprep_wf/single_subject_002S0413_wf/anat_preproc_wf/anat_fit_wf/fast".
# 241125-22:29:36,750 nipype.workflow INFO:
# 	 [Node] Executing "fast" <nipype.interfaces.fsl.preprocess.FAST>
# 241125-22:29:37,85 nipype.workflow INFO:
# 	 [Node] Finished "mask_anat", elapsed time 0.402829s.
# 241125-22:29:37,95 nipype.workflow INFO:
# 	 [Node] Finished "mask_anat", elapsed time 0.414318s.
# 241125-22:30:32,908 nipype.workflow INFO:
# 	 [Node] Finished "fast", elapsed time 56.225971s.
# 241125-22:30:34,686 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0729_wf.anat_preproc_wf.anat_fit_wf.lut_t1w_dseg" in "/tmp/work/smriprep_wf/single_subject_002S0729_wf/anat_preproc_wf/anat_fit_wf/lut_t1w_dseg".
# 241125-22:30:34,723 nipype.workflow INFO:
# 	 [Node] Executing "lut_t1w_dseg" <nipype.interfaces.utility.wrappers.Function>
# 241125-22:30:34,925 nipype.workflow INFO:
# 	 [Node] Finished "lut_t1w_dseg", elapsed time 0.200945s.
# 241125-22:30:40,251 nipype.workflow INFO:
# 	 [Node] Finished "fast", elapsed time 63.500527s.
# 241125-22:30:40,536 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0413_wf.anat_preproc_wf.anat_fit_wf.lut_t1w_dseg" in "/tmp/work/smriprep_wf/single_subject_002S0413_wf/anat_preproc_wf/anat_fit_wf/lut_t1w_dseg".
# 241125-22:30:40,538 nipype.workflow INFO:
# 	 [Node] Executing "lut_t1w_dseg" <nipype.interfaces.utility.wrappers.Function>
# 241125-22:30:40,735 nipype.workflow INFO:
# 	 [Node] Finished "lut_t1w_dseg", elapsed time 0.196914s.
# 241125-22:30:41,7 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0729_wf.anat_preproc_wf.anat_fit_wf.anat_reports_wf.seg_rpt" in "/tmp/work/smriprep_wf/single_subject_002S0729_wf/anat_preproc_wf/anat_fit_wf/anat_reports_wf/seg_rpt".
# 241125-22:30:41,10 nipype.workflow INFO:
# 	 [Node] Executing "seg_rpt" <niworkflows.interfaces.reportlets.masks.ROIsPlot>
# 241125-22:30:47,269 nipype.workflow INFO:
# 	 [Node] Setting-up "smriprep_wf.single_subject_002S0413_wf.anat_preproc_wf.anat_fit_wf.anat_reports_wf.seg_rpt" in "/tmp/work/smriprep_wf/single_subject_002S0413_wf/anat_preproc_wf/anat_fit_wf/anat_reports_wf/seg_rpt".
# 241125-22:30:47,271 nipype.workflow INFO:
# 	 [Node] Executing "seg_rpt" <niworkflows.interfaces.reportlets.masks.ROIsPlot>
# 241125-22:30:53,43 nipype.workflow INFO:
# 	 [Node] Finished "seg_rpt", elapsed time 12.032886s.
# 241125-22:30:59,377 nipype.workflow INFO:
# 	 [Node] Finished "seg_rpt", elapsed time 12.105292s.

# %%
import nibabel as nib

data = nib.load("data/mri/adni_thesis/sub-002S0413/ses-201205151642320/anat/sub-002S0413_ses-201205151642320_T1w.nii")
data_processed = nib.load("data_processed/mri/smriprep/sub-002S0413/ses-201205151642320/anat/sub-002S0413_ses-201205151642320_desc-preproc_T1w.nii.gz")

print(data.shape)
print(data_processed.shape)
# Out:
# (170, 256, 256)
# (170, 256, 256)

# %%
import matplotlib.pyplot as plt

plt.imshow(data.get_fdata()[:, 100, :], cmap='gray')

# %%
import numpy as np
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
from matplotlib import transforms


# %matplotlib inline

def plot_func(slice):
    fig, axes = plt.subplots(1, 2, figsize=(18, 9))  # Create side-by-side subplots

    tr = transforms.Affine2D().rotate_deg(90)

    # Plot the first image
    axes[0].imshow(data.get_fdata()[:, :, slice], cmap='gray', origin='lower')
    axes[0].set_title(f'Image basic preprocessing - Slice {slice}')
    axes[0].axis('off')

    # Plot the second image
    axes[1].imshow(data_processed.get_fdata()[:, :, slice], cmap='gray', origin='lower')
    axes[1].set_title(f'Image preprocessed - Slice {slice}')
    axes[1].axis('off')

    plt.show()

# Interactive slider
interact(
    plot_func,
    slice=widgets.IntSlider(value=100, min=0, max=data.shape[1]-1, step=5)
)
# Out:
# interactive(children=(IntSlider(value=100, description='slice', max=255, step=5), Output()), _dom_classes=('wi…
# <function __main__.plot_func(slice)>
