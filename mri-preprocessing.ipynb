# %% [markdown]
# ### MR files are nested in directories, make the structure flat

# %%
import glob
import os
from os import write

# %%
dataset_base_path = "/media/jfallmann/T9/University/master_thesis/dataset"

mri_raw_path = f"{dataset_base_path}/mri/raw"
mri_base_path = f"{dataset_base_path}/mri"
snp_raw_path = f"{dataset_base_path}/snp/raw"
mri_bids_path = f"{dataset_base_path}/mri/bids"
mri_fastsurfer_out = f"{dataset_base_path}/mri/processed"
tables_path = f"{dataset_base_path}/tables"

# %%
# Get all the MR files
mr_input_files = glob.glob(f'{mri_raw_path}/**/*.nii', recursive=True)
print(f"Found {len(mr_input_files)} MR files")
# Out:
# Found 2248 MR files

# %%
## are there any directories with multiple files?
from collections import defaultdict
dir_files = defaultdict(list)
for file in mr_input_files:
    dir_files[os.path.dirname(file)].append(file)

for k, v in dir_files.items():
    if len(v) > 1:
        print(k, v)

print("Done")
# Out:
# Done

# %%
def clean_id(id: str) -> str:
    return id.replace("_", "").replace(".", "").replace("-", "").lower()

# %%
import re
# Get all subject ids where genome data is available
genome_files = glob.glob(f'{snp_raw_path}/**/*.vcf', recursive=True)
genome_split_regex = r'(.*)_SNP'
genome_subjects = [re.search(genome_split_regex, os.path.basename(file)).group(1) for file in genome_files]
genome_subjects = [clean_id(subject) for subject in genome_subjects]
print(f"Found {len(genome_subjects)} subjects with genome data")
# Out:
# Found 809 subjects with genome data

# %%
banned_subjects = []

with open(f'{dataset_base_path}/banned_subjects.txt') as subjects_file:
    for line in subjects_file:
        banned_subjects.append(line.strip())

allowed_subjects = [subject for subject in genome_subjects if subject not in banned_subjects]
print(f"Found {len(allowed_subjects)} subjects after removing banned subjects")
# Out:
# Found 806 subjects after removing banned subjects

# %%
# files have the structure ADNI/<subject-id>/<preprocessing-name>/<session-id>/<some-id>/<filename>.nii
# we want to group files by subject id, choose the folder with the longest name and use the most recent session
# if there are multiple files in the same session, choose the one with the longest name
# session name is a date string in the format YYYY-MM-DD_THH_MM.0

files_per_subject = defaultdict(str)

for file in mr_input_files:
    file_splits = file.split('/')

    adni_index = file_splits.index('ADNI')
    subject_id = clean_id(file_splits[adni_index + 1])
    preprocessing_name = file_splits[adni_index + 2]
    session_id =  file_splits[adni_index + 3]

    # skip if subject has no genome data
    if subject_id not in allowed_subjects:
        print(f"Skipping {subject_id} as no genome data is available")
        continue

    # get current file stored for subject
    current_file = files_per_subject.get(subject_id, None)
    if current_file is None:
        files_per_subject[subject_id] = file
    else:
        current_file_splits = current_file.split('/')
        current_session_id = current_file_splits[adni_index + 3]
        current_preprocessing_name = current_file_splits[adni_index + 2]

        if session_id > current_session_id:
            files_per_subject[subject_id] = file
        elif session_id == current_session_id:
            if len(preprocessing_name) > len(current_preprocessing_name):
                files_per_subject[subject_id] = file

print(f"Found {len(files_per_subject)} subjects with MR data")
# Out:
# Skipping 099s4124 as no genome data is available
# Skipping 153s4165 as no genome data is available
# Skipping 003s4142 as no genome data is available
# Skipping 137s4227 as no genome data is available
# Skipping 094s4295 as no genome data is available
# Skipping 109s4378 as no genome data is available
# Skipping 041s4375 as no genome data is available
# Skipping 941s4377 as no genome data is available
# Skipping 941s4377 as no genome data is available
# Skipping 109s4380 as no genome data is available
# Skipping 041s4495 as no genome data is available
# Skipping 109s4471 as no genome data is available
# Skipping 016s4601 as no genome data is available
# Skipping 137s4623 as no genome data is available
# Skipping 137s4587 as no genome data is available
# Skipping 109s4594 as no genome data is available
# Skipping 109s4594 as no genome data is available
# Skipping 021s4633 as no genome data is available
# Skipping 003s4644 as no genome data is available
# Skipping 024s4674 as no genome data is available
# Skipping 029s4652 as no genome data is available
# Skipping 135s4689 as no genome data is available
# Skipping 135s4689 as no genome data is available
# Skipping 137s4678 as no genome data is available
# Skipping 135s4710 as no genome data is available
# Skipping 016s4646 as no genome data is available
# Skipping 126s4712 as no genome data is available
# Skipping 135s4723 as no genome data is available
# Skipping 126s4743 as no genome data is available
# Skipping 073s4739 as no genome data is available
# Skipping 941s4764 as no genome data is available
# Skipping 941s4764 as no genome data is available
# Skipping 021s4744 as no genome data is available
# Skipping 128s4742 as no genome data is available
# Skipping 128s4742 as no genome data is available
# Skipping 128s4745 as no genome data is available
# Skipping 027s4757 as no genome data is available
# Skipping 073s4777 as no genome data is available
# Skipping 127s4765 as no genome data is available
# Skipping 072s4694 as no genome data is available
# Skipping 123s4780 as no genome data is available
# Skipping 123s4780 as no genome data is available
# Skipping 128s4774 as no genome data is available
# Skipping 035s4784 as no genome data is available
# Skipping 070s4798 as no genome data is available
# Skipping 032s4755 as no genome data is available
# Skipping 011s4827 as no genome data is available
# Skipping 011s4827 as no genome data is available
# Skipping 073s4825 as no genome data is available
# Skipping 073s4825 as no genome data is available
# Skipping 003s4839 as no genome data is available
# Skipping 021s4857 as no genome data is available
# Skipping 021s4857 as no genome data is available
# Skipping 027s4802 as no genome data is available
# Skipping 041s4874 as no genome data is available
# Skipping 116s4855 as no genome data is available
# Skipping 057s4888 as no genome data is available
# Skipping 052s4807 as no genome data is available
# Skipping 070s4856 as no genome data is available
# Skipping 070s4856 as no genome data is available
# Skipping 072s4769 as no genome data is available
# Skipping 127s4843 as no genome data is available
# Skipping 128s4832 as no genome data is available
# Skipping 128s4832 as no genome data is available
# Skipping 141s4819 as no genome data is available
# Skipping 072s4871 as no genome data is available
# Skipping 116s4898 as no genome data is available
# Skipping 116s4898 as no genome data is available
# Skipping 041s4876 as no genome data is available
# Skipping 024s4905 as no genome data is available
# Skipping 024s4905 as no genome data is available
# Skipping 016s4887 as no genome data is available
# Skipping 016s4887 as no genome data is available
# Skipping 052s4885 as no genome data is available
# Skipping 057s4909 as no genome data is available
# Skipping 027s4919 as no genome data is available
# Skipping 068s4914 as no genome data is available
# Skipping 037s4879 as no genome data is available
# Skipping 037s4879 as no genome data is available
# Skipping 032s4921 as no genome data is available
# Skipping 127s4940 as no genome data is available
# Skipping 020s4920 as no genome data is available
# Skipping 020s4920 as no genome data is available
# Skipping 135s4954 as no genome data is available
# Skipping 067s4918 as no genome data is available
# Skipping 067s4918 as no genome data is available
# Skipping 027s4926 as no genome data is available
# Skipping 016s4951 as no genome data is available
# Skipping 016s4951 as no genome data is available
# Skipping 009s0751 as no genome data is available
# Skipping 027s4962 as no genome data is available
# Skipping 016s4963 as no genome data is available
# Skipping 041s4989 as no genome data is available
# Skipping 023s4035 as no genome data is available
# Skipping 009s5000 as no genome data is available
# Skipping 009s5000 as no genome data is available
# Skipping 082s5014 as no genome data is available
# Skipping 082s5014 as no genome data is available
# Skipping 022s5004 as no genome data is available
# Skipping 033s5013 as no genome data is available
# Skipping 127s5028 as no genome data is available
# Skipping 073s4995 as no genome data is available
# Skipping 016s5007 as no genome data is available
# Skipping 052s4944 as no genome data is available
# Skipping 114s5047 as no genome data is available
# Skipping 009s5027 as no genome data is available
# Skipping 009s5027 as no genome data is available
# Skipping 009s5037 as no genome data is available
# Skipping 128s5066 as no genome data is available
# Skipping 073s5090 as no genome data is available
# Skipping 033s5087 as no genome data is available
# Skipping 041s5078 as no genome data is available
# Skipping 068s4968 as no genome data is available
# Skipping 941s5124 as no genome data is available
# Skipping 021s5099 as no genome data is available
# Skipping 036s5149 as no genome data is available
# Skipping 041s5097 as no genome data is available
# Skipping 041s5097 as no genome data is available
# Skipping 041s5131 as no genome data is available
# Skipping 036s5112 as no genome data is available
# Skipping 041s5173 as no genome data is available
# Skipping 021s4718 as no genome data is available
# Skipping 023s5120 as no genome data is available
# Skipping 067s5160 as no genome data is available
# Skipping 094s4649 as no genome data is available
# Skipping 036s4538 as no genome data is available
# Skipping 036s5210 as no genome data is available
# Skipping 033s5198 as no genome data is available
# Skipping 072s5207 as no genome data is available
# Skipping 020s5203 as no genome data is available
# Skipping 067s4767 as no genome data is available
# Skipping 128s4671 as no genome data is available
# Skipping 021s5236 as no genome data is available
# Skipping 029s5219 as no genome data is available
# Skipping 067s5212 as no genome data is available
# Skipping 036s5248 as no genome data is available
# Skipping 135s5269 as no genome data is available
# Skipping 082s5279 as no genome data is available
# Skipping 082s5278 as no genome data is available
# Skipping 011s4845 as no genome data is available
# Skipping 032s5263 as no genome data is available
# Skipping 032s5263 as no genome data is available
# Skipping 036s5271 as no genome data is available
# Skipping 041s5253 as no genome data is available
# Skipping 135s5273 as no genome data is available
# Skipping 073s5227 as no genome data is available
# Skipping 036s4820 as no genome data is available
# Skipping 016s4902 as no genome data is available
# Skipping 016s4638 as no genome data is available
# Skipping 003s5150 as no genome data is available
# Skipping 003s5209 as no genome data is available
# Skipping 007s5265 as no genome data is available
# Skipping 022s4922 as no genome data is available
# Skipping 051s5285 as no genome data is available
# Skipping 009s4814 as no genome data is available
# Skipping 128s4842 as no genome data is available
# Skipping 011s4949 as no genome data is available
# Skipping 035s4783 as no genome data is available
# Skipping 153s4838 as no genome data is available
# Skipping 073s4795 as no genome data is available
# Skipping 009s5125 as no genome data is available
# Skipping 009s5125 as no genome data is available
# Skipping 009s5252 as no genome data is available
# Skipping 041s5082 as no genome data is available
# Skipping 003s4872 as no genome data is available
# Skipping 051s5005 as no genome data is available
# Skipping 036s5063 as no genome data is available
# Skipping 098s4002 as no genome data is available
# Skipping 070s5040 as no genome data is available
# Skipping 041s5141 as no genome data is available
# Skipping 021s5129 as no genome data is available
# Skipping 941s4066 as no genome data is available
# Skipping 041s5100 as no genome data is available
# Skipping 027s4729 as no genome data is available
# Skipping 024s5054 as no genome data is available
# Skipping 029s5135 as no genome data is available
# Skipping 082s5179 as no genome data is available
# Skipping 013s5137 as no genome data is available
# Skipping 037s5126 as no genome data is available
# Skipping 128s5123 as no genome data is available
# Skipping 094s4459 as no genome data is available
# Skipping 094s4486 as no genome data is available
# Skipping 073s4986 as no genome data is available
# Skipping 099s4124 as no genome data is available
# Skipping 024s4186 as no genome data is available
# Skipping 003s4142 as no genome data is available
# Skipping 073s4230 as no genome data is available
# Skipping 094s4295 as no genome data is available
# Skipping 109s4378 as no genome data is available
# Skipping 941s4377 as no genome data is available
# Skipping 941s4377 as no genome data is available
# Skipping 094s4460 as no genome data is available
# Skipping 116s4537 as no genome data is available
# Skipping 109s4471 as no genome data is available
# Skipping 003s4524 as no genome data is available
# Skipping 016s4583 as no genome data is available
# Skipping 016s4575 as no genome data is available
# Skipping 024s4622 as no genome data is available
# Skipping 137s4587 as no genome data is available
# Skipping 020s4619 as no genome data is available
# Skipping 021s4633 as no genome data is available
# Skipping 003s4644 as no genome data is available
# Skipping 003s4644 as no genome data is available
# Skipping 029s4652 as no genome data is available
# Skipping 029s4652 as no genome data is available
# Skipping 137s4631 as no genome data is available
# Skipping 041s4509 as no genome data is available
# Skipping 094s4649 as no genome data is available
# Skipping 016s4646 as no genome data is available
# Skipping 141s4711 as no genome data is available
# Skipping 141s4711 as no genome data is available
# Skipping 135s4723 as no genome data is available
# Skipping 016s4638 as no genome data is available
# Skipping 126s4743 as no genome data is available
# Skipping 073s4739 as no genome data is available
# Skipping 073s4739 as no genome data is available
# Skipping 127s4624 as no genome data is available
# Skipping 021s4744 as no genome data is available
# Skipping 137s4756 as no genome data is available
# Skipping 128s4745 as no genome data is available
# Skipping 067s4767 as no genome data is available
# Skipping 073s4777 as no genome data is available
# Skipping 073s4777 as no genome data is available
# Skipping 016s4688 as no genome data is available
# Skipping 072s4694 as no genome data is available
# Skipping 123s4780 as no genome data is available
# Skipping 141s4803 as no genome data is available
# Skipping 035s4784 as no genome data is available
# Skipping 070s4798 as no genome data is available
# Skipping 073s4762 as no genome data is available
# Skipping 073s4762 as no genome data is available
# Skipping 011s4827 as no genome data is available
# Skipping 073s4825 as no genome data is available
# Skipping 003s4839 as no genome data is available
# Skipping 022s4805 as no genome data is available
# Skipping 027s4804 as no genome data is available
# Skipping 003s4872 as no genome data is available
# Skipping 003s4872 as no genome data is available
# Skipping 137s4852 as no genome data is available
# Skipping 057s4888 as no genome data is available
# Skipping 072s4769 as no genome data is available
# Skipping 127s4843 as no genome data is available
# Skipping 128s4832 as no genome data is available
# Skipping 141s4819 as no genome data is available
# Skipping 153s4838 as no genome data is available
# Skipping 153s4838 as no genome data is available
# Skipping 072s4871 as no genome data is available
# Skipping 137s4815 as no genome data is available
# Skipping 137s4816 as no genome data is available
# Skipping 024s4905 as no genome data is available
# Skipping 024s4905 as no genome data is available
# Skipping 016s4902 as no genome data is available
# Skipping 016s4902 as no genome data is available
# Skipping 052s4885 as no genome data is available
# Skipping 003s4892 as no genome data is available
# Skipping 003s4892 as no genome data is available
# Skipping 011s4906 as no genome data is available
# Skipping 027s4919 as no genome data is available
# Skipping 141s4907 as no genome data is available
# Skipping 021s4924 as no genome data is available
# Skipping 037s4879 as no genome data is available
# Skipping 037s4879 as no genome data is available
# Skipping 051s4929 as no genome data is available
# Skipping 020s4920 as no genome data is available
# Skipping 020s4920 as no genome data is available
# Skipping 135s4954 as no genome data is available
# Skipping 027s4936 as no genome data is available
# Skipping 027s4938 as no genome data is available
# Skipping 009s0751 as no genome data is available
# Skipping 073s4986 as no genome data is available
# Skipping 073s4986 as no genome data is available
# Skipping 027s4966 as no genome data is available
# Skipping 127s4992 as no genome data is available
# Skipping 051s4980 as no genome data is available
# Skipping 022s5004 as no genome data is available
# Skipping 073s4995 as no genome data is available
# Skipping 021s2077 as no genome data is available
# Skipping 016s5032 as no genome data is available
# Skipping 005s5038 as no genome data is available
# Skipping 114s5047 as no genome data is available
# Skipping 024s5054 as no genome data is available
# Skipping 024s5054 as no genome data is available
# Skipping 127s5056 as no genome data is available
# Skipping 009s5037 as no genome data is available
# Skipping 128s5066 as no genome data is available
# Skipping 041s5082 as no genome data is available
# Skipping 041s5082 as no genome data is available
# Skipping 068s4968 as no genome data is available
# Skipping 016s5031 as no genome data is available
# Skipping 021s5129 as no genome data is available
# Skipping 021s5129 as no genome data is available
# Skipping 036s5149 as no genome data is available
# Skipping 041s5100 as no genome data is available
# Skipping 041s5100 as no genome data is available
# Skipping 041s5141 as no genome data is available
# Skipping 036s5112 as no genome data is available
# Skipping 021s4718 as no genome data is available
# Skipping 024s4674 as no genome data is available
# Skipping 067s5160 as no genome data is available
# Skipping 067s4728 as no genome data is available
# Skipping 135s4689 as no genome data is available
# Skipping 036s4714 as no genome data is available
# Skipping 036s5210 as no genome data is available
# Skipping 072s5207 as no genome data is available
# Skipping 007s5196 as no genome data is available
# Skipping 128s4671 as no genome data is available
# Skipping 941s4764 as no genome data is available
# Skipping 021s5237 as no genome data is available
# Skipping 029s5219 as no genome data is available
# Skipping 128s5123 as no genome data is available
# Skipping 128s5123 as no genome data is available
# Skipping 067s5212 as no genome data is available
# Skipping 036s5248 as no genome data is available
# Skipping 009s4741 as no genome data is available
# Skipping 082s5279 as no genome data is available
# Skipping 082s5278 as no genome data is available
# Skipping 033s5259 as no genome data is available
# Skipping 036s5283 as no genome data is available
# Skipping 041s5253 as no genome data is available
# Skipping 128s4742 as no genome data is available
# Skipping 135s5273 as no genome data is available
# Skipping 036s4878 as no genome data is available
# Skipping 024s5290 as no genome data is available
# Skipping 116s4898 as no genome data is available
# Skipping 003s5154 as no genome data is available
# Skipping 003s5165 as no genome data is available
# Skipping 003s5209 as no genome data is available
# Skipping 007s4911 as no genome data is available
# Skipping 007s5265 as no genome data is available
# Skipping 009s4958 as no genome data is available
# Skipping 051s5285 as no genome data is available
# Skipping 036s4899 as no genome data is available
# Skipping 009s4814 as no genome data is available
# Skipping 011s4949 as no genome data is available
# Skipping 041s4877 as no genome data is available
# Skipping 123s4904 as no genome data is available
# Skipping 094s4858 as no genome data is available
# Skipping 094s4858 as no genome data is available
# Skipping 033s5013 as no genome data is available
# Skipping 082s5014 as no genome data is available
# Skipping 016s5007 as no genome data is available
# Skipping 009s5125 as no genome data is available
# Skipping 032s4755 as no genome data is available
# Skipping 073s5023 as no genome data is available
# Skipping 073s5023 as no genome data is available
# Skipping 041s5078 as no genome data is available
# Skipping 041s5097 as no genome data is available
# Skipping 027s4729 as no genome data is available
# Skipping 070s5040 as no genome data is available
# Skipping 016s5057 as no genome data is available
# Skipping 029s4585 as no genome data is available
# Skipping 116s4732 as no genome data is available
# Skipping 009s5147 as no genome data is available
# Skipping 082s5179 as no genome data is available
# Skipping 013s5137 as no genome data is available
# Skipping 013s4985 as no genome data is available
# Skipping 072s4941 as no genome data is available
# Skipping 032s5263 as no genome data is available
# Skipping 070s4708 as no genome data is available
# Skipping 123s4806 as no genome data is available
# Skipping 941s4066 as no genome data is available
# Skipping 067s4113 as no genome data is available
# Skipping 024s4186 as no genome data is available
# Skipping 073s4230 as no genome data is available
# Skipping 032s4304 as no genome data is available
# Skipping 094s4460 as no genome data is available
# Skipping 116s4537 as no genome data is available
# Skipping 003s4524 as no genome data is available
# Skipping 016s4583 as no genome data is available
# Skipping 016s4575 as no genome data is available
# Skipping 024s4622 as no genome data is available
# Skipping 035s4085 as no genome data is available
# Skipping 057s4110 as no genome data is available
# Skipping 020s4619 as no genome data is available
# Skipping 029s4585 as no genome data is available
# Skipping 029s4585 as no genome data is available
# Skipping 137s4631 as no genome data is available
# Skipping 137s4632 as no genome data is available
# Skipping 094s4649 as no genome data is available
# Skipping 141s4711 as no genome data is available
# Skipping 141s4711 as no genome data is available
# Skipping 021s4718 as no genome data is available
# Skipping 016s4638 as no genome data is available
# Skipping 067s4728 as no genome data is available
# Skipping 067s4728 as no genome data is available
# Skipping 127s4624 as no genome data is available
# Skipping 116s4732 as no genome data is available
# Skipping 116s4732 as no genome data is available
# Skipping 137s4756 as no genome data is available
# Skipping 128s4586 as no genome data is available
# Skipping 067s4767 as no genome data is available
# Skipping 127s4765 as no genome data is available
# Skipping 016s4688 as no genome data is available
# Skipping 009s4741 as no genome data is available
# Skipping 009s4741 as no genome data is available
# Skipping 123s4806 as no genome data is available
# Skipping 123s4806 as no genome data is available
# Skipping 141s4803 as no genome data is available
# Skipping 070s4793 as no genome data is available
# Skipping 037s4750 as no genome data is available
# Skipping 073s4762 as no genome data is available
# Skipping 073s4762 as no genome data is available
# Skipping 035s4783 as no genome data is available
# Skipping 011s4845 as no genome data is available
# Skipping 003s4840 as no genome data is available
# Skipping 022s4805 as no genome data is available
# Skipping 027s4801 as no genome data is available
# Skipping 027s4804 as no genome data is available
# Skipping 037s4770 as no genome data is available
# Skipping 003s4872 as no genome data is available
# Skipping 137s4852 as no genome data is available
# Skipping 068s4859 as no genome data is available
# Skipping 073s4853 as no genome data is available
# Skipping 127s4844 as no genome data is available
# Skipping 128s4842 as no genome data is available
# Skipping 153s4838 as no genome data is available
# Skipping 126s4896 as no genome data is available
# Skipping 137s4815 as no genome data is available
# Skipping 137s4816 as no genome data is available
# Skipping 003s4900 as no genome data is available
# Skipping 016s4902 as no genome data is available
# Skipping 011s4912 as no genome data is available
# Skipping 003s4892 as no genome data is available
# Skipping 003s4892 as no genome data is available
# Skipping 011s4906 as no genome data is available
# Skipping 041s4877 as no genome data is available
# Skipping 041s4877 as no genome data is available
# Skipping 141s4907 as no genome data is available
# Skipping 021s4924 as no genome data is available
# Skipping 011s4893 as no genome data is available
# Skipping 011s4893 as no genome data is available
# Skipping 011s4949 as no genome data is available
# Skipping 051s4929 as no genome data is available
# Skipping 051s4929 as no genome data is available
# Skipping 022s4922 as no genome data is available
# Skipping 005s4910 as no genome data is available
# Skipping 016s4952 as no genome data is available
# Skipping 016s4952 as no genome data is available
# Skipping 009s4958 as no genome data is available
# Skipping 009s4958 as no genome data is available
# Skipping 027s4955 as no genome data is available
# Skipping 072s4941 as no genome data is available
# Skipping 072s4941 as no genome data is available
# Skipping 141s4976 as no genome data is available
# Skipping 073s5016 as no genome data is available
# Skipping 051s4980 as no genome data is available
# Skipping 051s5005 as no genome data is available
# Skipping 135s5015 as no genome data is available
# Skipping 135s5015 as no genome data is available
# Skipping 099s4994 as no genome data is available
# Skipping 021s2077 as no genome data is available
# Skipping 005s5038 as no genome data is available
# Skipping 024s5054 as no genome data is available
# Skipping 127s5056 as no genome data is available
# Skipping 009s5037 as no genome data is available
# Skipping 009s5037 as no genome data is available
# Skipping 041s5082 as no genome data is available
# Skipping 020s5140 as no genome data is available
# Skipping 016s5031 as no genome data is available
# Skipping 016s5031 as no genome data is available
# Skipping 021s5129 as no genome data is available
# Skipping 067s5159 as no genome data is available
# Skipping 041s5100 as no genome data is available
# Skipping 041s5141 as no genome data is available
# Skipping 109s4380 as no genome data is available
# Skipping 021s5177 as no genome data is available
# Skipping 024s4674 as no genome data is available
# Skipping 068s5146 as no genome data is available
# Skipping 073s4739 as no genome data is available
# Skipping 941s5193 as no genome data is available
# Skipping 041s5204 as no genome data is available
# Skipping 036s4714 as no genome data is available
# Skipping 073s5167 as no genome data is available
# Skipping 135s4723 as no genome data is available
# Skipping 067s5205 as no genome data is available
# Skipping 135s4722 as no genome data is available
# Skipping 072s4769 as no genome data is available
# Skipping 021s5237 as no genome data is available
# Skipping 033s5235 as no genome data is available
# Skipping 128s5123 as no genome data is available
# Skipping 041s5244 as no genome data is available
# Skipping 153s5267 as no genome data is available
# Skipping 041s4876 as no genome data is available
# Skipping 016s5251 as no genome data is available
# Skipping 032s4823 as no genome data is available
# Skipping 033s5259 as no genome data is available
# Skipping 036s4894 as no genome data is available
# Skipping 036s5283 as no genome data is available
# Skipping 067s4782 as no genome data is available
# Skipping 073s4777 as no genome data is available
# Skipping 128s4772 as no genome data is available
# Skipping 135s5275 as no genome data is available
# Skipping 135s4863 as no genome data is available
# Skipping 036s4878 as no genome data is available
# Skipping 082s5282 as no genome data is available
# Skipping 024s5290 as no genome data is available
# Skipping 003s5130 as no genome data is available
# Skipping 003s5154 as no genome data is available
# Skipping 003s5165 as no genome data is available
# Skipping 023s4796 as no genome data is available
# Skipping 041s4989 as no genome data is available
# Skipping 036s4899 as no genome data is available
# Skipping 021s4744 as no genome data is available
# Skipping 032s5289 as no genome data is available
# Skipping 123s4904 as no genome data is available
# Skipping 051s5293 as no genome data is available
# Skipping 033s5013 as no genome data is available
# Skipping 016s5007 as no genome data is available
# Skipping 009s5224 as no genome data is available
# Skipping 009s4903 as no genome data is available
# Skipping 032s4755 as no genome data is available
# Skipping 073s5023 as no genome data is available
# Skipping 073s5023 as no genome data is available
# Skipping 041s5078 as no genome data is available
# Skipping 128s5066 as no genome data is available
# Skipping 098s4002 as no genome data is available
# Skipping 016s5057 as no genome data is available
# Skipping 941s5124 as no genome data is available
# Skipping 094s4630 as no genome data is available
# Skipping 029s4652 as no genome data is available
# Skipping 127s4992 as no genome data is available
# Skipping 041s5131 as no genome data is available
# Skipping 009s5147 as no genome data is available
# Skipping 013s4985 as no genome data is available
# Skipping 003s4644 as no genome data is available
# Skipping 135s5113 as no genome data is available
# Skipping 022s5004 as no genome data is available
# Skipping 094s4858 as no genome data is available
# Skipping 094s4486 as no genome data is available
# Skipping 014s4068 as no genome data is available
# Skipping 041s4083 as no genome data is available
# Skipping 067s4113 as no genome data is available
# Skipping 023s4035 as no genome data is available
# Skipping 032s4304 as no genome data is available
# Skipping 123s4362 as no genome data is available
# Skipping 003s4373 as no genome data is available
# Skipping 072s4606 as no genome data is available
# Skipping 035s4085 as no genome data is available
# Skipping 057s4110 as no genome data is available
# Skipping 137s4623 as no genome data is available
# Skipping 126s4675 as no genome data is available
# Skipping 029s4585 as no genome data is available
# Skipping 128s4671 as no genome data is available
# Skipping 137s4632 as no genome data is available
# Skipping 037s4706 as no genome data is available
# Skipping 037s4706 as no genome data is available
# Skipping 041s4509 as no genome data is available
# Skipping 135s4722 as no genome data is available
# Skipping 135s4722 as no genome data is available
# Skipping 021s4718 as no genome data is available
# Skipping 070s4719 as no genome data is available
# Skipping 041s4720 as no genome data is available
# Skipping 041s4720 as no genome data is available
# Skipping 067s4728 as no genome data is available
# Skipping 127s4749 as no genome data is available
# Skipping 116s4732 as no genome data is available
# Skipping 073s4748 as no genome data is available
# Skipping 128s4586 as no genome data is available
# Skipping 128s4586 as no genome data is available
# Skipping 073s4795 as no genome data is available
# Skipping 127s4765 as no genome data is available
# Skipping 128s4772 as no genome data is available
# Skipping 128s4772 as no genome data is available
# Skipping 009s4741 as no genome data is available
# Skipping 128s4792 as no genome data is available
# Skipping 123s4806 as no genome data is available
# Skipping 070s4793 as no genome data is available
# Skipping 037s4750 as no genome data is available
# Skipping 037s4750 as no genome data is available
# Skipping 009s4814 as no genome data is available
# Skipping 035s4783 as no genome data is available
# Skipping 011s4845 as no genome data is available
# Skipping 003s4840 as no genome data is available
# Skipping 027s4801 as no genome data is available
# Skipping 032s4823 as no genome data is available
# Skipping 032s4823 as no genome data is available
# Skipping 037s4770 as no genome data is available
# Skipping 037s4770 as no genome data is available
# Skipping 126s4891 as no genome data is available
# Skipping 067s4782 as no genome data is available
# Skipping 067s4782 as no genome data is available
# Skipping 068s4859 as no genome data is available
# Skipping 073s4853 as no genome data is available
# Skipping 073s4853 as no genome data is available
# Skipping 127s4844 as no genome data is available
# Skipping 135s4863 as no genome data is available
# Skipping 135s4863 as no genome data is available
# Skipping 027s4873 as no genome data is available
# Skipping 126s4896 as no genome data is available
# Skipping 057s4897 as no genome data is available
# Skipping 027s4869 as no genome data is available
# Skipping 003s4900 as no genome data is available
# Skipping 003s4900 as no genome data is available
# Skipping 023s4796 as no genome data is available
# Skipping 023s4796 as no genome data is available
# Skipping 011s4912 as no genome data is available
# Skipping 011s4912 as no genome data is available
# Skipping 007s4911 as no genome data is available
# Skipping 127s4928 as no genome data is available
# Skipping 041s4877 as no genome data is available
# Skipping 011s4893 as no genome data is available
# Skipping 011s4893 as no genome data is available
# Skipping 009s4903 as no genome data is available
# Skipping 009s4903 as no genome data is available
# Skipping 123s4904 as no genome data is available
# Skipping 011s4949 as no genome data is available
# Skipping 027s4943 as no genome data is available
# Skipping 022s4922 as no genome data is available
# Skipping 005s4910 as no genome data is available
# Skipping 016s4952 as no genome data is available
# Skipping 016s4952 as no genome data is available
# Skipping 009s4958 as no genome data is available
# Skipping 072s4941 as no genome data is available
# Skipping 141s4976 as no genome data is available
# Skipping 041s4974 as no genome data is available
# Skipping 041s4974 as no genome data is available
# Skipping 073s5016 as no genome data is available
# Skipping 052s4945 as no genome data is available
# Skipping 051s5005 as no genome data is available
# Skipping 033s5017 as no genome data is available
# Skipping 033s5017 as no genome data is available
# Skipping 135s5015 as no genome data is available
# Skipping 135s5015 as no genome data is available
# Skipping 099s4994 as no genome data is available
# Skipping 070s5040 as no genome data is available
# Skipping 020s5140 as no genome data is available
# Skipping 016s5057 as no genome data is available
# Skipping 067s5159 as no genome data is available
# Skipping 041s5131 as no genome data is available
# Skipping 041s5131 as no genome data is available
# Skipping 109s4380 as no genome data is available
# Skipping 016s4646 as no genome data is available
# Skipping 021s5177 as no genome data is available
# Skipping 068s5146 as no genome data is available
# Skipping 082s5184 as no genome data is available
# Skipping 941s5193 as no genome data is available
# Skipping 021s5194 as no genome data is available
# Skipping 041s5204 as no genome data is available
# Skipping 036s4736 as no genome data is available
# Skipping 035s4785 as no genome data is available
# Skipping 073s5167 as no genome data is available
# Skipping 135s5113 as no genome data is available
# Skipping 135s5113 as no genome data is available
# Skipping 007s5196 as no genome data is available
# Skipping 067s5205 as no genome data is available
# Skipping 072s4769 as no genome data is available
# Skipping 029s5158 as no genome data is available
# Skipping 033s5235 as no genome data is available
# Skipping 068s5206 as no genome data is available
# Skipping 041s5244 as no genome data is available
# Skipping 153s5261 as no genome data is available
# Skipping 153s5267 as no genome data is available
# Skipping 128s4774 as no genome data is available
# Skipping 041s4876 as no genome data is available
# Skipping 016s5251 as no genome data is available
# Skipping 023s5241 as no genome data is available
# Skipping 035s4784 as no genome data is available
# Skipping 036s4894 as no genome data is available
# Skipping 116s4855 as no genome data is available
# Skipping 135s5275 as no genome data is available
# Skipping 114s5234 as no genome data is available
# Skipping 082s5282 as no genome data is available
# Skipping 003s5130 as no genome data is available
# Skipping 003s5130 as no genome data is available
# Skipping 029s5166 as no genome data is available
# Skipping 003s5187 as no genome data is available
# Skipping 051s5294 as no genome data is available
# Skipping 041s4989 as no genome data is available
# Skipping 021s4744 as no genome data is available
# Skipping 032s5289 as no genome data is available
# Skipping 094s4858 as no genome data is available
# Skipping 135s4954 as no genome data is available
# Skipping 051s5293 as no genome data is available
# Skipping 082s5029 as no genome data is available
# Skipping 009s5224 as no genome data is available
# Skipping 013s5071 as no genome data is available
# Skipping 041s5026 as no genome data is available
# Skipping 032s4921 as no genome data is available
# Skipping 051s4929 as no genome data is available
# Skipping 128s5066 as no genome data is available
# Skipping 016s5032 as no genome data is available
# Skipping 016s5031 as no genome data is available
# Skipping 033s5087 as no genome data is available
# Skipping 009s5147 as no genome data is available
# Skipping 941s5124 as no genome data is available
# Skipping 094s4630 as no genome data is available
# Skipping 114s5047 as no genome data is available
# Skipping 009s5176 as no genome data is available
# Skipping 072s5207 as no genome data is available
# Skipping 009s5037 as no genome data is available
# Skipping 072s4871 as no genome data is available
# Skipping 022s5004 as no genome data is available
# Skipping 070s4708 as no genome data is available
# Skipping 094s4737 as no genome data is available
# Skipping 094s4737 as no genome data is available
# Skipping 014s4068 as no genome data is available
# Skipping 041s4083 as no genome data is available
# Skipping 023s4035 as no genome data is available
# Skipping 023s4035 as no genome data is available
# Skipping 153s4165 as no genome data is available
# Skipping 137s4227 as no genome data is available
# Skipping 123s4362 as no genome data is available
# Skipping 041s4375 as no genome data is available
# Skipping 109s4380 as no genome data is available
# Skipping 003s4373 as no genome data is available
# Skipping 041s4495 as no genome data is available
# Skipping 072s4606 as no genome data is available
# Skipping 035s4085 as no genome data is available
# Skipping 016s4601 as no genome data is available
# Skipping 137s4623 as no genome data is available
# Skipping 109s4594 as no genome data is available
# Skipping 109s4594 as no genome data is available
# Skipping 126s4675 as no genome data is available
# Skipping 024s4674 as no genome data is available
# Skipping 135s4689 as no genome data is available
# Skipping 128s4671 as no genome data is available
# Skipping 137s4678 as no genome data is available
# Skipping 135s4710 as no genome data is available
# Skipping 037s4706 as no genome data is available
# Skipping 037s4706 as no genome data is available
# Skipping 126s4712 as no genome data is available
# Skipping 135s4722 as no genome data is available
# Skipping 070s4719 as no genome data is available
# Skipping 041s4720 as no genome data is available
# Skipping 041s4720 as no genome data is available
# Skipping 941s4764 as no genome data is available
# Skipping 127s4749 as no genome data is available
# Skipping 128s4742 as no genome data is available
# Skipping 073s4748 as no genome data is available
# Skipping 027s4757 as no genome data is available
# Skipping 073s4795 as no genome data is available
# Skipping 073s4795 as no genome data is available
# Skipping 127s4765 as no genome data is available
# Skipping 128s4772 as no genome data is available
# Skipping 009s4741 as no genome data is available
# Skipping 128s4792 as no genome data is available
# Skipping 128s4774 as no genome data is available
# Skipping 128s4774 as no genome data is available
# Skipping 070s4793 as no genome data is available
# Skipping 032s4755 as no genome data is available
# Skipping 009s4814 as no genome data is available
# Skipping 021s4857 as no genome data is available
# Skipping 021s4857 as no genome data is available
# Skipping 027s4802 as no genome data is available
# Skipping 032s4823 as no genome data is available
# Skipping 041s4874 as no genome data is available
# Skipping 041s4874 as no genome data is available
# Skipping 041s4874 as no genome data is available
# Skipping 116s4855 as no genome data is available
# Skipping 116s4855 as no genome data is available
# Skipping 126s4891 as no genome data is available
# Skipping 052s4807 as no genome data is available
# Skipping 067s4782 as no genome data is available
# Skipping 070s4856 as no genome data is available
# Skipping 070s4856 as no genome data is available
# Skipping 127s4844 as no genome data is available
# Skipping 135s4863 as no genome data is available
# Skipping 027s4873 as no genome data is available
# Skipping 116s4898 as no genome data is available
# Skipping 057s4897 as no genome data is available
# Skipping 041s4876 as no genome data is available
# Skipping 027s4869 as no genome data is available
# Skipping 016s4887 as no genome data is available
# Skipping 016s4887 as no genome data is available
# Skipping 023s4796 as no genome data is available
# Skipping 057s4909 as no genome data is available
# Skipping 007s4911 as no genome data is available
# Skipping 007s4911 as no genome data is available
# Skipping 127s4928 as no genome data is available
# Skipping 041s4877 as no genome data is available
# Skipping 068s4914 as no genome data is available
# Skipping 032s4921 as no genome data is available
# Skipping 032s4921 as no genome data is available
# Skipping 009s4903 as no genome data is available
# Skipping 123s4904 as no genome data is available
# Skipping 127s4940 as no genome data is available
# Skipping 027s4943 as no genome data is available
# Skipping 067s4918 as no genome data is available
# Skipping 067s4918 as no genome data is available
# Skipping 005s4910 as no genome data is available
# Skipping 016s4951 as no genome data is available
# Skipping 016s4951 as no genome data is available
# Skipping 016s4963 as no genome data is available
# Skipping 041s4989 as no genome data is available
# Skipping 041s4974 as no genome data is available
# Skipping 041s4974 as no genome data is available
# Skipping 009s5000 as no genome data is available
# Skipping 009s5000 as no genome data is available
# Skipping 082s5014 as no genome data is available
# Skipping 052s4945 as no genome data is available
# Skipping 051s5005 as no genome data is available
# Skipping 051s5005 as no genome data is available
# Skipping 033s5013 as no genome data is available
# Skipping 033s5017 as no genome data is available
# Skipping 033s5017 as no genome data is available
# Skipping 127s5028 as no genome data is available
# Skipping 016s5007 as no genome data is available
# Skipping 052s4944 as no genome data is available
# Skipping 016s5032 as no genome data is available
# Skipping 016s5032 as no genome data is available
# Skipping 070s5040 as no genome data is available
# Skipping 009s5027 as no genome data is available
# Skipping 009s5027 as no genome data is available
# Skipping 027s4964 as no genome data is available
# Skipping 073s5090 as no genome data is available
# Skipping 033s5087 as no genome data is available
# Skipping 033s5087 as no genome data is available
# Skipping 041s5078 as no genome data is available
# Skipping 941s5124 as no genome data is available
# Skipping 016s5057 as no genome data is available
# Skipping 021s5099 as no genome data is available
# Skipping 041s5097 as no genome data is available
# Skipping 041s5131 as no genome data is available
# Skipping 041s5173 as no genome data is available
# Skipping 016s4646 as no genome data is available
# Skipping 023s5120 as no genome data is available
# Skipping 082s5184 as no genome data is available
# Skipping 094s4649 as no genome data is available
# Skipping 021s5194 as no genome data is available
# Skipping 036s4538 as no genome data is available
# Skipping 036s4736 as no genome data is available
# Skipping 033s5198 as no genome data is available
# Skipping 035s4785 as no genome data is available
# Skipping 135s5113 as no genome data is available
# Skipping 020s5203 as no genome data is available
# Skipping 067s4767 as no genome data is available
# Skipping 135s4723 as no genome data is available
# Skipping 021s5236 as no genome data is available
# Skipping 029s5158 as no genome data is available
# Skipping 068s5206 as no genome data is available
# Skipping 011s4827 as no genome data is available
# Skipping 153s5261 as no genome data is available
# Skipping 135s5269 as no genome data is available
# Skipping 011s4845 as no genome data is available
# Skipping 023s5241 as no genome data is available
# Skipping 032s5263 as no genome data is available
# Skipping 035s4784 as no genome data is available
# Skipping 036s5271 as no genome data is available
# Skipping 037s4750 as no genome data is available
# Skipping 128s4586 as no genome data is available
# Skipping 128s4832 as no genome data is available
# Skipping 073s5227 as no genome data is available
# Skipping 114s5234 as no genome data is available
# Skipping 036s4820 as no genome data is available
# Skipping 011s4912 as no genome data is available
# Skipping 016s4638 as no genome data is available
# Skipping 073s4853 as no genome data is available
# Skipping 003s5150 as no genome data is available
# Skipping 029s5166 as no genome data is available
# Skipping 003s5187 as no genome data is available
# Skipping 022s4922 as no genome data is available
# Skipping 051s5294 as no genome data is available
# Skipping 128s4842 as no genome data is available
# Skipping 003s4900 as no genome data is available
# Skipping 035s4783 as no genome data is available
# Skipping 123s4780 as no genome data is available
# Skipping 135s4954 as no genome data is available
# Skipping 082s5029 as no genome data is available
# Skipping 009s5252 as no genome data is available
# Skipping 013s5071 as no genome data is available
# Skipping 041s5026 as no genome data is available
# Skipping 036s5063 as no genome data is available
# Skipping 009s5125 as no genome data is available
# Skipping 041s5141 as no genome data is available
# Skipping 003s5130 as no genome data is available
# Skipping 009s5147 as no genome data is available
# Skipping 037s4770 as no genome data is available
# Skipping 114s5047 as no genome data is available
# Skipping 029s5135 as no genome data is available
# Skipping 009s5176 as no genome data is available
# Skipping 072s5207 as no genome data is available
# Skipping 037s5126 as no genome data is available
# Skipping 072s4871 as no genome data is available
# Skipping 073s4825 as no genome data is available
# Skipping 094s4459 as no genome data is available
# Skipping 094s4630 as no genome data is available
# Skipping 094s4630 as no genome data is available
# Found 410 subjects with MR data

# %%
# create a bids dataset in data/mri
# folder structure should be data/mri/adni_thesis/sub-<subject_id>/ses-<session_id>

if not os.path.exists(mri_bids_path):
    os.makedirs(mri_bids_path)

for subject_id, filepath in files_per_subject.items():
    file_splits = filepath.split('/')

    adni_index = file_splits.index('ADNI')

    subject_id_clean = subject_id
    session_id =  clean_id(file_splits[adni_index + 3])

    folder = f'{mri_bids_path}/sub-{subject_id}/ses-{session_id}/anat'
    if not os.path.exists(folder):
        os.makedirs(folder)

    new_file = f'{folder}/sub-{subject_id}_ses-{session_id}_T1w.nii'
    os.rename(filepath, new_file)

print("Done, created BIDS dataset")
# Out:
# Done, created BIDS dataset

# %%
# get all subject ids in the bids dataset
bids_subjects = glob.glob(f'{mri_bids_path}/sub-*')
bids_subjects = [os.path.basename(subject).replace("sub-","") for subject in bids_subjects]
print(f"Found {len(bids_subjects)} subjects in BIDS dataset")
# Out:
# Found 410 subjects in BIDS dataset

# %%
# write list of subjects to dataset folder
with open(f"{dataset_base_path}/subjects.txt", "w") as f:
    for subject in bids_subjects:
        f.write(f"{subject}\n")

# %% [markdown]
# ## Create batch file for fastsurfer

# %%
# find all subjects not already processed
processed_folders = glob.glob(f"{mri_fastsurfer_out}/*")
processed_subjects = [processed_folder.split("/")[-1] for processed_folder in processed_folders]

# move all unused processed files to tmp folder
#for processed_file, processed_subject in zip(processed_folders, processed_subjects):
#    if processed_subject not in genome_subjects:
#        os.rename(processed_file, f"{mri_fastsurfer_out}_temp/{processed_subject}")

# %%
# fastsurfer batchfile format is as follows:
# <subject-id>=<path-to-mr-file>

mr_files = glob.glob(f'{mri_bids_path}/**/*.nii', recursive=True)
docker_filepath = "/data"

with open(f"{mri_bids_path}/fastsurfer_batch.txt", "w") as f:
    for filepath in mr_files:
        # replace current filesystem path with docker path
        docker_file = filepath.replace(mri_bids_path, docker_filepath)
        file_splits = docker_file.split('/')
        subject_id = clean_id(file_splits[2].replace("sub-", ""))
        if subject_id in processed_subjects:
            continue
        f.write(f"{subject_id}={docker_file}\n")

# %%
# Run preprocessing pipeline
#! smriprep-docker ./data/mri/adni_thesis ./data_processed/mri participant --fs-license-file ./license.txt --ncpus 4 --skull-strip-mode force

# %%
# create fastsurfer output directory
if not os.path.exists(mri_fastsurfer_out):
    os.makedirs(mri_fastsurfer_out)

# %%
# !docker run --privileged --gpus all -v /media/jfallmann/T9/University/master_thesis/dataset/mri/bids:/data -v /media/jfallmann/T9/University/master_thesis/dataset/mri/processed:/output -v /media/jfallmann/T9/University/master_thesis/license:/fs_license --entrypoint "/fastsurfer/brun_fastsurfer.sh" --rm --user $(id -u):$(id -g) deepmi/fastsurfer:latest --fs_license /fs_license/license.txt --subject_list /data/fastsurfer_batch.txt --sd /output --parallel --3T --seg_only --no_cereb --no_hypothal
# Out:
# /fastsurfer/brun_fastsurfer.sh --fs_license /fs_license/license.txt --subject_list /data/fastsurfer_batch.txt --sd /output --parallel --3T --seg_only --no_cereb --no_hypothal
# Tue, 07 Jan 2025 13:30:00 +0000
#
# INFO: run_fastsurfer not explicitly specified, using $FASTSURFER_HOME/run_fastsurfer.sh.
# 098s4050=/data/sub-098s4050/ses-201105271516560/anat/sub-098s4050_ses-201105271516560_T1w.nii 011s4075=/data/sub-011s4075/ses-201206221215290/anat/sub-011s4075_ses-201206221215290_T1w.nii 041s4051=/data/sub-041s4051/ses-201207121118550/anat/sub-041s4051_ses-201207121118550_T1w.nii 068s4134=/data/sub-068s4134/ses-201210151304380/anat/sub-068s4134_ses-201210151304380_T1w.nii 123s4127=/data/sub-123s4127/ses-201208030941490/anat/sub-123s4127_ses-201208030941490_T1w.nii 005s4168=/data/sub-005s4168/ses-201209060947300/anat/sub-005s4168_ses-201209060947300_T1w.nii 023s4122=/data/sub-023s4122/ses-201303051114060/anat/sub-023s4122_ses-201303051114060_T1w.nii 023s4115=/data/sub-023s4115/ses-201210021043050/anat/sub-023s4115_ses-201210021043050_T1w.nii 037s4146=/data/sub-037s4146/ses-201209191400510/anat/sub-037s4146_ses-201209191400510_T1w.nii 127s4240=/data/sub-127s4240/ses-201209251419310/anat/sub-127s4240_ses-201209251419310_T1w.nii 073s4311=/data/sub-073s4311/ses-201210151150390/anat/sub-073s4311_ses-201210151150390_T1w.nii 011s4278=/data/sub-011s4278/ses-201210251149410/anat/sub-011s4278_ses-201210251149410_T1w.nii 003s4288=/data/sub-003s4288/ses-201211010924190/anat/sub-003s4288_ses-201211010924190_T1w.nii 153s4297=/data/sub-153s4297/ses-201110310925210/anat/sub-153s4297_ses-201110310925210_T1w.nii 029s4307=/data/sub-029s4307/ses-201302141348210/anat/sub-029s4307_ses-201302141348210_T1w.nii 073s4393=/data/sub-073s4393/ses-201211281030330/anat/sub-073s4393_ses-201211281030330_T1w.nii 007s4387=/data/sub-007s4387/ses-201301211307270/anat/sub-007s4387_ses-201301211307270_T1w.nii 009s4359=/data/sub-009s4359/ses-201302131057010/anat/sub-009s4359_ses-201302131057010_T1w.nii 141s4423=/data/sub-141s4423/ses-201112201416050/anat/sub-141s4423_ses-201112201416050_T1w.nii 068s4424=/data/sub-068s4424/ses-201112231355220/anat/sub-068s4424_ses-201112231355220_T1w.nii 141s4456=/data/sub-141s4456/ses-201201170945340/anat/sub-141s4456_ses-201201170945340_T1w.nii 116s4453=/data/sub-116s4453/ses-201301161110340/anat/sub-116s4453_ses-201301161110340_T1w.nii 137s4466=/data/sub-137s4466/ses-201303011445310/anat/sub-137s4466_ses-201303011445310_T1w.nii 126s4507=/data/sub-126s4507/ses-201202031005260/anat/sub-126s4507_ses-201202031005260_T1w.nii 007s4516=/data/sub-007s4516/ses-201303131230280/anat/sub-007s4516_ses-201303131230280_T1w.nii 029s4385=/data/sub-029s4385/ses-201303051514580/anat/sub-029s4385_ses-201303051514580_T1w.nii 128s4571=/data/sub-128s4571/ses-201306191711580/anat/sub-128s4571_ses-201306191711580_T1w.nii 109s4531=/data/sub-109s4531/ses-201303251311530/anat/sub-109s4531_ses-201303251311530_T1w.nii 007s4620=/data/sub-007s4620/ses-201304151230160/anat/sub-007s4620_ses-201304151230160_T1w.nii
# Version: 2.3.3+bd65b36
# Tue Jan  7 13:30:01 UTC 2025
#
# python3.10 -s /fastsurfer/FastSurferCNN/run_prediction.py --t1 /data/sub-098s4050/ses-201105271516560/anat/sub-098s4050_ses-201105271516560_T1w.nii --asegdkt_segfile /output/098s4050/mri/aparc.DKTatlas+aseg.deep.mgz --conformed_name /output/098s4050/mri/orig.mgz --brainmask_name /output/098s4050/mri/mask.mgz --aseg_name /output/098s4050/mri/aseg.auto_noCCseg.mgz --sid 098s4050 --seg_log /output/098s4050/scripts/deep-seg.log --vox_size min --batch_size 1 --viewagg_device auto --device auto --sd /output
# [INFO: run_prediction.py:  648]: Checking or downloading default checkpoints ...
# [INFO: common.py:  827]: Single subject with absolute file path for input.
# [INFO: common.py:  885]: Analyzing single subject /data/sub-098s4050/ses-201105271516560/anat/sub-098s4050_ses-201105271516560_T1w.nii
# [INFO: common.py:  986]: Output will be stored in Subjects Directory: /output
# [INFO: common.py:  114]: Using device: cuda
# [INFO: common.py:  114]: Using viewagg_device: cuda
# [INFO: run_prediction.py:  245]: Running view aggregation on cuda
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_coronal_v2.0.0.pkl
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_sagittal_v2.0.0.pkl
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_axial_v2.0.0.pkl
# [INFO: run_prediction.py:  324]: Successfully loaded image from /data/sub-098s4050/ses-201105271516560/anat/sub-098s4050_ses-201105271516560_T1w.nii.
# [INFO: run_prediction.py:  441]: Output image directory /output/098s4050/mri/orig does not exist. Creating it now...
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/098s4050/mri/orig/001.mgz.
# The input image is not conformed.
# A min-conformed image must satisfy the following criteria:
#  - Number of Dimensions 3        : True
#  - Dimensions 256x256x256        : BUT image dimensions (196, 256, 256)
#  - Voxel Size 1.0x1.0x1.0        : BUT image 1.2x1.0547x1.0547
#  - Orientation LIA               : BUT strict: [[ 1.19e+00 -6.85e-05 1.40e-01] [-4.90e-02 1.00e+00 3.23e-01] [-1.51e-01 -3.26e-01 9.94e-01]]
#  - Dtype uint8                   : BUT dtype >f4
# [INFO: run_prediction.py:  337]: Conforming image
# (1.0, 1.0, 1.0)
# Input:    min: 0.0  max: 13125.15625
# rescale:  min: 0.0  max: 7599.46533203125  scale: 0.033554992207832264
# Output:   min: 0.0  max: 255.0
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/098s4050/mri/orig.mgz.
# [INFO: run_prediction.py:  400]: Run coronal prediction
# [INFO: dataset.py:   78]: Loading Coronal with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:06<00:00, 41.88batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for coronal successful
# [INFO: inference.py:  468]: Coronal inference on /data/sub-098s4050/ses-201105271516560/anat/sub-098s4050_ses-201105271516560_T1w.nii finished in 6.1149 seconds
# [INFO: run_prediction.py:  400]: Run sagittal prediction
# [INFO: dataset.py:   69]: Loading Sagittal with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:06<00:00, 40.97batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for sagittal successful
# [INFO: inference.py:  468]: Sagittal inference on /data/sub-098s4050/ses-201105271516560/anat/sub-098s4050_ses-201105271516560_T1w.nii finished in 6.2500 seconds
# [INFO: run_prediction.py:  400]: Run axial prediction
# [INFO: dataset.py:   74]: Loading Axial with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:05<00:00, 42.98batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for axial successful
# [INFO: inference.py:  468]: Axial inference on /data/sub-098s4050/ses-201105271516560/anat/sub-098s4050_ses-201105271516560_T1w.nii finished in 5.9569 seconds
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/098s4050/mri/aparc.DKTatlas+aseg.deep.mgz.
# [INFO: run_prediction.py:  725]: Creating brainmask based on segmentation...
# Creating dilated mask ...
# Frontal region special treatment:  20815
#   Found 1 connected component(s)!
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/098s4050/mri/mask.mgz.
# [INFO: run_prediction.py:  744]: Creating aseg based on segmentation...
# Reducing to aseg ...
# FlipWM: rh 0 and lh 0 flipped.
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/098s4050/mri/aseg.auto_noCCseg.mgz.
# [INFO: run_prediction.py:  763]: Running volume-based QC check on segmentation...
# Checking total volume ...
# Voxel size in mm3: 1.0
# Total segmentation volume in liter: 1.16
# INFO: Running N4 bias-field correction
# python3.10 -s /fastsurfer/recon_surf/N4_bias_correct.py --in /output/098s4050/mri/orig.mgz --rescale /output/098s4050/mri/orig_nu.mgz --aseg /output/098s4050/mri/aparc.DKTatlas+aseg.deep.mgz --threads 1
#
# N4 Bias Correction Parameters:
#
# - verbosity: -1
# - input volume: /output/098s4050/mri/orig.mgz
# - output volume: do not save
# - rescaled volume: /output/098s4050/mri/orig_nu.mgz
# - mask: default (>0)
# - aseg: /output/098s4050/mri/aparc.DKTatlas+aseg.deep.mgz
# - shrink factor: 4
# - number fitting levels: 4
# - number iterations: 50
# - convergence threshold: 0.0
# - threads: 1
# read MGZ (FreeSurfer) image via nibabel...
# executing N4 correction ...
# - mask: ones (default)
# normalize WM to 105.0 (find WM from aseg)
# read MGZ (FreeSurfer) image via nibabel...
# - source white matter intensity: 43.13
# - m: 2.3647
# converting rescaled to UCHAR
# writing PosixPath: /output/098s4050/mri/orig_nu.mgz
# write MGZ (FreeSurfer) image via nibabel...
# python3.10 -s /fastsurfer/FastSurferCNN/segstats.py --segfile /output/098s4050/mri/aparc.DKTatlas+aseg.deep.mgz --segstatsfile /output/098s4050/stats/aseg+DKT.stats --normfile /output/098s4050/mri/orig_nu.mgz --threads 1 --empty --excludeid 0 --sd /output --sid 098s4050 --ids 2 4 5 7 8 10 11 12 13 14 15 16 17 18 24 26 28 31 41 43 44 46 47 49 50 51 52 53 54 58 60 63 77 251 252 253 254 255 1002 1003 1005 1006 1007 1008 1009 1010 1011 1012 1013 1014 1015 1016 1017 1018 1019 1020 1021 1022 1023 1024 1025 1026 1027 1028 1029 1030 1031 1034 1035 2002 2003 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031 2034 2035 --lut /fastsurfer/FastSurferCNN/config/FreeSurferColorLUT.txt measures --compute Mask(/output/098s4050/mri/mask.mgz) BrainSeg BrainSegNotVent SupraTentorial SupraTentorialNotVent SubCortGray rhCerebralWhiteMatter lhCerebralWhiteMatter CerebralWhiteMatter
# None of the labels [251, 252, 253, 254, 255] for merged label 10007 exist in the segmentation.
# Partial volume stats for 100 labels written to /output/098s4050/stats/aseg+DKT.stats.
# Calculation took 10.33 seconds using up to 1 threads.
# Version: 2.3.3+bd65b36
# Tue Jan  7 13:33:10 UTC 2025
#
# python3.10 -s /fastsurfer/FastSurferCNN/run_prediction.py --t1 /data/sub-011s4075/ses-201206221215290/anat/sub-011s4075_ses-201206221215290_T1w.nii --asegdkt_segfile /output/011s4075/mri/aparc.DKTatlas+aseg.deep.mgz --conformed_name /output/011s4075/mri/orig.mgz --brainmask_name /output/011s4075/mri/mask.mgz --aseg_name /output/011s4075/mri/aseg.auto_noCCseg.mgz --sid 011s4075 --seg_log /output/011s4075/scripts/deep-seg.log --vox_size min --batch_size 1 --viewagg_device auto --device auto --sd /output
# [INFO: run_prediction.py:  648]: Checking or downloading default checkpoints ...
# [INFO: common.py:  827]: Single subject with absolute file path for input.
# [INFO: common.py:  885]: Analyzing single subject /data/sub-011s4075/ses-201206221215290/anat/sub-011s4075_ses-201206221215290_T1w.nii
# [INFO: common.py:  986]: Output will be stored in Subjects Directory: /output
# [INFO: common.py:  114]: Using device: cuda
# [INFO: common.py:  114]: Using viewagg_device: cuda
# [INFO: run_prediction.py:  245]: Running view aggregation on cuda
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_coronal_v2.0.0.pkl
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_sagittal_v2.0.0.pkl
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_axial_v2.0.0.pkl
# [INFO: run_prediction.py:  324]: Successfully loaded image from /data/sub-011s4075/ses-201206221215290/anat/sub-011s4075_ses-201206221215290_T1w.nii.
# [INFO: run_prediction.py:  441]: Output image directory /output/011s4075/mri/orig does not exist. Creating it now...
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/011s4075/mri/orig/001.mgz.
# The input image is not conformed.
# A min-conformed image must satisfy the following criteria:
#  - Number of Dimensions 3        : True
#  - Dimensions 256x256x256        : BUT image dimensions (176, 240, 256)
#  - Voxel Size 1.0x1.0x1.0        : BUT image 1.1999999x1.0546875x1.0546875
#  - Orientation LIA               : BUT strict: [[ 1.2 0. -0.01] [-0. 1.05 0.12] [ 0.01 -0.12 1.05]]
#  - Dtype uint8                   : BUT dtype >f4
# [INFO: run_prediction.py:  337]: Conforming image
# (1.0, 1.0, 1.0)
# Input:    min: 0.0  max: 1477.1085205078125
# rescale:  min: 0.0  max: 943.872314453125  scale: 0.2701636610114428
# Output:   min: 0.0  max: 255.0
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/011s4075/mri/orig.mgz.
# [INFO: run_prediction.py:  400]: Run coronal prediction
# [INFO: dataset.py:   78]: Loading Coronal with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:06<00:00, 41.87batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for coronal successful
# [INFO: inference.py:  468]: Coronal inference on /data/sub-011s4075/ses-201206221215290/anat/sub-011s4075_ses-201206221215290_T1w.nii finished in 6.1166 seconds
# [INFO: run_prediction.py:  400]: Run sagittal prediction
# [INFO: dataset.py:   69]: Loading Sagittal with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:06<00:00, 40.57batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for sagittal successful
# [INFO: inference.py:  468]: Sagittal inference on /data/sub-011s4075/ses-201206221215290/anat/sub-011s4075_ses-201206221215290_T1w.nii finished in 6.3106 seconds
# [INFO: run_prediction.py:  400]: Run axial prediction
# [INFO: dataset.py:   74]: Loading Axial with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:05<00:00, 42.85batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for axial successful
# [INFO: inference.py:  468]: Axial inference on /data/sub-011s4075/ses-201206221215290/anat/sub-011s4075_ses-201206221215290_T1w.nii finished in 5.9752 seconds
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/011s4075/mri/aparc.DKTatlas+aseg.deep.mgz.
# [INFO: run_prediction.py:  725]: Creating brainmask based on segmentation...
# Creating dilated mask ...
# Frontal region special treatment:  20210
#   Found 1 connected component(s)!
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/011s4075/mri/mask.mgz.
# [INFO: run_prediction.py:  744]: Creating aseg based on segmentation...
# Reducing to aseg ...
# FlipWM: rh 0 and lh 0 flipped.
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/011s4075/mri/aseg.auto_noCCseg.mgz.
# [INFO: run_prediction.py:  763]: Running volume-based QC check on segmentation...
# Checking total volume ...
# Voxel size in mm3: 1.0
# Total segmentation volume in liter: 1.13
# INFO: Running N4 bias-field correction
# python3.10 -s /fastsurfer/recon_surf/N4_bias_correct.py --in /output/011s4075/mri/orig.mgz --rescale /output/011s4075/mri/orig_nu.mgz --aseg /output/011s4075/mri/aparc.DKTatlas+aseg.deep.mgz --threads 1
#
# N4 Bias Correction Parameters:
#
# - verbosity: -1
# - input volume: /output/011s4075/mri/orig.mgz
# - output volume: do not save
# - rescaled volume: /output/011s4075/mri/orig_nu.mgz
# - mask: default (>0)
# - aseg: /output/011s4075/mri/aparc.DKTatlas+aseg.deep.mgz
# - shrink factor: 4
# - number fitting levels: 4
# - number iterations: 50
# - convergence threshold: 0.0
# - threads: 1
# read MGZ (FreeSurfer) image via nibabel...
# executing N4 correction ...
# - mask: ones (default)
# normalize WM to 105.0 (find WM from aseg)
# read MGZ (FreeSurfer) image via nibabel...
# - source white matter intensity: 58.05
# - m: 1.7572
# converting rescaled to UCHAR
# writing PosixPath: /output/011s4075/mri/orig_nu.mgz
# write MGZ (FreeSurfer) image via nibabel...
# python3.10 -s /fastsurfer/FastSurferCNN/segstats.py --segfile /output/011s4075/mri/aparc.DKTatlas+aseg.deep.mgz --segstatsfile /output/011s4075/stats/aseg+DKT.stats --normfile /output/011s4075/mri/orig_nu.mgz --threads 1 --empty --excludeid 0 --sd /output --sid 011s4075 --ids 2 4 5 7 8 10 11 12 13 14 15 16 17 18 24 26 28 31 41 43 44 46 47 49 50 51 52 53 54 58 60 63 77 251 252 253 254 255 1002 1003 1005 1006 1007 1008 1009 1010 1011 1012 1013 1014 1015 1016 1017 1018 1019 1020 1021 1022 1023 1024 1025 1026 1027 1028 1029 1030 1031 1034 1035 2002 2003 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031 2034 2035 --lut /fastsurfer/FastSurferCNN/config/FreeSurferColorLUT.txt measures --compute Mask(/output/011s4075/mri/mask.mgz) BrainSeg BrainSegNotVent SupraTentorial SupraTentorialNotVent SubCortGray rhCerebralWhiteMatter lhCerebralWhiteMatter CerebralWhiteMatter
# None of the labels [251, 252, 253, 254, 255] for merged label 10007 exist in the segmentation.
# Partial volume stats for 100 labels written to /output/011s4075/stats/aseg+DKT.stats.
# Calculation took 9.67 seconds using up to 1 threads.
# Version: 2.3.3+bd65b36
# Tue Jan  7 13:36:18 UTC 2025
#
# python3.10 -s /fastsurfer/FastSurferCNN/run_prediction.py --t1 /data/sub-041s4051/ses-201207121118550/anat/sub-041s4051_ses-201207121118550_T1w.nii --asegdkt_segfile /output/041s4051/mri/aparc.DKTatlas+aseg.deep.mgz --conformed_name /output/041s4051/mri/orig.mgz --brainmask_name /output/041s4051/mri/mask.mgz --aseg_name /output/041s4051/mri/aseg.auto_noCCseg.mgz --sid 041s4051 --seg_log /output/041s4051/scripts/deep-seg.log --vox_size min --batch_size 1 --viewagg_device auto --device auto --sd /output
# [INFO: run_prediction.py:  648]: Checking or downloading default checkpoints ...
# [INFO: common.py:  827]: Single subject with absolute file path for input.
# [INFO: common.py:  885]: Analyzing single subject /data/sub-041s4051/ses-201207121118550/anat/sub-041s4051_ses-201207121118550_T1w.nii
# [INFO: common.py:  986]: Output will be stored in Subjects Directory: /output
# [INFO: common.py:  114]: Using device: cuda
# [INFO: common.py:  114]: Using viewagg_device: cuda
# [INFO: run_prediction.py:  245]: Running view aggregation on cuda
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_coronal_v2.0.0.pkl
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_sagittal_v2.0.0.pkl
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_axial_v2.0.0.pkl
# [INFO: run_prediction.py:  324]: Successfully loaded image from /data/sub-041s4051/ses-201207121118550/anat/sub-041s4051_ses-201207121118550_T1w.nii.
# [INFO: run_prediction.py:  441]: Output image directory /output/041s4051/mri/orig does not exist. Creating it now...
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/041s4051/mri/orig/001.mgz.
# The input image is not conformed.
# A min-conformed image must satisfy the following criteria:
#  - Number of Dimensions 3        : True
#  - Dimensions 256x256x256        : BUT image dimensions (176, 240, 256)
#  - Voxel Size 1.0x1.0x1.0        : BUT image 1.1999999x1.0546875x1.0546875
#  - Orientation LIA               : BUT strict: [[ 1.19 0.09 -0.09] [-0.1 1.05 0.04] [ 0.11 -0.03 1.05]]
#  - Dtype uint8                   : BUT dtype >f4
# [INFO: run_prediction.py:  337]: Conforming image
# (1.0, 1.0, 1.0)
# Input:    min: 0.0  max: 2566.7763671875
# rescale:  min: 0.0  max: 1824.97802734375  scale: 0.1397277096925664
# Output:   min: 0.0  max: 255.0
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/041s4051/mri/orig.mgz.
# [INFO: run_prediction.py:  400]: Run coronal prediction
# [INFO: dataset.py:   78]: Loading Coronal with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:06<00:00, 42.02batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for coronal successful
# [INFO: inference.py:  468]: Coronal inference on /data/sub-041s4051/ses-201207121118550/anat/sub-041s4051_ses-201207121118550_T1w.nii finished in 6.0948 seconds
# [INFO: run_prediction.py:  400]: Run sagittal prediction
# [INFO: dataset.py:   69]: Loading Sagittal with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:06<00:00, 41.16batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for sagittal successful
# [INFO: inference.py:  468]: Sagittal inference on /data/sub-041s4051/ses-201207121118550/anat/sub-041s4051_ses-201207121118550_T1w.nii finished in 6.2206 seconds
# [INFO: run_prediction.py:  400]: Run axial prediction
# [INFO: dataset.py:   74]: Loading Axial with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:06<00:00, 42.66batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for axial successful
# [INFO: inference.py:  468]: Axial inference on /data/sub-041s4051/ses-201207121118550/anat/sub-041s4051_ses-201207121118550_T1w.nii finished in 6.0023 seconds
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/041s4051/mri/aparc.DKTatlas+aseg.deep.mgz.
# [INFO: run_prediction.py:  725]: Creating brainmask based on segmentation...
# Creating dilated mask ...
# Frontal region special treatment:  19988
#   Found 1 connected component(s)!
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/041s4051/mri/mask.mgz.
# [INFO: run_prediction.py:  744]: Creating aseg based on segmentation...
# Reducing to aseg ...
# FlipWM: rh 0 and lh 0 flipped.
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/041s4051/mri/aseg.auto_noCCseg.mgz.
# [INFO: run_prediction.py:  763]: Running volume-based QC check on segmentation...
# Checking total volume ...
# Voxel size in mm3: 1.0
# Total segmentation volume in liter: 1.32
# INFO: Running N4 bias-field correction
# python3.10 -s /fastsurfer/recon_surf/N4_bias_correct.py --in /output/041s4051/mri/orig.mgz --rescale /output/041s4051/mri/orig_nu.mgz --aseg /output/041s4051/mri/aparc.DKTatlas+aseg.deep.mgz --threads 1
#
# N4 Bias Correction Parameters:
#
# - verbosity: -1
# - input volume: /output/041s4051/mri/orig.mgz
# - output volume: do not save
# - rescaled volume: /output/041s4051/mri/orig_nu.mgz
# - mask: default (>0)
# - aseg: /output/041s4051/mri/aparc.DKTatlas+aseg.deep.mgz
# - shrink factor: 4
# - number fitting levels: 4
# - number iterations: 50
# - convergence threshold: 0.0
# - threads: 1
# read MGZ (FreeSurfer) image via nibabel...
# executing N4 correction ...
# - mask: ones (default)
# normalize WM to 105.0 (find WM from aseg)
# read MGZ (FreeSurfer) image via nibabel...
# - source white matter intensity: 40.10
# - m: 2.5436
# converting rescaled to UCHAR
# writing PosixPath: /output/041s4051/mri/orig_nu.mgz
# write MGZ (FreeSurfer) image via nibabel...
# python3.10 -s /fastsurfer/FastSurferCNN/segstats.py --segfile /output/041s4051/mri/aparc.DKTatlas+aseg.deep.mgz --segstatsfile /output/041s4051/stats/aseg+DKT.stats --normfile /output/041s4051/mri/orig_nu.mgz --threads 1 --empty --excludeid 0 --sd /output --sid 041s4051 --ids 2 4 5 7 8 10 11 12 13 14 15 16 17 18 24 26 28 31 41 43 44 46 47 49 50 51 52 53 54 58 60 63 77 251 252 253 254 255 1002 1003 1005 1006 1007 1008 1009 1010 1011 1012 1013 1014 1015 1016 1017 1018 1019 1020 1021 1022 1023 1024 1025 1026 1027 1028 1029 1030 1031 1034 1035 2002 2003 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031 2034 2035 --lut /fastsurfer/FastSurferCNN/config/FreeSurferColorLUT.txt measures --compute Mask(/output/041s4051/mri/mask.mgz) BrainSeg BrainSegNotVent SupraTentorial SupraTentorialNotVent SubCortGray rhCerebralWhiteMatter lhCerebralWhiteMatter CerebralWhiteMatter
# None of the labels [251, 252, 253, 254, 255] for merged label 10007 exist in the segmentation.
# Partial volume stats for 100 labels written to /output/041s4051/stats/aseg+DKT.stats.
# Calculation took 10.56 seconds using up to 1 threads.
# Version: 2.3.3+bd65b36
# Tue Jan  7 13:39:27 UTC 2025
#
# python3.10 -s /fastsurfer/FastSurferCNN/run_prediction.py --t1 /data/sub-068s4134/ses-201210151304380/anat/sub-068s4134_ses-201210151304380_T1w.nii --asegdkt_segfile /output/068s4134/mri/aparc.DKTatlas+aseg.deep.mgz --conformed_name /output/068s4134/mri/orig.mgz --brainmask_name /output/068s4134/mri/mask.mgz --aseg_name /output/068s4134/mri/aseg.auto_noCCseg.mgz --sid 068s4134 --seg_log /output/068s4134/scripts/deep-seg.log --vox_size min --batch_size 1 --viewagg_device auto --device auto --sd /output
# [INFO: run_prediction.py:  648]: Checking or downloading default checkpoints ...
# [INFO: common.py:  827]: Single subject with absolute file path for input.
# [INFO: common.py:  885]: Analyzing single subject /data/sub-068s4134/ses-201210151304380/anat/sub-068s4134_ses-201210151304380_T1w.nii
# [INFO: common.py:  986]: Output will be stored in Subjects Directory: /output
# [INFO: common.py:  114]: Using device: cuda
# [INFO: common.py:  114]: Using viewagg_device: cuda
# [INFO: run_prediction.py:  245]: Running view aggregation on cuda
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_coronal_v2.0.0.pkl
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_sagittal_v2.0.0.pkl
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_axial_v2.0.0.pkl
# [INFO: run_prediction.py:  324]: Successfully loaded image from /data/sub-068s4134/ses-201210151304380/anat/sub-068s4134_ses-201210151304380_T1w.nii.
# [INFO: run_prediction.py:  441]: Output image directory /output/068s4134/mri/orig does not exist. Creating it now...
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/068s4134/mri/orig/001.mgz.
# The input image is not conformed.
# A min-conformed image must satisfy the following criteria:
#  - Number of Dimensions 3        : True
#  - Dimensions 256x256x256        : BUT image dimensions (176, 240, 256)
#  - Voxel Size 1.0x1.0x1.0        : BUT image 1.1999999x1.0546875x1.0546875
#  - Orientation LIA               : BUT strict: [[ 1.2 0.01 -0.03] [-0.01 1.05 0.05] [ 0.04 -0.05 1.05]]
#  - Dtype uint8                   : BUT dtype >f4
# [INFO: run_prediction.py:  337]: Conforming image
# (1.0, 1.0, 1.0)
# Input:    min: 0.0  max: 1968.4508056640625
# rescale:  min: 0.0  max: 952.7301635742188  scale: 0.267651859623457
# Output:   min: 0.0  max: 255.0
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/068s4134/mri/orig.mgz.
# [INFO: run_prediction.py:  400]: Run coronal prediction
# [INFO: dataset.py:   78]: Loading Coronal with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:06<00:00, 42.02batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for coronal successful
# [INFO: inference.py:  468]: Coronal inference on /data/sub-068s4134/ses-201210151304380/anat/sub-068s4134_ses-201210151304380_T1w.nii finished in 6.0953 seconds
# [INFO: run_prediction.py:  400]: Run sagittal prediction
# [INFO: dataset.py:   69]: Loading Sagittal with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:06<00:00, 40.94batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for sagittal successful
# [INFO: inference.py:  468]: Sagittal inference on /data/sub-068s4134/ses-201210151304380/anat/sub-068s4134_ses-201210151304380_T1w.nii finished in 6.2537 seconds
# [INFO: run_prediction.py:  400]: Run axial prediction
# [INFO: dataset.py:   74]: Loading Axial with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:05<00:00, 42.85batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for axial successful
# [INFO: inference.py:  468]: Axial inference on /data/sub-068s4134/ses-201210151304380/anat/sub-068s4134_ses-201210151304380_T1w.nii finished in 5.9747 seconds
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/068s4134/mri/aparc.DKTatlas+aseg.deep.mgz.
# [INFO: run_prediction.py:  725]: Creating brainmask based on segmentation...
# Creating dilated mask ...
# Frontal region special treatment:  19047
#   Found 1 connected component(s)!
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/068s4134/mri/mask.mgz.
# [INFO: run_prediction.py:  744]: Creating aseg based on segmentation...
# Reducing to aseg ...
# FlipWM: rh 0 and lh 0 flipped.
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/068s4134/mri/aseg.auto_noCCseg.mgz.
# [INFO: run_prediction.py:  763]: Running volume-based QC check on segmentation...
# Checking total volume ...
# Voxel size in mm3: 1.0
# Total segmentation volume in liter: 1.11
# INFO: Running N4 bias-field correction
# python3.10 -s /fastsurfer/recon_surf/N4_bias_correct.py --in /output/068s4134/mri/orig.mgz --rescale /output/068s4134/mri/orig_nu.mgz --aseg /output/068s4134/mri/aparc.DKTatlas+aseg.deep.mgz --threads 1
#
# N4 Bias Correction Parameters:
#
# - verbosity: -1
# - input volume: /output/068s4134/mri/orig.mgz
# - output volume: do not save
# - rescaled volume: /output/068s4134/mri/orig_nu.mgz
# - mask: default (>0)
# - aseg: /output/068s4134/mri/aparc.DKTatlas+aseg.deep.mgz
# - shrink factor: 4
# - number fitting levels: 4
# - number iterations: 50
# - convergence threshold: 0.0
# - threads: 1
# read MGZ (FreeSurfer) image via nibabel...
# executing N4 correction ...
# - mask: ones (default)
# normalize WM to 105.0 (find WM from aseg)
# read MGZ (FreeSurfer) image via nibabel...
# - source white matter intensity: 73.47
# - m: 1.3882
# converting rescaled to UCHAR
# writing PosixPath: /output/068s4134/mri/orig_nu.mgz
# write MGZ (FreeSurfer) image via nibabel...
# python3.10 -s /fastsurfer/FastSurferCNN/segstats.py --segfile /output/068s4134/mri/aparc.DKTatlas+aseg.deep.mgz --segstatsfile /output/068s4134/stats/aseg+DKT.stats --normfile /output/068s4134/mri/orig_nu.mgz --threads 1 --empty --excludeid 0 --sd /output --sid 068s4134 --ids 2 4 5 7 8 10 11 12 13 14 15 16 17 18 24 26 28 31 41 43 44 46 47 49 50 51 52 53 54 58 60 63 77 251 252 253 254 255 1002 1003 1005 1006 1007 1008 1009 1010 1011 1012 1013 1014 1015 1016 1017 1018 1019 1020 1021 1022 1023 1024 1025 1026 1027 1028 1029 1030 1031 1034 1035 2002 2003 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031 2034 2035 --lut /fastsurfer/FastSurferCNN/config/FreeSurferColorLUT.txt measures --compute Mask(/output/068s4134/mri/mask.mgz) BrainSeg BrainSegNotVent SupraTentorial SupraTentorialNotVent SubCortGray rhCerebralWhiteMatter lhCerebralWhiteMatter CerebralWhiteMatter
# None of the labels [251, 252, 253, 254, 255] for merged label 10007 exist in the segmentation.
# Partial volume stats for 100 labels written to /output/068s4134/stats/aseg+DKT.stats.
# Calculation took 9.42 seconds using up to 1 threads.
# Version: 2.3.3+bd65b36
# Tue Jan  7 13:42:36 UTC 2025
#
# python3.10 -s /fastsurfer/FastSurferCNN/run_prediction.py --t1 /data/sub-123s4127/ses-201208030941490/anat/sub-123s4127_ses-201208030941490_T1w.nii --asegdkt_segfile /output/123s4127/mri/aparc.DKTatlas+aseg.deep.mgz --conformed_name /output/123s4127/mri/orig.mgz --brainmask_name /output/123s4127/mri/mask.mgz --aseg_name /output/123s4127/mri/aseg.auto_noCCseg.mgz --sid 123s4127 --seg_log /output/123s4127/scripts/deep-seg.log --vox_size min --batch_size 1 --viewagg_device auto --device auto --sd /output
# [INFO: run_prediction.py:  648]: Checking or downloading default checkpoints ...
# [INFO: common.py:  827]: Single subject with absolute file path for input.
# [INFO: common.py:  885]: Analyzing single subject /data/sub-123s4127/ses-201208030941490/anat/sub-123s4127_ses-201208030941490_T1w.nii
# [INFO: common.py:  986]: Output will be stored in Subjects Directory: /output
# [INFO: common.py:  114]: Using device: cuda
# [INFO: common.py:  114]: Using viewagg_device: cuda
# [INFO: run_prediction.py:  245]: Running view aggregation on cuda
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_coronal_v2.0.0.pkl
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_sagittal_v2.0.0.pkl
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_axial_v2.0.0.pkl
# [INFO: run_prediction.py:  324]: Successfully loaded image from /data/sub-123s4127/ses-201208030941490/anat/sub-123s4127_ses-201208030941490_T1w.nii.
# [INFO: run_prediction.py:  441]: Output image directory /output/123s4127/mri/orig does not exist. Creating it now...
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/123s4127/mri/orig/001.mgz.
# The input image is not conformed.
# A min-conformed image must satisfy the following criteria:
#  - Number of Dimensions 3        : True
#  - Dimensions 256x256x256        : BUT image dimensions (176, 240, 256)
#  - Voxel Size 1.0x1.0x1.0        : BUT image 1.1999999x1.0546875x1.0546875
#  - Orientation LIA               : BUT strict: [[ 1.2 0.03 0.06] [-0.04 1.04 0.17] [-0.06 -0.17 1.04]]
#  - Dtype uint8                   : BUT dtype >f4
# [INFO: run_prediction.py:  337]: Conforming image
# (1.0, 1.0, 1.0)
# Input:    min: 0.0  max: 2549.858154296875
# rescale:  min: 0.0  max: 1315.726806640625  scale: 0.19380923054313828
# Output:   min: 0.0  max: 255.0
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/123s4127/mri/orig.mgz.
# [INFO: run_prediction.py:  400]: Run coronal prediction
# [INFO: dataset.py:   78]: Loading Coronal with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:06<00:00, 42.00batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for coronal successful
# [INFO: inference.py:  468]: Coronal inference on /data/sub-123s4127/ses-201208030941490/anat/sub-123s4127_ses-201208030941490_T1w.nii finished in 6.0974 seconds
# [INFO: run_prediction.py:  400]: Run sagittal prediction
# [INFO: dataset.py:   69]: Loading Sagittal with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:06<00:00, 41.08batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for sagittal successful
# [INFO: inference.py:  468]: Sagittal inference on /data/sub-123s4127/ses-201208030941490/anat/sub-123s4127_ses-201208030941490_T1w.nii finished in 6.2326 seconds
# [INFO: run_prediction.py:  400]: Run axial prediction
# [INFO: dataset.py:   74]: Loading Axial with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:05<00:00, 42.92batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for axial successful
# [INFO: inference.py:  468]: Axial inference on /data/sub-123s4127/ses-201208030941490/anat/sub-123s4127_ses-201208030941490_T1w.nii finished in 5.9661 seconds
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/123s4127/mri/aparc.DKTatlas+aseg.deep.mgz.
# [INFO: run_prediction.py:  725]: Creating brainmask based on segmentation...
# Creating dilated mask ...
# Frontal region special treatment:  19138
#   Found 1 connected component(s)!
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/123s4127/mri/mask.mgz.
# [INFO: run_prediction.py:  744]: Creating aseg based on segmentation...
# Reducing to aseg ...
# FlipWM: rh 0 and lh 0 flipped.
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/123s4127/mri/aseg.auto_noCCseg.mgz.
# [INFO: run_prediction.py:  763]: Running volume-based QC check on segmentation...
# Checking total volume ...
# Voxel size in mm3: 1.0
# Total segmentation volume in liter: 1.02
# INFO: Running N4 bias-field correction
# python3.10 -s /fastsurfer/recon_surf/N4_bias_correct.py --in /output/123s4127/mri/orig.mgz --rescale /output/123s4127/mri/orig_nu.mgz --aseg /output/123s4127/mri/aparc.DKTatlas+aseg.deep.mgz --threads 1
#
# N4 Bias Correction Parameters:
#
# - verbosity: -1
# - input volume: /output/123s4127/mri/orig.mgz
# - output volume: do not save
# - rescaled volume: /output/123s4127/mri/orig_nu.mgz
# - mask: default (>0)
# - aseg: /output/123s4127/mri/aparc.DKTatlas+aseg.deep.mgz
# - shrink factor: 4
# - number fitting levels: 4
# - number iterations: 50
# - convergence threshold: 0.0
# - threads: 1
# read MGZ (FreeSurfer) image via nibabel...
# executing N4 correction ...
# - mask: ones (default)
# normalize WM to 105.0 (find WM from aseg)
# read MGZ (FreeSurfer) image via nibabel...
# - source white matter intensity: 57.30
# - m: 1.7802
# converting rescaled to UCHAR
# writing PosixPath: /output/123s4127/mri/orig_nu.mgz
# write MGZ (FreeSurfer) image via nibabel...
# python3.10 -s /fastsurfer/FastSurferCNN/segstats.py --segfile /output/123s4127/mri/aparc.DKTatlas+aseg.deep.mgz --segstatsfile /output/123s4127/stats/aseg+DKT.stats --normfile /output/123s4127/mri/orig_nu.mgz --threads 1 --empty --excludeid 0 --sd /output --sid 123s4127 --ids 2 4 5 7 8 10 11 12 13 14 15 16 17 18 24 26 28 31 41 43 44 46 47 49 50 51 52 53 54 58 60 63 77 251 252 253 254 255 1002 1003 1005 1006 1007 1008 1009 1010 1011 1012 1013 1014 1015 1016 1017 1018 1019 1020 1021 1022 1023 1024 1025 1026 1027 1028 1029 1030 1031 1034 1035 2002 2003 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031 2034 2035 --lut /fastsurfer/FastSurferCNN/config/FreeSurferColorLUT.txt measures --compute Mask(/output/123s4127/mri/mask.mgz) BrainSeg BrainSegNotVent SupraTentorial SupraTentorialNotVent SubCortGray rhCerebralWhiteMatter lhCerebralWhiteMatter CerebralWhiteMatter
# None of the labels [251, 252, 253, 254, 255] for merged label 10007 exist in the segmentation.
# Partial volume stats for 100 labels written to /output/123s4127/stats/aseg+DKT.stats.
# Calculation took 9.19 seconds using up to 1 threads.
# Version: 2.3.3+bd65b36
# Tue Jan  7 13:45:44 UTC 2025
#
# python3.10 -s /fastsurfer/FastSurferCNN/run_prediction.py --t1 /data/sub-005s4168/ses-201209060947300/anat/sub-005s4168_ses-201209060947300_T1w.nii --asegdkt_segfile /output/005s4168/mri/aparc.DKTatlas+aseg.deep.mgz --conformed_name /output/005s4168/mri/orig.mgz --brainmask_name /output/005s4168/mri/mask.mgz --aseg_name /output/005s4168/mri/aseg.auto_noCCseg.mgz --sid 005s4168 --seg_log /output/005s4168/scripts/deep-seg.log --vox_size min --batch_size 1 --viewagg_device auto --device auto --sd /output
# [INFO: run_prediction.py:  648]: Checking or downloading default checkpoints ...
# [INFO: common.py:  827]: Single subject with absolute file path for input.
# [INFO: common.py:  885]: Analyzing single subject /data/sub-005s4168/ses-201209060947300/anat/sub-005s4168_ses-201209060947300_T1w.nii
# [INFO: common.py:  986]: Output will be stored in Subjects Directory: /output
# [INFO: common.py:  114]: Using device: cuda
# [INFO: common.py:  114]: Using viewagg_device: cuda
# [INFO: run_prediction.py:  245]: Running view aggregation on cuda
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_coronal_v2.0.0.pkl
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_sagittal_v2.0.0.pkl
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_axial_v2.0.0.pkl
# [INFO: run_prediction.py:  324]: Successfully loaded image from /data/sub-005s4168/ses-201209060947300/anat/sub-005s4168_ses-201209060947300_T1w.nii.
# [INFO: run_prediction.py:  441]: Output image directory /output/005s4168/mri/orig does not exist. Creating it now...
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/005s4168/mri/orig/001.mgz.
# The input image is not conformed.
# A min-conformed image must satisfy the following criteria:
#  - Number of Dimensions 3        : True
#  - Dimensions 256x256x256        : BUT image dimensions (196, 256, 256)
#  - Voxel Size 1.0x1.0x1.0        : BUT image 1.2x1.0547x1.0547
#  - Orientation LIA               : BUT strict: [[ 1.2 0.04 0.03] [-0.05 1.03 0.2 ] [-0.02 -0.2 1.04]]
#  - Dtype uint8                   : BUT dtype >f4
# [INFO: run_prediction.py:  337]: Conforming image
# (1.0, 1.0, 1.0)
# Input:    min: 0.0  max: 17569.970703125
# rescale:  min: 0.0  max: 9030.96484375  scale: 0.028236185658111177
# Output:   min: 0.0  max: 255.0
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/005s4168/mri/orig.mgz.
# [INFO: run_prediction.py:  400]: Run coronal prediction
# [INFO: dataset.py:   78]: Loading Coronal with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:06<00:00, 41.85batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for coronal successful
# [INFO: inference.py:  468]: Coronal inference on /data/sub-005s4168/ses-201209060947300/anat/sub-005s4168_ses-201209060947300_T1w.nii finished in 6.1191 seconds
# [INFO: run_prediction.py:  400]: Run sagittal prediction
# [INFO: dataset.py:   69]: Loading Sagittal with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:06<00:00, 41.04batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for sagittal successful
# [INFO: inference.py:  468]: Sagittal inference on /data/sub-005s4168/ses-201209060947300/anat/sub-005s4168_ses-201209060947300_T1w.nii finished in 6.2380 seconds
# [INFO: run_prediction.py:  400]: Run axial prediction
# [INFO: dataset.py:   74]: Loading Axial with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:05<00:00, 43.06batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for axial successful
# [INFO: inference.py:  468]: Axial inference on /data/sub-005s4168/ses-201209060947300/anat/sub-005s4168_ses-201209060947300_T1w.nii finished in 5.9467 seconds
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/005s4168/mri/aparc.DKTatlas+aseg.deep.mgz.
# [INFO: run_prediction.py:  725]: Creating brainmask based on segmentation...
# Creating dilated mask ...
# Frontal region special treatment:  21135
#   Found 1 connected component(s)!
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/005s4168/mri/mask.mgz.
# [INFO: run_prediction.py:  744]: Creating aseg based on segmentation...
# Reducing to aseg ...
# FlipWM: rh 0 and lh 0 flipped.
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/005s4168/mri/aseg.auto_noCCseg.mgz.
# [INFO: run_prediction.py:  763]: Running volume-based QC check on segmentation...
# Checking total volume ...
# Voxel size in mm3: 1.0
# Total segmentation volume in liter: 1.1
# INFO: Running N4 bias-field correction
# python3.10 -s /fastsurfer/recon_surf/N4_bias_correct.py --in /output/005s4168/mri/orig.mgz --rescale /output/005s4168/mri/orig_nu.mgz --aseg /output/005s4168/mri/aparc.DKTatlas+aseg.deep.mgz --threads 1
#
# N4 Bias Correction Parameters:
#
# - verbosity: -1
# - input volume: /output/005s4168/mri/orig.mgz
# - output volume: do not save
# - rescaled volume: /output/005s4168/mri/orig_nu.mgz
# - mask: default (>0)
# - aseg: /output/005s4168/mri/aparc.DKTatlas+aseg.deep.mgz
# - shrink factor: 4
# - number fitting levels: 4
# - number iterations: 50
# - convergence threshold: 0.0
# - threads: 1
# read MGZ (FreeSurfer) image via nibabel...
# executing N4 correction ...
# - mask: ones (default)
# normalize WM to 105.0 (find WM from aseg)
# read MGZ (FreeSurfer) image via nibabel...
# - source white matter intensity: 48.06
# - m: 2.1225
# converting rescaled to UCHAR
# writing PosixPath: /output/005s4168/mri/orig_nu.mgz
# write MGZ (FreeSurfer) image via nibabel...
# python3.10 -s /fastsurfer/FastSurferCNN/segstats.py --segfile /output/005s4168/mri/aparc.DKTatlas+aseg.deep.mgz --segstatsfile /output/005s4168/stats/aseg+DKT.stats --normfile /output/005s4168/mri/orig_nu.mgz --threads 1 --empty --excludeid 0 --sd /output --sid 005s4168 --ids 2 4 5 7 8 10 11 12 13 14 15 16 17 18 24 26 28 31 41 43 44 46 47 49 50 51 52 53 54 58 60 63 77 251 252 253 254 255 1002 1003 1005 1006 1007 1008 1009 1010 1011 1012 1013 1014 1015 1016 1017 1018 1019 1020 1021 1022 1023 1024 1025 1026 1027 1028 1029 1030 1031 1034 1035 2002 2003 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031 2034 2035 --lut /fastsurfer/FastSurferCNN/config/FreeSurferColorLUT.txt measures --compute Mask(/output/005s4168/mri/mask.mgz) BrainSeg BrainSegNotVent SupraTentorial SupraTentorialNotVent SubCortGray rhCerebralWhiteMatter lhCerebralWhiteMatter CerebralWhiteMatter
# None of the labels [251, 252, 253, 254, 255] for merged label 10007 exist in the segmentation.
# Partial volume stats for 100 labels written to /output/005s4168/stats/aseg+DKT.stats.
# Calculation took 9.58 seconds using up to 1 threads.
# Version: 2.3.3+bd65b36
# Tue Jan  7 13:48:53 UTC 2025
#
# python3.10 -s /fastsurfer/FastSurferCNN/run_prediction.py --t1 /data/sub-023s4122/ses-201303051114060/anat/sub-023s4122_ses-201303051114060_T1w.nii --asegdkt_segfile /output/023s4122/mri/aparc.DKTatlas+aseg.deep.mgz --conformed_name /output/023s4122/mri/orig.mgz --brainmask_name /output/023s4122/mri/mask.mgz --aseg_name /output/023s4122/mri/aseg.auto_noCCseg.mgz --sid 023s4122 --seg_log /output/023s4122/scripts/deep-seg.log --vox_size min --batch_size 1 --viewagg_device auto --device auto --sd /output
# [INFO: run_prediction.py:  648]: Checking or downloading default checkpoints ...
# [INFO: common.py:  827]: Single subject with absolute file path for input.
# [INFO: common.py:  885]: Analyzing single subject /data/sub-023s4122/ses-201303051114060/anat/sub-023s4122_ses-201303051114060_T1w.nii
# [INFO: common.py:  986]: Output will be stored in Subjects Directory: /output
# [INFO: common.py:  114]: Using device: cuda
# [INFO: common.py:  114]: Using viewagg_device: cuda
# [INFO: run_prediction.py:  245]: Running view aggregation on cuda
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_coronal_v2.0.0.pkl
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_sagittal_v2.0.0.pkl
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_axial_v2.0.0.pkl
# [INFO: run_prediction.py:  324]: Successfully loaded image from /data/sub-023s4122/ses-201303051114060/anat/sub-023s4122_ses-201303051114060_T1w.nii.
# [INFO: run_prediction.py:  441]: Output image directory /output/023s4122/mri/orig does not exist. Creating it now...
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/023s4122/mri/orig/001.mgz.
# The input image is not conformed.
# A min-conformed image must satisfy the following criteria:
#  - Number of Dimensions 3        : True
#  - Dimensions 256x256x256        : BUT image dimensions (176, 240, 256)
#  - Voxel Size 1.0x1.0x1.0        : BUT image 1.1999999x1.0546875x1.0546875
#  - Orientation LIA               : BUT strict: [[ 1.2 0.06 0.06] [-0.08 1.04 0.14] [-0.06 -0.14 1.04]]
#  - Dtype uint8                   : BUT dtype >f4
# [INFO: run_prediction.py:  337]: Conforming image
# (1.0, 1.0, 1.0)
# Input:    min: 0.0  max: 1654.729248046875
# rescale:  min: 0.0  max: 1024.27734375  scale: 0.24895600938161433
# Output:   min: 0.0  max: 255.0
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/023s4122/mri/orig.mgz.
# [INFO: run_prediction.py:  400]: Run coronal prediction
# [INFO: dataset.py:   78]: Loading Coronal with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:06<00:00, 41.77batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for coronal successful
# [INFO: inference.py:  468]: Coronal inference on /data/sub-023s4122/ses-201303051114060/anat/sub-023s4122_ses-201303051114060_T1w.nii finished in 6.1314 seconds
# [INFO: run_prediction.py:  400]: Run sagittal prediction
# [INFO: dataset.py:   69]: Loading Sagittal with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:06<00:00, 40.85batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for sagittal successful
# [INFO: inference.py:  468]: Sagittal inference on /data/sub-023s4122/ses-201303051114060/anat/sub-023s4122_ses-201303051114060_T1w.nii finished in 6.2670 seconds
# [INFO: run_prediction.py:  400]: Run axial prediction
# [INFO: dataset.py:   74]: Loading Axial with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:05<00:00, 42.85batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for axial successful
# [INFO: inference.py:  468]: Axial inference on /data/sub-023s4122/ses-201303051114060/anat/sub-023s4122_ses-201303051114060_T1w.nii finished in 5.9748 seconds
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/023s4122/mri/aparc.DKTatlas+aseg.deep.mgz.
# [INFO: run_prediction.py:  725]: Creating brainmask based on segmentation...
# Creating dilated mask ...
# Frontal region special treatment:  24229
#   Found 1 connected component(s)!
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/023s4122/mri/mask.mgz.
# [INFO: run_prediction.py:  744]: Creating aseg based on segmentation...
# Reducing to aseg ...
# FlipWM: rh 0 and lh 0 flipped.
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/023s4122/mri/aseg.auto_noCCseg.mgz.
# [INFO: run_prediction.py:  763]: Running volume-based QC check on segmentation...
# Checking total volume ...
# Voxel size in mm3: 1.0
# Total segmentation volume in liter: 1.25
# INFO: Running N4 bias-field correction
# python3.10 -s /fastsurfer/recon_surf/N4_bias_correct.py --in /output/023s4122/mri/orig.mgz --rescale /output/023s4122/mri/orig_nu.mgz --aseg /output/023s4122/mri/aparc.DKTatlas+aseg.deep.mgz --threads 1
#
# N4 Bias Correction Parameters:
#
# ...
# [INFO: run_prediction.py:  744]: Creating aseg based on segmentation...
# Reducing to aseg ...
# FlipWM: rh 0 and lh 1 flipped.
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/128s4571/mri/aseg.auto_noCCseg.mgz.
# [INFO: run_prediction.py:  763]: Running volume-based QC check on segmentation...
# Checking total volume ...
# Voxel size in mm3: 1.0
# Total segmentation volume in liter: 1.27
# INFO: Running N4 bias-field correction
# python3.10 -s /fastsurfer/recon_surf/N4_bias_correct.py --in /output/128s4571/mri/orig.mgz --rescale /output/128s4571/mri/orig_nu.mgz --aseg /output/128s4571/mri/aparc.DKTatlas+aseg.deep.mgz --threads 1
#
# N4 Bias Correction Parameters:
#
# - verbosity: -1
# - input volume: /output/128s4571/mri/orig.mgz
# - output volume: do not save
# - rescaled volume: /output/128s4571/mri/orig_nu.mgz
# - mask: default (>0)
# - aseg: /output/128s4571/mri/aparc.DKTatlas+aseg.deep.mgz
# - shrink factor: 4
# - number fitting levels: 4
# - number iterations: 50
# - convergence threshold: 0.0
# - threads: 1
# read MGZ (FreeSurfer) image via nibabel...
# executing N4 correction ...
# - mask: ones (default)
# normalize WM to 105.0 (find WM from aseg)
# read MGZ (FreeSurfer) image via nibabel...
# - source white matter intensity: 45.00
# - m: 2.2665
# converting rescaled to UCHAR
# writing PosixPath: /output/128s4571/mri/orig_nu.mgz
# write MGZ (FreeSurfer) image via nibabel...
# python3.10 -s /fastsurfer/FastSurferCNN/segstats.py --segfile /output/128s4571/mri/aparc.DKTatlas+aseg.deep.mgz --segstatsfile /output/128s4571/stats/aseg+DKT.stats --normfile /output/128s4571/mri/orig_nu.mgz --threads 1 --empty --excludeid 0 --sd /output --sid 128s4571 --ids 2 4 5 7 8 10 11 12 13 14 15 16 17 18 24 26 28 31 41 43 44 46 47 49 50 51 52 53 54 58 60 63 77 251 252 253 254 255 1002 1003 1005 1006 1007 1008 1009 1010 1011 1012 1013 1014 1015 1016 1017 1018 1019 1020 1021 1022 1023 1024 1025 1026 1027 1028 1029 1030 1031 1034 1035 2002 2003 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031 2034 2035 --lut /fastsurfer/FastSurferCNN/config/FreeSurferColorLUT.txt measures --compute Mask(/output/128s4571/mri/mask.mgz) BrainSeg BrainSegNotVent SupraTentorial SupraTentorialNotVent SubCortGray rhCerebralWhiteMatter lhCerebralWhiteMatter CerebralWhiteMatter
# None of the labels [251, 252, 253, 254, 255] for merged label 10007 exist in the segmentation.
# Partial volume stats for 100 labels written to /output/128s4571/stats/aseg+DKT.stats.
# Calculation took 11.19 seconds using up to 1 threads.
# Version: 2.3.3+bd65b36
# Tue Jan  7 14:55:02 UTC 2025
#
# python3.10 -s /fastsurfer/FastSurferCNN/run_prediction.py --t1 /data/sub-109s4531/ses-201303251311530/anat/sub-109s4531_ses-201303251311530_T1w.nii --asegdkt_segfile /output/109s4531/mri/aparc.DKTatlas+aseg.deep.mgz --conformed_name /output/109s4531/mri/orig.mgz --brainmask_name /output/109s4531/mri/mask.mgz --aseg_name /output/109s4531/mri/aseg.auto_noCCseg.mgz --sid 109s4531 --seg_log /output/109s4531/scripts/deep-seg.log --vox_size min --batch_size 1 --viewagg_device auto --device auto --sd /output
# [INFO: run_prediction.py:  648]: Checking or downloading default checkpoints ...
# [INFO: common.py:  827]: Single subject with absolute file path for input.
# [INFO: common.py:  885]: Analyzing single subject /data/sub-109s4531/ses-201303251311530/anat/sub-109s4531_ses-201303251311530_T1w.nii
# [INFO: common.py:  986]: Output will be stored in Subjects Directory: /output
# [INFO: common.py:  114]: Using device: cuda
# [INFO: common.py:  114]: Using viewagg_device: cuda
# [INFO: run_prediction.py:  245]: Running view aggregation on cuda
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_coronal_v2.0.0.pkl
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_sagittal_v2.0.0.pkl
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_axial_v2.0.0.pkl
# [INFO: run_prediction.py:  324]: Successfully loaded image from /data/sub-109s4531/ses-201303251311530/anat/sub-109s4531_ses-201303251311530_T1w.nii.
# [INFO: run_prediction.py:  441]: Output image directory /output/109s4531/mri/orig does not exist. Creating it now...
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/109s4531/mri/orig/001.mgz.
# The input image is not conformed.
# A min-conformed image must satisfy the following criteria:
#  - Number of Dimensions 3        : True
#  - Dimensions 256x256x256        : BUT image dimensions (196, 256, 256)
#  - Voxel Size 1.0x1.0x1.0        : BUT image 1.2x1.0547x1.0547
#  - Orientation LIA               : BUT strict: [[ 1.19 -0.12 -0.08] [ 0.15 1.03 0.16] [ 0.07 -0.17 1.04]]
#  - Dtype uint8                   : BUT dtype >f4
# [INFO: run_prediction.py:  337]: Conforming image
# (1.0, 1.0, 1.0)
# Input:    min: 0.0  max: 9954.927734375
# rescale:  min: 0.0  max: 6729.53125  scale: 0.03789268383291927
# Output:   min: 0.0  max: 255.0
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/109s4531/mri/orig.mgz.
# [INFO: run_prediction.py:  400]: Run coronal prediction
# [INFO: dataset.py:   78]: Loading Coronal with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:06<00:00, 41.94batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for coronal successful
# [INFO: inference.py:  468]: Coronal inference on /data/sub-109s4531/ses-201303251311530/anat/sub-109s4531_ses-201303251311530_T1w.nii finished in 6.1063 seconds
# [INFO: run_prediction.py:  400]: Run sagittal prediction
# [INFO: dataset.py:   69]: Loading Sagittal with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:06<00:00, 40.19batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for sagittal successful
# [INFO: inference.py:  468]: Sagittal inference on /data/sub-109s4531/ses-201303251311530/anat/sub-109s4531_ses-201303251311530_T1w.nii finished in 6.3710 seconds
# [INFO: run_prediction.py:  400]: Run axial prediction
# [INFO: dataset.py:   74]: Loading Axial with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:05<00:00, 42.88batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for axial successful
# [INFO: inference.py:  468]: Axial inference on /data/sub-109s4531/ses-201303251311530/anat/sub-109s4531_ses-201303251311530_T1w.nii finished in 5.9704 seconds
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/109s4531/mri/aparc.DKTatlas+aseg.deep.mgz.
# [INFO: run_prediction.py:  725]: Creating brainmask based on segmentation...
# Creating dilated mask ...
# Frontal region special treatment:  18139
#   Found 1 connected component(s)!
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/109s4531/mri/mask.mgz.
# [INFO: run_prediction.py:  744]: Creating aseg based on segmentation...
# Reducing to aseg ...
# FlipWM: rh 0 and lh 0 flipped.
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/109s4531/mri/aseg.auto_noCCseg.mgz.
# [INFO: run_prediction.py:  763]: Running volume-based QC check on segmentation...
# Checking total volume ...
# Voxel size in mm3: 1.0
# Total segmentation volume in liter: 1.12
# INFO: Running N4 bias-field correction
# python3.10 -s /fastsurfer/recon_surf/N4_bias_correct.py --in /output/109s4531/mri/orig.mgz --rescale /output/109s4531/mri/orig_nu.mgz --aseg /output/109s4531/mri/aparc.DKTatlas+aseg.deep.mgz --threads 1
#
# N4 Bias Correction Parameters:
#
# - verbosity: -1
# - input volume: /output/109s4531/mri/orig.mgz
# - output volume: do not save
# - rescaled volume: /output/109s4531/mri/orig_nu.mgz
# - mask: default (>0)
# - aseg: /output/109s4531/mri/aparc.DKTatlas+aseg.deep.mgz
# - shrink factor: 4
# - number fitting levels: 4
# - number iterations: 50
# - convergence threshold: 0.0
# - threads: 1
# read MGZ (FreeSurfer) image via nibabel...
# executing N4 correction ...
# - mask: ones (default)
# normalize WM to 105.0 (find WM from aseg)
# read MGZ (FreeSurfer) image via nibabel...
# - source white matter intensity: 49.11
# - m: 2.0770
# converting rescaled to UCHAR
# writing PosixPath: /output/109s4531/mri/orig_nu.mgz
# write MGZ (FreeSurfer) image via nibabel...
# python3.10 -s /fastsurfer/FastSurferCNN/segstats.py --segfile /output/109s4531/mri/aparc.DKTatlas+aseg.deep.mgz --segstatsfile /output/109s4531/stats/aseg+DKT.stats --normfile /output/109s4531/mri/orig_nu.mgz --threads 1 --empty --excludeid 0 --sd /output --sid 109s4531 --ids 2 4 5 7 8 10 11 12 13 14 15 16 17 18 24 26 28 31 41 43 44 46 47 49 50 51 52 53 54 58 60 63 77 251 252 253 254 255 1002 1003 1005 1006 1007 1008 1009 1010 1011 1012 1013 1014 1015 1016 1017 1018 1019 1020 1021 1022 1023 1024 1025 1026 1027 1028 1029 1030 1031 1034 1035 2002 2003 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031 2034 2035 --lut /fastsurfer/FastSurferCNN/config/FreeSurferColorLUT.txt measures --compute Mask(/output/109s4531/mri/mask.mgz) BrainSeg BrainSegNotVent SupraTentorial SupraTentorialNotVent SubCortGray rhCerebralWhiteMatter lhCerebralWhiteMatter CerebralWhiteMatter
# None of the labels [251, 252, 253, 254, 255] for merged label 10007 exist in the segmentation.
# Partial volume stats for 100 labels written to /output/109s4531/stats/aseg+DKT.stats.
# Calculation took 10.22 seconds using up to 1 threads.
# Version: 2.3.3+bd65b36
# Tue Jan  7 14:58:11 UTC 2025
#
# python3.10 -s /fastsurfer/FastSurferCNN/run_prediction.py --t1 /data/sub-007s4620/ses-201304151230160/anat/sub-007s4620_ses-201304151230160_T1w.nii --asegdkt_segfile /output/007s4620/mri/aparc.DKTatlas+aseg.deep.mgz --conformed_name /output/007s4620/mri/orig.mgz --brainmask_name /output/007s4620/mri/mask.mgz --aseg_name /output/007s4620/mri/aseg.auto_noCCseg.mgz --sid 007s4620 --seg_log /output/007s4620/scripts/deep-seg.log --vox_size min --batch_size 1 --viewagg_device auto --device auto --sd /output
# [INFO: run_prediction.py:  648]: Checking or downloading default checkpoints ...
# [INFO: common.py:  827]: Single subject with absolute file path for input.
# [INFO: common.py:  885]: Analyzing single subject /data/sub-007s4620/ses-201304151230160/anat/sub-007s4620_ses-201304151230160_T1w.nii
# [INFO: common.py:  986]: Output will be stored in Subjects Directory: /output
# [INFO: common.py:  114]: Using device: cuda
# [INFO: common.py:  114]: Using viewagg_device: cuda
# [INFO: run_prediction.py:  245]: Running view aggregation on cuda
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_coronal_v2.0.0.pkl
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_sagittal_v2.0.0.pkl
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_axial_v2.0.0.pkl
# [INFO: run_prediction.py:  324]: Successfully loaded image from /data/sub-007s4620/ses-201304151230160/anat/sub-007s4620_ses-201304151230160_T1w.nii.
# [INFO: run_prediction.py:  441]: Output image directory /output/007s4620/mri/orig does not exist. Creating it now...
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/007s4620/mri/orig/001.mgz.
# The input image is not conformed.
# A min-conformed image must satisfy the following criteria:
#  - Number of Dimensions 3        : True
#  - Dimensions 256x256x256        : BUT image dimensions (196, 256, 256)
#  - Voxel Size 1.0x1.0x1.0        : BUT image 1.2x1.0547x1.0547
#  - Orientation LIA               : BUT strict: [[ 1.20e+00 -5.76e-04 -1.63e-02] [ 3.18e-03 1.04e+00 1.44e-01] [ 1.83e-02 -1.44e-01 1.04e+00]]
#  - Dtype uint8                   : BUT dtype >f4
# [INFO: run_prediction.py:  337]: Conforming image
# (1.0, 1.0, 1.0)
# Input:    min: 0.0  max: 19259.978515625
# rescale:  min: 0.0  max: 7126.19189453125  scale: 0.03578348769918629
# Output:   min: 0.0  max: 255.0
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/007s4620/mri/orig.mgz.
# [INFO: run_prediction.py:  400]: Run coronal prediction
# [INFO: dataset.py:   78]: Loading Coronal with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:06<00:00, 41.78batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for coronal successful
# [INFO: inference.py:  468]: Coronal inference on /data/sub-007s4620/ses-201304151230160/anat/sub-007s4620_ses-201304151230160_T1w.nii finished in 6.1303 seconds
# [INFO: run_prediction.py:  400]: Run sagittal prediction
# [INFO: dataset.py:   69]: Loading Sagittal with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:06<00:00, 40.13batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for sagittal successful
# [INFO: inference.py:  468]: Sagittal inference on /data/sub-007s4620/ses-201304151230160/anat/sub-007s4620_ses-201304151230160_T1w.nii finished in 6.3795 seconds
# [INFO: run_prediction.py:  400]: Run axial prediction
# [INFO: dataset.py:   74]: Loading Axial with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:05<00:00, 42.96batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for axial successful
# [INFO: inference.py:  468]: Axial inference on /data/sub-007s4620/ses-201304151230160/anat/sub-007s4620_ses-201304151230160_T1w.nii finished in 5.9604 seconds
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/007s4620/mri/aparc.DKTatlas+aseg.deep.mgz.
# [INFO: run_prediction.py:  725]: Creating brainmask based on segmentation...
# Creating dilated mask ...
# Frontal region special treatment:  20508
#   Found 1 connected component(s)!
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/007s4620/mri/mask.mgz.
# [INFO: run_prediction.py:  744]: Creating aseg based on segmentation...
# Reducing to aseg ...
# FlipWM: rh 0 and lh 0 flipped.
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/007s4620/mri/aseg.auto_noCCseg.mgz.
# [INFO: run_prediction.py:  763]: Running volume-based QC check on segmentation...
# Checking total volume ...
# Voxel size in mm3: 1.0
# Total segmentation volume in liter: 1.04
# INFO: Running N4 bias-field correction
# python3.10 -s /fastsurfer/recon_surf/N4_bias_correct.py --in /output/007s4620/mri/orig.mgz --rescale /output/007s4620/mri/orig_nu.mgz --aseg /output/007s4620/mri/aparc.DKTatlas+aseg.deep.mgz --threads 1
#
# N4 Bias Correction Parameters:
#
# - verbosity: -1
# - input volume: /output/007s4620/mri/orig.mgz
# - output volume: do not save
# - rescaled volume: /output/007s4620/mri/orig_nu.mgz
# - mask: default (>0)
# - aseg: /output/007s4620/mri/aparc.DKTatlas+aseg.deep.mgz
# - shrink factor: 4
# - number fitting levels: 4
# - number iterations: 50
# - convergence threshold: 0.0
# - threads: 1
# read MGZ (FreeSurfer) image via nibabel...
# executing N4 correction ...
# - mask: ones (default)
# normalize WM to 105.0 (find WM from aseg)
# read MGZ (FreeSurfer) image via nibabel...
# - source white matter intensity: 53.35
# - m: 1.9120
# converting rescaled to UCHAR
# writing PosixPath: /output/007s4620/mri/orig_nu.mgz
# write MGZ (FreeSurfer) image via nibabel...
# python3.10 -s /fastsurfer/FastSurferCNN/segstats.py --segfile /output/007s4620/mri/aparc.DKTatlas+aseg.deep.mgz --segstatsfile /output/007s4620/stats/aseg+DKT.stats --normfile /output/007s4620/mri/orig_nu.mgz --threads 1 --empty --excludeid 0 --sd /output --sid 007s4620 --ids 2 4 5 7 8 10 11 12 13 14 15 16 17 18 24 26 28 31 41 43 44 46 47 49 50 51 52 53 54 58 60 63 77 251 252 253 254 255 1002 1003 1005 1006 1007 1008 1009 1010 1011 1012 1013 1014 1015 1016 1017 1018 1019 1020 1021 1022 1023 1024 1025 1026 1027 1028 1029 1030 1031 1034 1035 2002 2003 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031 2034 2035 --lut /fastsurfer/FastSurferCNN/config/FreeSurferColorLUT.txt measures --compute Mask(/output/007s4620/mri/mask.mgz) BrainSeg BrainSegNotVent SupraTentorial SupraTentorialNotVent SubCortGray rhCerebralWhiteMatter lhCerebralWhiteMatter CerebralWhiteMatter
# None of the labels [251, 252, 253, 254, 255] for merged label 10007 exist in the segmentation.
# Partial volume stats for 100 labels written to /output/007s4620/stats/aseg+DKT.stats.
# Calculation took 9.94 seconds using up to 1 threads.

# %%
# !docker run --gpus all -v /media/jfallmann/T9/University/master_thesis/dataset/mri/bids:/data -v /media/jfallmann/T9/University/master_thesis/dataset/mri/processed:/output -v /media/jfallmann/T9/University/master_thesis/license:/fs_license --entrypoint "/fastsurfer/brun_fastsurfer.sh" --rm --user $(id -u):$(id -g) deepmi/fastsurfer:latest --fs_license /fs_license/license.txt --subject_list /data/fastsurfer_batch2.txt --sd /output --parallel --3T --seg_only --no_cereb --no_hypothal
# Out:
# /fastsurfer/brun_fastsurfer.sh --fs_license /fs_license/license.txt --subject_list /data/fastsurfer_batch2.txt --sd /output --parallel --3T --seg_only --no_cereb --no_hypothal
# Tue, 07 Jan 2025 02:28:33 +0000
#
# INFO: run_fastsurfer not explicitly specified, using $FASTSURFER_HOME/run_fastsurfer.sh.
# 072s4610=/data/sub-072s4610/ses-201304090730570/anat/sub-072s4610_ses-201304090730570_T1w.nii 099s4104=/data/sub-099s4104/ses-201207110807380/anat/sub-099s4104_ses-201207110807380_T1w.nii 128s4609=/data/sub-128s4609/ses-201204041828370/anat/sub-128s4609_ses-201204041828370_T1w.nii 041s4629=/data/sub-041s4629/ses-201304221158430/anat/sub-041s4629_ses-201304221158430_T1w.nii 070s4692=/data/sub-070s4692/ses-201205081035540/anat/sub-070s4692_ses-201205081035540_T1w.nii 037s4030=/data/sub-037s4030/ses-201205141108430/anat/sub-037s4030_ses-201205141108430_T1w.nii 014s4080=/data/sub-014s4080/ses-201206211033430/anat/sub-014s4080_ses-201206211033430_T1w.nii 016s4009=/data/sub-016s4009/ses-201207180940140/anat/sub-016s4009_ses-201207180940140_T1w.nii 941s4036=/data/sub-941s4036/ses-201208171318460/anat/sub-941s4036_ses-201208171318460_T1w.nii 116s4167=/data/sub-116s4167/ses-201208291116580/anat/sub-116s4167_ses-201208291116580_T1w.nii 127s4148=/data/sub-127s4148/ses-201208300908040/anat/sub-127s4148_ses-201208300908040_T1w.nii 072s2083=/data/sub-072s2083/ses-201209111026390/anat/sub-072s2083_ses-201209111026390_T1w.nii 123s2055=/data/sub-123s2055/ses-201209241436050/anat/sub-123s2055_ses-201209241436050_T1w.nii 005s4185=/data/sub-005s4185/ses-201209271137370/anat/sub-005s4185_ses-201209271137370_T1w.nii 128s2036=/data/sub-128s2036/ses-201210060910010/anat/sub-128s2036_ses-201210060910010_T1w.nii 073s0089=/data/sub-073s0089/ses-201210091114110/anat/sub-073s0089_ses-201210091114110_T1w.nii 099s2042=/data/sub-099s2042/ses-201208210808420/anat/sub-099s2042_ses-201208210808420_T1w.nii 024s4280=/data/sub-024s4280/ses-201211051025130/anat/sub-024s4280_ses-201211051025130_T1w.nii 128s2045=/data/sub-128s2045/ses-201210181449010/anat/sub-128s2045_ses-201210181449010_T1w.nii 067s2196=/data/sub-067s2196/ses-201211281153460/anat/sub-067s2196_ses-201211281153460_T1w.nii 014s4328=/data/sub-014s4328/ses-201211081101260/anat/sub-014s4328_ses-201211081101260_T1w.nii 021s4276=/data/sub-021s4276/ses-201210221004540/anat/sub-021s4276_ses-201210221004540_T1w.nii 067s2195=/data/sub-067s2195/ses-201212051217390/anat/sub-067s2195_ses-201212051217390_T1w.nii 035s2074=/data/sub-035s2074/ses-201211271413050/anat/sub-035s2074_ses-201211271413050_T1w.nii 094s2201=/data/sub-094s2201/ses-201301151022330/anat/sub-094s2201_ses-201301151022330_T1w.nii 072s4445=/data/sub-072s4445/ses-201301240955020/anat/sub-072s4445_ses-201301240955020_T1w.nii 037s4381=/data/sub-037s4381/ses-201301251132420/anat/sub-037s4381_ses-201301251132420_T1w.nii 021s4419=/data/sub-021s4419/ses-201212171032370/anat/sub-021s4419_ses-201212171032370_T1w.nii 128s2151=/data/sub-128s2151/ses-201302051739350/anat/sub-128s2151_ses-201302051739350_T1w.nii 011s2274=/data/sub-011s2274/ses-201302061432250/anat/sub-011s2274_ses-201302061432250_T1w.nii 022s4291=/data/sub-022s4291/ses-201301301429580/anat/sub-022s4291_ses-201301301429580_T1w.nii 023s4448=/data/sub-023s4448/ses-201302281128010/anat/sub-023s4448_ses-201302281128010_T1w.nii 099s4565=/data/sub-099s4565/ses-201302261036210/anat/sub-099s4565_ses-201302261036210_T1w.nii 073s4614=/data/sub-073s4614/ses-201303120850540/anat/sub-073s4614_ses-201303120850540_T1w.nii 035s4464=/data/sub-035s4464/ses-201302211415500/anat/sub-035s4464_ses-201302211415500_T1w.nii 072s4007=/data/sub-072s4007/ses-201203221108250/anat/sub-072s4007_ses-201203221108250_T1w.nii 014s4576=/data/sub-014s4576/ses-201304041124060/anat/sub-014s4576_ses-201304041124060_T1w.nii 073s2225=/data/sub-073s2225/ses-201304291337190/anat/sub-073s2225_ses-201304291337190_T1w.nii 067s2301=/data/sub-067s2301/ses-201303151036450/anat/sub-067s2301_ses-201303151036450_T1w.nii 073s2153=/data/sub-073s2153/ses-201304011234170/anat/sub-073s2153_ses-201304011234170_T1w.nii 094s4560=/data/sub-094s4560/ses-201303211430590/anat/sub-094s4560_ses-201303211430590_T1w.nii 007s4568=/data/sub-007s4568/ses-201305131446180/anat/sub-007s4568_ses-201305131446180_T1w.nii 022s2379=/data/sub-022s2379/ses-201305311149020/anat ...
# Version: 2.3.3+bd65b36
# Tue Jan  7 02:28:33 UTC 2025
#
# python3.10 -s /fastsurfer/FastSurferCNN/run_prediction.py --t1 /data/sub-072s4610/ses-201304090730570/anat/sub-072s4610_ses-201304090730570_T1w.nii --asegdkt_segfile /output/072s4610/mri/aparc.DKTatlas+aseg.deep.mgz --conformed_name /output/072s4610/mri/orig.mgz --brainmask_name /output/072s4610/mri/mask.mgz --aseg_name /output/072s4610/mri/aseg.auto_noCCseg.mgz --sid 072s4610 --seg_log /output/072s4610/scripts/deep-seg.log --vox_size min --batch_size 1 --viewagg_device auto --device auto --sd /output
# [INFO: run_prediction.py:  648]: Checking or downloading default checkpoints ...
# [INFO: common.py:  827]: Single subject with absolute file path for input.
# [INFO: common.py:  885]: Analyzing single subject /data/sub-072s4610/ses-201304090730570/anat/sub-072s4610_ses-201304090730570_T1w.nii
# [INFO: common.py:  986]: Output will be stored in Subjects Directory: /output
# [INFO: common.py:  114]: Using device: cuda
# [INFO: common.py:  114]: Using viewagg_device: cuda
# [INFO: run_prediction.py:  245]: Running view aggregation on cuda
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_coronal_v2.0.0.pkl
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_sagittal_v2.0.0.pkl
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_axial_v2.0.0.pkl
# [INFO: run_prediction.py:  324]: Successfully loaded image from /data/sub-072s4610/ses-201304090730570/anat/sub-072s4610_ses-201304090730570_T1w.nii.
# [INFO: run_prediction.py:  441]: Output image directory /output/072s4610/mri/orig does not exist. Creating it now...
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/072s4610/mri/orig/001.mgz.
# The input image is not conformed.
# A min-conformed image must satisfy the following criteria:
#  - Number of Dimensions 3        : True
#  - Dimensions 256x256x256        : BUT image dimensions (176, 240, 256)
#  - Voxel Size 1.0x1.0x1.0        : BUT image 1.1999999x1.0546875x1.0546875
#  - Orientation LIA               : BUT strict: [[ 1.2 -0.01 -0.07] [ 0.02 1.05 0.06] [ 0.08 -0.06 1.05]]
#  - Dtype uint8                   : BUT dtype >f4
# [INFO: run_prediction.py:  337]: Conforming image
# (1.0, 1.0, 1.0)
# Input:    min: 0.0  max: 2186.599609375
# rescale:  min: 0.0  max: 994.90283203125  scale: 0.2563064369606603
# Output:   min: 0.0  max: 255.0
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/072s4610/mri/orig.mgz.
# [INFO: run_prediction.py:  400]: Run coronal prediction
# [INFO: dataset.py:   78]: Loading Coronal with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:05<00:00, 42.77batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for coronal successful
# [INFO: inference.py:  468]: Coronal inference on /data/sub-072s4610/ses-201304090730570/anat/sub-072s4610_ses-201304090730570_T1w.nii finished in 5.9875 seconds
# [INFO: run_prediction.py:  400]: Run sagittal prediction
# [INFO: dataset.py:   69]: Loading Sagittal with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:06<00:00, 42.28batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for sagittal successful
# [INFO: inference.py:  468]: Sagittal inference on /data/sub-072s4610/ses-201304090730570/anat/sub-072s4610_ses-201304090730570_T1w.nii finished in 6.0562 seconds
# [INFO: run_prediction.py:  400]: Run axial prediction
# [INFO: dataset.py:   74]: Loading Axial with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:05<00:00, 43.96batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for axial successful
# [INFO: inference.py:  468]: Axial inference on /data/sub-072s4610/ses-201304090730570/anat/sub-072s4610_ses-201304090730570_T1w.nii finished in 5.8243 seconds
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/072s4610/mri/aparc.DKTatlas+aseg.deep.mgz.
# [INFO: run_prediction.py:  725]: Creating brainmask based on segmentation...
# Creating dilated mask ...
# Frontal region special treatment:  15238
#   Found 1 connected component(s)!
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/072s4610/mri/mask.mgz.
# [INFO: run_prediction.py:  744]: Creating aseg based on segmentation...
# Reducing to aseg ...
# FlipWM: rh 0 and lh 0 flipped.
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/072s4610/mri/aseg.auto_noCCseg.mgz.
# [INFO: run_prediction.py:  763]: Running volume-based QC check on segmentation...
# Checking total volume ...
# Voxel size in mm3: 1.0
# Total segmentation volume in liter: 0.9
# INFO: Running N4 bias-field correction
# python3.10 -s /fastsurfer/recon_surf/N4_bias_correct.py --in /output/072s4610/mri/orig.mgz --rescale /output/072s4610/mri/orig_nu.mgz --aseg /output/072s4610/mri/aparc.DKTatlas+aseg.deep.mgz --threads 1
#
# N4 Bias Correction Parameters:
#
# - verbosity: -1
# - input volume: /output/072s4610/mri/orig.mgz
# - output volume: do not save
# - rescaled volume: /output/072s4610/mri/orig_nu.mgz
# - mask: default (>0)
# - aseg: /output/072s4610/mri/aparc.DKTatlas+aseg.deep.mgz
# - shrink factor: 4
# - number fitting levels: 4
# - number iterations: 50
# - convergence threshold: 0.0
# - threads: 1
# read MGZ (FreeSurfer) image via nibabel...
# executing N4 correction ...
# - mask: ones (default)
# normalize WM to 105.0 (find WM from aseg)
# read MGZ (FreeSurfer) image via nibabel...
# - source white matter intensity: 49.23
# - m: 2.0720
# converting rescaled to UCHAR
# writing PosixPath: /output/072s4610/mri/orig_nu.mgz
# write MGZ (FreeSurfer) image via nibabel...
# python3.10 -s /fastsurfer/FastSurferCNN/segstats.py --segfile /output/072s4610/mri/aparc.DKTatlas+aseg.deep.mgz --segstatsfile /output/072s4610/stats/aseg+DKT.stats --normfile /output/072s4610/mri/orig_nu.mgz --threads 1 --empty --excludeid 0 --sd /output --sid 072s4610 --ids 2 4 5 7 8 10 11 12 13 14 15 16 17 18 24 26 28 31 41 43 44 46 47 49 50 51 52 53 54 58 60 63 77 251 252 253 254 255 1002 1003 1005 1006 1007 1008 1009 1010 1011 1012 1013 1014 1015 1016 1017 1018 1019 1020 1021 1022 1023 1024 1025 1026 1027 1028 1029 1030 1031 1034 1035 2002 2003 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031 2034 2035 --lut /fastsurfer/FastSurferCNN/config/FreeSurferColorLUT.txt measures --compute Mask(/output/072s4610/mri/mask.mgz) BrainSeg BrainSegNotVent SupraTentorial SupraTentorialNotVent SubCortGray rhCerebralWhiteMatter lhCerebralWhiteMatter CerebralWhiteMatter
# None of the labels [251, 252, 253, 254, 255] for merged label 10007 exist in the segmentation.
# Partial volume stats for 100 labels written to /output/072s4610/stats/aseg+DKT.stats.
# Calculation took 8.88 seconds using up to 1 threads.
# Version: 2.3.3+bd65b36
# Tue Jan  7 02:31:41 UTC 2025
#
# python3.10 -s /fastsurfer/FastSurferCNN/run_prediction.py --t1 /data/sub-099s4104/ses-201207110807380/anat/sub-099s4104_ses-201207110807380_T1w.nii --asegdkt_segfile /output/099s4104/mri/aparc.DKTatlas+aseg.deep.mgz --conformed_name /output/099s4104/mri/orig.mgz --brainmask_name /output/099s4104/mri/mask.mgz --aseg_name /output/099s4104/mri/aseg.auto_noCCseg.mgz --sid 099s4104 --seg_log /output/099s4104/scripts/deep-seg.log --vox_size min --batch_size 1 --viewagg_device auto --device auto --sd /output
# [INFO: run_prediction.py:  648]: Checking or downloading default checkpoints ...
# [INFO: common.py:  827]: Single subject with absolute file path for input.
# [INFO: common.py:  885]: Analyzing single subject /data/sub-099s4104/ses-201207110807380/anat/sub-099s4104_ses-201207110807380_T1w.nii
# [INFO: common.py:  986]: Output will be stored in Subjects Directory: /output
# [INFO: common.py:  114]: Using device: cuda
# [INFO: common.py:  114]: Using viewagg_device: cuda
# [INFO: run_prediction.py:  245]: Running view aggregation on cuda
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_coronal_v2.0.0.pkl
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_sagittal_v2.0.0.pkl
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_axial_v2.0.0.pkl
# [INFO: run_prediction.py:  324]: Successfully loaded image from /data/sub-099s4104/ses-201207110807380/anat/sub-099s4104_ses-201207110807380_T1w.nii.
# [INFO: run_prediction.py:  441]: Output image directory /output/099s4104/mri/orig does not exist. Creating it now...
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/099s4104/mri/orig/001.mgz.
# The input image is not conformed.
# A min-conformed image must satisfy the following criteria:
#  - Number of Dimensions 3        : True
#  - Dimensions 256x256x256        : BUT image dimensions (176, 240, 256)
#  - Voxel Size 1.0x1.0x1.0        : BUT image 1.2x1.0546875x1.0546875
#  - Orientation LIA               : BUT strict: [[ 1.2 -0.04 0. ] [ 0.04 1.02 0.25] [-0.01 -0.25 1.02]]
#  - Dtype uint8                   : BUT dtype >f4
# [INFO: run_prediction.py:  337]: Conforming image
# (1.0, 1.0, 1.0)
# Input:    min: 0.0  max: 1848.9176025390625
# rescale:  min: 0.0  max: 1155.573486328125  scale: 0.22066965278882555
# Output:   min: 0.0  max: 255.0
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/099s4104/mri/orig.mgz.
# [INFO: run_prediction.py:  400]: Run coronal prediction
# [INFO: dataset.py:   78]: Loading Coronal with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:05<00:00, 42.83batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for coronal successful
# [INFO: inference.py:  468]: Coronal inference on /data/sub-099s4104/ses-201207110807380/anat/sub-099s4104_ses-201207110807380_T1w.nii finished in 5.9797 seconds
# [INFO: run_prediction.py:  400]: Run sagittal prediction
# [INFO: dataset.py:   69]: Loading Sagittal with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:06<00:00, 42.31batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for sagittal successful
# [INFO: inference.py:  468]: Sagittal inference on /data/sub-099s4104/ses-201207110807380/anat/sub-099s4104_ses-201207110807380_T1w.nii finished in 6.0518 seconds
# [INFO: run_prediction.py:  400]: Run axial prediction
# [INFO: dataset.py:   74]: Loading Axial with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:05<00:00, 43.91batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for axial successful
# [INFO: inference.py:  468]: Axial inference on /data/sub-099s4104/ses-201207110807380/anat/sub-099s4104_ses-201207110807380_T1w.nii finished in 5.8305 seconds
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/099s4104/mri/aparc.DKTatlas+aseg.deep.mgz.
# [INFO: run_prediction.py:  725]: Creating brainmask based on segmentation...
# Creating dilated mask ...
# Frontal region special treatment:  20337
#   Found 1 connected component(s)!
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/099s4104/mri/mask.mgz.
# [INFO: run_prediction.py:  744]: Creating aseg based on segmentation...
# Reducing to aseg ...
# FlipWM: rh 1 and lh 0 flipped.
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/099s4104/mri/aseg.auto_noCCseg.mgz.
# [INFO: run_prediction.py:  763]: Running volume-based QC check on segmentation...
# Checking total volume ...
# Voxel size in mm3: 1.0
# Total segmentation volume in liter: 1.06
# INFO: Running N4 bias-field correction
# python3.10 -s /fastsurfer/recon_surf/N4_bias_correct.py --in /output/099s4104/mri/orig.mgz --rescale /output/099s4104/mri/orig_nu.mgz --aseg /output/099s4104/mri/aparc.DKTatlas+aseg.deep.mgz --threads 1
#
# N4 Bias Correction Parameters:
#
# - verbosity: -1
# - input volume: /output/099s4104/mri/orig.mgz
# - output volume: do not save
# - rescaled volume: /output/099s4104/mri/orig_nu.mgz
# - mask: default (>0)
# - aseg: /output/099s4104/mri/aparc.DKTatlas+aseg.deep.mgz
# - shrink factor: 4
# - number fitting levels: 4
# - number iterations: 50
# - convergence threshold: 0.0
# - threads: 1
# read MGZ (FreeSurfer) image via nibabel...
# executing N4 correction ...
# - mask: ones (default)
# normalize WM to 105.0 (find WM from aseg)
# read MGZ (FreeSurfer) image via nibabel...
# - source white matter intensity: 64.87
# - m: 1.5724
# converting rescaled to UCHAR
# writing PosixPath: /output/099s4104/mri/orig_nu.mgz
# write MGZ (FreeSurfer) image via nibabel...
# python3.10 -s /fastsurfer/FastSurferCNN/segstats.py --segfile /output/099s4104/mri/aparc.DKTatlas+aseg.deep.mgz --segstatsfile /output/099s4104/stats/aseg+DKT.stats --normfile /output/099s4104/mri/orig_nu.mgz --threads 1 --empty --excludeid 0 --sd /output --sid 099s4104 --ids 2 4 5 7 8 10 11 12 13 14 15 16 17 18 24 26 28 31 41 43 44 46 47 49 50 51 52 53 54 58 60 63 77 251 252 253 254 255 1002 1003 1005 1006 1007 1008 1009 1010 1011 1012 1013 1014 1015 1016 1017 1018 1019 1020 1021 1022 1023 1024 1025 1026 1027 1028 1029 1030 1031 1034 1035 2002 2003 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031 2034 2035 --lut /fastsurfer/FastSurferCNN/config/FreeSurferColorLUT.txt measures --compute Mask(/output/099s4104/mri/mask.mgz) BrainSeg BrainSegNotVent SupraTentorial SupraTentorialNotVent SubCortGray rhCerebralWhiteMatter lhCerebralWhiteMatter CerebralWhiteMatter
# None of the labels [251, 252, 253, 254, 255] for merged label 10007 exist in the segmentation.
# Partial volume stats for 100 labels written to /output/099s4104/stats/aseg+DKT.stats.
# Calculation took 9.67 seconds using up to 1 threads.
# Version: 2.3.3+bd65b36
# Tue Jan  7 02:34:49 UTC 2025
#
# python3.10 -s /fastsurfer/FastSurferCNN/run_prediction.py --t1 /data/sub-128s4609/ses-201204041828370/anat/sub-128s4609_ses-201204041828370_T1w.nii --asegdkt_segfile /output/128s4609/mri/aparc.DKTatlas+aseg.deep.mgz --conformed_name /output/128s4609/mri/orig.mgz --brainmask_name /output/128s4609/mri/mask.mgz --aseg_name /output/128s4609/mri/aseg.auto_noCCseg.mgz --sid 128s4609 --seg_log /output/128s4609/scripts/deep-seg.log --vox_size min --batch_size 1 --viewagg_device auto --device auto --sd /output
# [INFO: run_prediction.py:  648]: Checking or downloading default checkpoints ...
# [INFO: common.py:  827]: Single subject with absolute file path for input.
# [INFO: common.py:  885]: Analyzing single subject /data/sub-128s4609/ses-201204041828370/anat/sub-128s4609_ses-201204041828370_T1w.nii
# [INFO: common.py:  986]: Output will be stored in Subjects Directory: /output
# [INFO: common.py:  114]: Using device: cuda
# [INFO: common.py:  114]: Using viewagg_device: cuda
# [INFO: run_prediction.py:  245]: Running view aggregation on cuda
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_coronal_v2.0.0.pkl
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_sagittal_v2.0.0.pkl
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_axial_v2.0.0.pkl
# [INFO: run_prediction.py:  324]: Successfully loaded image from /data/sub-128s4609/ses-201204041828370/anat/sub-128s4609_ses-201204041828370_T1w.nii.
# [INFO: run_prediction.py:  441]: Output image directory /output/128s4609/mri/orig does not exist. Creating it now...
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/128s4609/mri/orig/001.mgz.
# The input image is not conformed.
# A min-conformed image must satisfy the following criteria:
#  - Number of Dimensions 3        : True
#  - Dimensions 256x256x256        : BUT image dimensions (176, 240, 256)
#  - Voxel Size 1.0x1.0x1.0        : BUT image 1.1999999x1.0546875x1.0546875
#  - Orientation LIA               : BUT strict: [[ 1.19 -0.06 -0.08] [ 0.08 1.05 0.07] [ 0.09 -0.07 1.05]]
#  - Dtype uint8                   : BUT dtype >f4
# [INFO: run_prediction.py:  337]: Conforming image
# (1.0, 1.0, 1.0)
# Input:    min: 0.0  max: 2515.130615234375
# rescale:  min: 0.0  max: 1219.83837890625  scale: 0.20904408683111117
# Output:   min: 0.0  max: 255.0
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/128s4609/mri/orig.mgz.
# [INFO: run_prediction.py:  400]: Run coronal prediction
# [INFO: dataset.py:   78]: Loading Coronal with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:05<00:00, 42.94batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for coronal successful
# [INFO: inference.py:  468]: Coronal inference on /data/sub-128s4609/ses-201204041828370/anat/sub-128s4609_ses-201204041828370_T1w.nii finished in 5.9644 seconds
# [INFO: run_prediction.py:  400]: Run sagittal prediction
# [INFO: dataset.py:   69]: Loading Sagittal with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:06<00:00, 42.45batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for sagittal successful
# [INFO: inference.py:  468]: Sagittal inference on /data/sub-128s4609/ses-201204041828370/anat/sub-128s4609_ses-201204041828370_T1w.nii finished in 6.0321 seconds
# [INFO: run_prediction.py:  400]: Run axial prediction
# [INFO: dataset.py:   74]: Loading Axial with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:05<00:00, 43.93batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for axial successful
# [INFO: inference.py:  468]: Axial inference on /data/sub-128s4609/ses-201204041828370/anat/sub-128s4609_ses-201204041828370_T1w.nii finished in 5.8282 seconds
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/128s4609/mri/aparc.DKTatlas+aseg.deep.mgz.
# [INFO: run_prediction.py:  725]: Creating brainmask based on segmentation...
# Creating dilated mask ...
# Frontal region special treatment:  18417
#   Found 1 connected component(s)!
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/128s4609/mri/mask.mgz.
# [INFO: run_prediction.py:  744]: Creating aseg based on segmentation...
# Reducing to aseg ...
# FlipWM: rh 0 and lh 0 flipped.
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/128s4609/mri/aseg.auto_noCCseg.mgz.
# [INFO: run_prediction.py:  763]: Running volume-based QC check on segmentation...
# Checking total volume ...
# Voxel size in mm3: 1.0
# Total segmentation volume in liter: 1.01
# INFO: Running N4 bias-field correction
# python3.10 -s /fastsurfer/recon_surf/N4_bias_correct.py --in /output/128s4609/mri/orig.mgz --rescale /output/128s4609/mri/orig_nu.mgz --aseg /output/128s4609/mri/aparc.DKTatlas+aseg.deep.mgz --threads 1
#
# N4 Bias Correction Parameters:
#
# - verbosity: -1
# - input volume: /output/128s4609/mri/orig.mgz
# - output volume: do not save
# - rescaled volume: /output/128s4609/mri/orig_nu.mgz
# - mask: default (>0)
# - aseg: /output/128s4609/mri/aparc.DKTatlas+aseg.deep.mgz
# - shrink factor: 4
# - number fitting levels: 4
# - number iterations: 50
# - convergence threshold: 0.0
# - threads: 1
# read MGZ (FreeSurfer) image via nibabel...
# executing N4 correction ...
# - mask: ones (default)
# normalize WM to 105.0 (find WM from aseg)
# read MGZ (FreeSurfer) image via nibabel...
# - source white matter intensity: 44.10
# - m: 2.3128
# converting rescaled to UCHAR
# writing PosixPath: /output/128s4609/mri/orig_nu.mgz
# write MGZ (FreeSurfer) image via nibabel...
# python3.10 -s /fastsurfer/FastSurferCNN/segstats.py --segfile /output/128s4609/mri/aparc.DKTatlas+aseg.deep.mgz --segstatsfile /output/128s4609/stats/aseg+DKT.stats --normfile /output/128s4609/mri/orig_nu.mgz --threads 1 --empty --excludeid 0 --sd /output --sid 128s4609 --ids 2 4 5 7 8 10 11 12 13 14 15 16 17 18 24 26 28 31 41 43 44 46 47 49 50 51 52 53 54 58 60 63 77 251 252 253 254 255 1002 1003 1005 1006 1007 1008 1009 1010 1011 1012 1013 1014 1015 1016 1017 1018 1019 1020 1021 1022 1023 1024 1025 1026 1027 1028 1029 1030 1031 1034 1035 2002 2003 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031 2034 2035 --lut /fastsurfer/FastSurferCNN/config/FreeSurferColorLUT.txt measures --compute Mask(/output/128s4609/mri/mask.mgz) BrainSeg BrainSegNotVent SupraTentorial SupraTentorialNotVent SubCortGray rhCerebralWhiteMatter lhCerebralWhiteMatter CerebralWhiteMatter
# None of the labels [251, 252, 253, 254, 255] for merged label 10007 exist in the segmentation.
# Partial volume stats for 100 labels written to /output/128s4609/stats/aseg+DKT.stats.
# Calculation took 9.82 seconds using up to 1 threads.
# Version: 2.3.3+bd65b36
# Tue Jan  7 02:37:56 UTC 2025
#
# python3.10 -s /fastsurfer/FastSurferCNN/run_prediction.py --t1 /data/sub-041s4629/ses-201304221158430/anat/sub-041s4629_ses-201304221158430_T1w.nii --asegdkt_segfile /output/041s4629/mri/aparc.DKTatlas+aseg.deep.mgz --conformed_name /output/041s4629/mri/orig.mgz --brainmask_name /output/041s4629/mri/mask.mgz --aseg_name /output/041s4629/mri/aseg.auto_noCCseg.mgz --sid 041s4629 --seg_log /output/041s4629/scripts/deep-seg.log --vox_size min --batch_size 1 --viewagg_device auto --device auto --sd /output
# [INFO: run_prediction.py:  648]: Checking or downloading default checkpoints ...
# [INFO: common.py:  827]: Single subject with absolute file path for input.
# [INFO: common.py:  885]: Analyzing single subject /data/sub-041s4629/ses-201304221158430/anat/sub-041s4629_ses-201304221158430_T1w.nii
# [INFO: common.py:  986]: Output will be stored in Subjects Directory: /output
# [INFO: common.py:  114]: Using device: cuda
# [INFO: common.py:  114]: Using viewagg_device: cuda
# [INFO: run_prediction.py:  245]: Running view aggregation on cuda
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_coronal_v2.0.0.pkl
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_sagittal_v2.0.0.pkl
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_axial_v2.0.0.pkl
# [INFO: run_prediction.py:  324]: Successfully loaded image from /data/sub-041s4629/ses-201304221158430/anat/sub-041s4629_ses-201304221158430_T1w.nii.
# [INFO: run_prediction.py:  441]: Output image directory /output/041s4629/mri/orig does not exist. Creating it now...
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/041s4629/mri/orig/001.mgz.
# The input image is not conformed.
# A min-conformed image must satisfy the following criteria:
#  - Number of Dimensions 3        : True
#  - Dimensions 256x256x256        : BUT image dimensions (176, 240, 256)
#  - Voxel Size 1.0x1.0x1.0        : BUT image 1.1999999x1.0546875x1.0546875
#  - Orientation LIA               : BUT strict: [[ 1.2 0.01 0. ] [-0.01 1.05 0.04] [-0. -0.04 1.05]]
#  - Dtype uint8                   : BUT dtype >f4
# [INFO: run_prediction.py:  337]: Conforming image
# (1.0, 1.0, 1.0)
# Input:    min: 0.0  max: 2653.8046875
# rescale:  min: 0.0  max: 1042.9451904296875  scale: 0.24449990501892188
# Output:   min: 0.0  max: 255.0
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/041s4629/mri/orig.mgz.
# [INFO: run_prediction.py:  400]: Run coronal prediction
# [INFO: dataset.py:   78]: Loading Coronal with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:05<00:00, 42.95batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for coronal successful
# [INFO: inference.py:  468]: Coronal inference on /data/sub-041s4629/ses-201304221158430/anat/sub-041s4629_ses-201304221158430_T1w.nii finished in 5.9629 seconds
# [INFO: run_prediction.py:  400]: Run sagittal prediction
# [INFO: dataset.py:   69]: Loading Sagittal with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:06<00:00, 42.14batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for sagittal successful
# [INFO: inference.py:  468]: Sagittal inference on /data/sub-041s4629/ses-201304221158430/anat/sub-041s4629_ses-201304221158430_T1w.nii finished in 6.0755 seconds
# [INFO: run_prediction.py:  400]: Run axial prediction
# [INFO: dataset.py:   74]: Loading Axial with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:05<00:00, 44.01batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for axial successful
# [INFO: inference.py:  468]: Axial inference on /data/sub-041s4629/ses-201304221158430/anat/sub-041s4629_ses-201304221158430_T1w.nii finished in 5.8177 seconds
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/041s4629/mri/aparc.DKTatlas+aseg.deep.mgz.
# [INFO: run_prediction.py:  725]: Creating brainmask based on segmentation...
# Creating dilated mask ...
# Frontal region special treatment:  18490
#   Found 1 connected component(s)!
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/041s4629/mri/mask.mgz.
# [INFO: run_prediction.py:  744]: Creating aseg based on segmentation...
# Reducing to aseg ...
# FlipWM: rh 0 and lh 0 flipped.
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/041s4629/mri/aseg.auto_noCCseg.mgz.
# [INFO: run_prediction.py:  763]: Running volume-based QC check on segmentation...
# Checking total volume ...
# Voxel size in mm3: 1.0
# Total segmentation volume in liter: 1.06
# INFO: Running N4 bias-field correction
# python3.10 -s /fastsurfer/recon_surf/N4_bias_correct.py --in /output/041s4629/mri/orig.mgz --rescale /output/041s4629/mri/orig_nu.mgz --aseg /output/041s4629/mri/aparc.DKTatlas+aseg.deep.mgz --threads 1
#
# N4 Bias Correction Parameters:
#
# - verbosity: -1
# - input volume: /output/041s4629/mri/orig.mgz
# - output volume: do not save
# - rescaled volume: /output/041s4629/mri/orig_nu.mgz
# - mask: default (>0)
# - aseg: /output/041s4629/mri/aparc.DKTatlas+aseg.deep.mgz
# - shrink factor: 4
# - number fitting levels: 4
# - number iterations: 50
# - convergence threshold: 0.0
# - threads: 1
# read MGZ (FreeSurfer) image via nibabel...
# executing N4 correction ...
# - mask: ones (default)
# normalize WM to 105.0 (find WM from aseg)
# read MGZ (FreeSurfer) image via nibabel...
# - source white matter intensity: 50.84
# - m: 2.0065
# converting rescaled to UCHAR
# writing PosixPath: /output/041s4629/mri/orig_nu.mgz
# write MGZ (FreeSurfer) image via nibabel...
# python3.10 -s /fastsurfer/FastSurferCNN/segstats.py --segfile /output/041s4629/mri/aparc.DKTatlas+aseg.deep.mgz --segstatsfile /output/041s4629/stats/aseg+DKT.stats --normfile /output/041s4629/mri/orig_nu.mgz --threads 1 --empty --excludeid 0 --sd /output --sid 041s4629 --ids 2 4 5 7 8 10 11 12 13 14 15 16 17 18 24 26 28 31 41 43 44 46 47 49 50 51 52 53 54 58 60 63 77 251 252 253 254 255 1002 1003 1005 1006 1007 1008 1009 1010 1011 1012 1013 1014 1015 1016 1017 1018 1019 1020 1021 1022 1023 1024 1025 1026 1027 1028 1029 1030 1031 1034 1035 2002 2003 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031 2034 2035 --lut /fastsurfer/FastSurferCNN/config/FreeSurferColorLUT.txt measures --compute Mask(/output/041s4629/mri/mask.mgz) BrainSeg BrainSegNotVent SupraTentorial SupraTentorialNotVent SubCortGray rhCerebralWhiteMatter lhCerebralWhiteMatter CerebralWhiteMatter
# None of the labels [251, 252, 253, 254, 255] for merged label 10007 exist in the segmentation.
# Partial volume stats for 100 labels written to /output/041s4629/stats/aseg+DKT.stats.
# Calculation took 10.08 seconds using up to 1 threads.
# Version: 2.3.3+bd65b36
# Tue Jan  7 02:41:05 UTC 2025
#
# python3.10 -s /fastsurfer/FastSurferCNN/run_prediction.py --t1 /data/sub-070s4692/ses-201205081035540/anat/sub-070s4692_ses-201205081035540_T1w.nii --asegdkt_segfile /output/070s4692/mri/aparc.DKTatlas+aseg.deep.mgz --conformed_name /output/070s4692/mri/orig.mgz --brainmask_name /output/070s4692/mri/mask.mgz --aseg_name /output/070s4692/mri/aseg.auto_noCCseg.mgz --sid 070s4692 --seg_log /output/070s4692/scripts/deep-seg.log --vox_size min --batch_size 1 --viewagg_device auto --device auto --sd /output
# [INFO: run_prediction.py:  648]: Checking or downloading default checkpoints ...
# [INFO: common.py:  827]: Single subject with absolute file path for input.
# [INFO: common.py:  885]: Analyzing single subject /data/sub-070s4692/ses-201205081035540/anat/sub-070s4692_ses-201205081035540_T1w.nii
# [INFO: common.py:  986]: Output will be stored in Subjects Directory: /output
# [INFO: common.py:  114]: Using device: cuda
# [INFO: common.py:  114]: Using viewagg_device: cuda
# [INFO: run_prediction.py:  245]: Running view aggregation on cuda
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_coronal_v2.0.0.pkl
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_sagittal_v2.0.0.pkl
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_axial_v2.0.0.pkl
# [INFO: run_prediction.py:  324]: Successfully loaded image from /data/sub-070s4692/ses-201205081035540/anat/sub-070s4692_ses-201205081035540_T1w.nii.
# [INFO: run_prediction.py:  441]: Output image directory /output/070s4692/mri/orig does not exist. Creating it now...
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/070s4692/mri/orig/001.mgz.
# The input image is not conformed.
# A min-conformed image must satisfy the following criteria:
#  - Number of Dimensions 3        : True
#  - Dimensions 256x256x256        : BUT image dimensions (176, 240, 256)
#  - Voxel Size 1.0x1.0x1.0        : BUT image 1.1999999x1.0546875x1.0546875
#  - Orientation LIA               : BUT strict: [[ 1.2 -0.07 -0.07] [ 0.09 1.02 0.24] [ 0.06 -0.25 1.02]]
#  - Dtype uint8                   : BUT dtype >f4
# [INFO: run_prediction.py:  337]: Conforming image
# (1.0, 1.0, 1.0)
# Input:    min: 0.0  max: 2685.487060546875
# rescale:  min: 0.0  max: 1127.904541015625  scale: 0.22608296245565648
# Output:   min: 0.0  max: 255.0
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/070s4692/mri/orig.mgz.
# [INFO: run_prediction.py:  400]: Run coronal prediction
# [INFO: dataset.py:   78]: Loading Coronal with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:05<00:00, 42.99batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for coronal successful
# [INFO: inference.py:  468]: Coronal inference on /data/sub-070s4692/ses-201205081035540/anat/sub-070s4692_ses-201205081035540_T1w.nii finished in 5.9573 seconds
# [INFO: run_prediction.py:  400]: Run sagittal prediction
# [INFO: dataset.py:   69]: Loading Sagittal with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:06<00:00, 42.42batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for sagittal successful
# [INFO: inference.py:  468]: Sagittal inference on /data/sub-070s4692/ses-201205081035540/anat/sub-070s4692_ses-201205081035540_T1w.nii finished in 6.0360 seconds
# [INFO: run_prediction.py:  400]: Run axial prediction
# [INFO: dataset.py:   74]: Loading Axial with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:05<00:00, 43.99batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for axial successful
# [INFO: inference.py:  468]: Axial inference on /data/sub-070s4692/ses-201205081035540/anat/sub-070s4692_ses-201205081035540_T1w.nii finished in 5.8197 seconds
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/070s4692/mri/aparc.DKTatlas+aseg.deep.mgz.
# [INFO: run_prediction.py:  725]: Creating brainmask based on segmentation...
# Creating dilated mask ...
# Frontal region special treatment:  21454
#   Found 1 connected component(s)!
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/070s4692/mri/mask.mgz.
# [INFO: run_prediction.py:  744]: Creating aseg based on segmentation...
# Reducing to aseg ...
# FlipWM: rh 0 and lh 0 flipped.
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/070s4692/mri/aseg.auto_noCCseg.mgz.
# [INFO: run_prediction.py:  763]: Running volume-based QC check on segmentation...
# Checking total volume ...
# Voxel size in mm3: 1.0
# Total segmentation volume in liter: 1.22
# INFO: Running N4 bias-field correction
# python3.10 -s /fastsurfer/recon_surf/N4_bias_correct.py --in /output/070s4692/mri/orig.mgz --rescale /output/070s4692/mri/orig_nu.mgz --aseg /output/070s4692/mri/aparc.DKTatlas+aseg.deep.mgz --threads 1
#
# N4 Bias Correction Parameters:
#
# - verbosity: -1
# - input volume: /output/070s4692/mri/orig.mgz
# - output volume: do not save
# - rescaled volume: /output/070s4692/mri/orig_nu.mgz
# - mask: default (>0)
# - aseg: /output/070s4692/mri/aparc.DKTatlas+aseg.deep.mgz
# - shrink factor: 4
# - number fitting levels: 4
# - number iterations: 50
# - convergence threshold: 0.0
# - threads: 1
# read MGZ (FreeSurfer) image via nibabel...
# executing N4 correction ...
# - mask: ones (default)
# normalize WM to 105.0 (find WM from aseg)
# read MGZ (FreeSurfer) image via nibabel...
# - source white matter intensity: 54.03
# - m: 1.8879
# converting rescaled to UCHAR
# writing PosixPath: /output/070s4692/mri/orig_nu.mgz
# write MGZ (FreeSurfer) image via nibabel...
# python3.10 -s /fastsurfer/FastSurferCNN/segstats.py --segfile /output/070s4692/mri/aparc.DKTatlas+aseg.deep.mgz --segstatsfile /output/070s4692/stats/aseg+DKT.stats --normfile /output/070s4692/mri/orig_nu.mgz --threads 1 --empty --excludeid 0 --sd /output --sid 070s4692 --ids 2 4 5 7 8 10 11 12 13 14 15 16 17 18 24 26 28 31 41 43 44 46 47 49 50 51 52 53 54 58 60 63 77 251 252 253 254 255 1002 1003 1005 1006 1007 1008 1009 1010 1011 1012 1013 1014 1015 1016 1017 1018 1019 1020 1021 1022 1023 1024 1025 1026 1027 1028 1029 1030 1031 1034 1035 2002 2003 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031 2034 2035 --lut /fastsurfer/FastSurferCNN/config/FreeSurferColorLUT.txt measures --compute Mask(/output/070s4692/mri/mask.mgz) BrainSeg BrainSegNotVent SupraTentorial SupraTentorialNotVent SubCortGray rhCerebralWhiteMatter lhCerebralWhiteMatter CerebralWhiteMatter
# None of the labels [251, 252, 253, 254, 255] for merged label 10007 exist in the segmentation.
# Partial volume stats for 100 labels written to /output/070s4692/stats/aseg+DKT.stats.
# Calculation took 11.30 seconds using up to 1 threads.
# Version: 2.3.3+bd65b36
# Tue Jan  7 02:44:14 UTC 2025
#
# python3.10 -s /fastsurfer/FastSurferCNN/run_prediction.py --t1 /data/sub-037s4030/ses-201205141108430/anat/sub-037s4030_ses-201205141108430_T1w.nii --asegdkt_segfile /output/037s4030/mri/aparc.DKTatlas+aseg.deep.mgz --conformed_name /output/037s4030/mri/orig.mgz --brainmask_name /output/037s4030/mri/mask.mgz --aseg_name /output/037s4030/mri/aseg.auto_noCCseg.mgz --sid 037s4030 --seg_log /output/037s4030/scripts/deep-seg.log --vox_size min --batch_size 1 --viewagg_device auto --device auto --sd /output
# [INFO: run_prediction.py:  648]: Checking or downloading default checkpoints ...
# [INFO: common.py:  827]: Single subject with absolute file path for input.
# [INFO: common.py:  885]: Analyzing single subject /data/sub-037s4030/ses-201205141108430/anat/sub-037s4030_ses-201205141108430_T1w.nii
# [INFO: common.py:  986]: Output will be stored in Subjects Directory: /output
# [INFO: common.py:  114]: Using device: cuda
# [INFO: common.py:  114]: Using viewagg_device: cuda
# [INFO: run_prediction.py:  245]: Running view aggregation on cuda
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_coronal_v2.0.0.pkl
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_sagittal_v2.0.0.pkl
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_axial_v2.0.0.pkl
# [INFO: run_prediction.py:  324]: Successfully loaded image from /data/sub-037s4030/ses-201205141108430/anat/sub-037s4030_ses-201205141108430_T1w.nii.
# [INFO: run_prediction.py:  441]: Output image directory /output/037s4030/mri/orig does not exist. Creating it now...
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/037s4030/mri/orig/001.mgz.
# The input image is not conformed.
# A min-conformed image must satisfy the following criteria:
#  - Number of Dimensions 3        : True
#  - Dimensions 256x256x256        : BUT image dimensions (176, 240, 256)
#  - Voxel Size 1.0x1.0x1.0        : BUT image 1.1999999x1.0546875x1.0546875
#  - Orientation LIA               : BUT strict: [[ 1.2 -0.03 0.02] [ 0.03 1.04 0.19] [-0.03 -0.19 1.04]]
#  - Dtype uint8                   : BUT dtype >f4
# [INFO: run_prediction.py:  337]: Conforming image
# (1.0, 1.0, 1.0)
# Input:    min: 0.0  max: 1597.4573974609375
# rescale:  min: 0.0  max: 961.6693725585938  scale: 0.26516389860847217
# Output:   min: 0.0  max: 255.0
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/037s4030/mri/orig.mgz.
# [INFO: run_prediction.py:  400]: Run coronal prediction
# [INFO: dataset.py:   78]: Loading Coronal with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:05<00:00, 43.12batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for coronal successful
# [INFO: inference.py:  468]: Coronal inference on /data/sub-037s4030/ses-201205141108430/anat/sub-037s4030_ses-201205141108430_T1w.nii finished in 5.9395 seconds
# [INFO: run_prediction.py:  400]: Run sagittal prediction
# [INFO: dataset.py:   69]: Loading Sagittal with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:06<00:00, 42.19batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for sagittal successful
# [INFO: inference.py:  468]: Sagittal inference on /data/sub-037s4030/ses-201205141108430/anat/sub-037s4030_ses-201205141108430_T1w.nii finished in 6.0683 seconds
# [INFO: run_prediction.py:  400]: Run axial prediction
# [INFO: dataset.py:   74]: Loading Axial with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:05<00:00, 44.02batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for axial successful
# [INFO: inference.py:  468]: Axial inference on /data/sub-037s4030/ses-201205141108430/anat/sub-037s4030_ses-201205141108430_T1w.nii finished in 5.8162 seconds
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/037s4030/mri/aparc.DKTatlas+aseg.deep.mgz.
# [INFO: run_prediction.py:  725]: Creating brainmask based on segmentation...
# Creating dilated mask ...
# Frontal region special treatment:  19723
#   Found 1 connected component(s)!
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/037s4030/mri/mask.mgz.
# [INFO: run_prediction.py:  744]: Creating aseg based on segmentation...
# Reducing to aseg ...
# FlipWM: rh 0 and lh 0 flipped.
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/037s4030/mri/aseg.auto_noCCseg.mgz.
# [INFO: run_prediction.py:  763]: Running volume-based QC check on segmentation...
# Checking total volume ...
# Voxel size in mm3: 1.0
# Total segmentation volume in liter: 1.14
# INFO: Running N4 bias-field correction
# python3.10 -s /fastsurfer/recon_surf/N4_bias_correct.py --in /output/037s4030/mri/orig.mgz --rescale /output/037s4030/mri/orig_nu.mgz --aseg /output/037s4030/mri/aparc.DKTatlas+aseg.deep.mgz --threads 1
#
# N4 Bias Correction Parameters:
#
# - verbosity: -1
# - input volume: /output/037s4030/mri/orig.mgz
# - output volume: do not save
# - rescaled volume: /output/037s4030/mri/orig_nu.mgz
# - mask: default (>0)
# - aseg: /output/037s4030/mri/aparc.DKTatlas+aseg.deep.mgz
# - shrink factor: 4
# - number fitting levels: 4
# - number iterations: 50
# - convergence threshold: 0.0
# - threads: 1
# read MGZ (FreeSurfer) image via nibabel...
# executing N4 correction ...
# - mask: ones (default)
# normalize WM to 105.0 (find WM from aseg)
# read MGZ (FreeSurfer) image via nibabel...
# - source white matter intensity: 65.80
# - m: 1.5501
# converting rescaled to UCHAR
# writing PosixPath: /output/037s4030/mri/orig_nu.mgz
# write MGZ (FreeSurfer) image via nibabel...
# python3.10 -s /fastsurfer/FastSurferCNN/segstats.py --segfile /output/037s4030/mri/aparc.DKTatlas+aseg.deep.mgz --segstatsfile /output/037s4030/stats/aseg+DKT.stats --normfile /output/037s4030/mri/orig_nu.mgz --threads 1 --empty --excludeid 0 --sd /output --sid 037s4030 --ids 2 4 5 7 8 10 11 12 13 14 15 16 17 18 24 26 28 31 41 43 44 46 47 49 50 51 52 53 54 58 60 63 77 251 252 253 254 255 1002 1003 1005 1006 1007 1008 1009 1010 1011 1012 1013 1014 1015 1016 1017 1018 1019 1020 1021 1022 1023 1024 1025 1026 1027 1028 1029 1030 1031 1034 1035 2002 2003 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031 2034 2035 --lut /fastsurfer/FastSurferCNN/config/FreeSurferColorLUT.txt measures --compute Mask(/output/037s4030/mri/mask.mgz) BrainSeg BrainSegNotVent SupraTentorial SupraTentorialNotVent SubCortGray rhCerebralWhiteMatter lhCerebralWhiteMatter CerebralWhiteMatter
# None of the labels [251, 252, 253, 254, 255] for merged label 10007 exist in the segmentation.
# Partial volume stats for 100 labels written to /output/037s4030/stats/aseg+DKT.stats.
# Calculation took 10.35 seconds using up to 1 threads.
# Version: 2.3.3+bd65b36
# Tue Jan  7 02:47:23 UTC 2025
#
# python3.10 -s /fastsurfer/FastSurferCNN/run_prediction.py --t1 /data/sub-014s4080/ses-201206211033430/anat/sub-014s4080_ses-201206211033430_T1w.nii --asegdkt_segfile /output/014s4080/mri/aparc.DKTatlas+aseg.deep.mgz --conformed_name /output/014s4080/mri/orig.mgz --brainmask_name /output/014s4080/mri/mask.mgz --aseg_name /output/014s4080/mri/aseg.auto_noCCseg.mgz --sid 014s4080 --seg_log /output/014s4080/scripts/deep-seg.log --vox_size min --batch_size 1 --viewagg_device auto --device auto --sd /output
# [INFO: run_prediction.py:  648]: Checking or downloading default checkpoints ...
# [INFO: common.py:  827]: Single subject with absolute file path for input.
# [INFO: common.py:  885]: Analyzing single subject /data/sub-014s4080/ses-201206211033430/anat/sub-014s4080_ses-201206211033430_T1w.nii
# [INFO: common.py:  986]: Output will be stored in Subjects Directory: /output
# [INFO: common.py:  114]: Using device: cuda
# [INFO: common.py:  114]: Using viewagg_device: cuda
# [INFO: run_prediction.py:  245]: Running view aggregation on cuda
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_coronal_v2.0.0.pkl
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_sagittal_v2.0.0.pkl
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_axial_v2.0.0.pkl
# [INFO: run_prediction.py:  324]: Successfully loaded image from /data/sub-014s4080/ses-201206211033430/anat/sub-014s4080_ses-201206211033430_T1w.nii.
# [INFO: run_prediction.py:  441]: Output image directory /output/014s4080/mri/orig does not exist. Creating it now...
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/014s4080/mri/orig/001.mgz.
# The input image is not conformed.
# A min-conformed image must satisfy the following criteria:
#  - Number of Dimensions 3        : True
#  - Dimensions 256x256x256        : BUT image dimensions (176, 240, 256)
#  - Voxel Size 1.0x1.0x1.0        : BUT image 1.1999999x1.0546875x1.0546875
#  - Orientation LIA               : BUT strict: [[ 1.2 0.05 -0.03] [-0.05 1.03 0.23] [ 0.04 -0.22 1.03]]
#  - Dtype uint8                   : BUT dtype >f4
# [INFO: run_prediction.py:  337]: Conforming image
# (1.0, 1.0, 1.0)
# Input:    min: 0.0  max: 2542.625
# rescale:  min: 0.0  max: 1039.93359375  scale: 0.24520796475135506
# Output:   min: 0.0  max: 255.0
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/014s4080/mri/orig.mgz.
# [INFO: run_prediction.py:  400]: Run coronal prediction
# [INFO: dataset.py:   78]: Loading Coronal with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:05<00:00, 43.00batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for coronal successful
# [INFO: inference.py:  468]: Coronal inference on /data/sub-014s4080/ses-201206211033430/anat/sub-014s4080_ses-201206211033430_T1w.nii finished in 5.9556 seconds
# [INFO: run_prediction.py:  400]: Run sagittal prediction
# [INFO: dataset.py:   69]: Loading Sagittal with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:06<00:00, 41.93batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for sagittal successful
# [INFO: inference.py:  468]: Sagittal inference on /data/sub-014s4080/ses-201206211033430/anat/sub-014s4080_ses-201206211033430_T1w.nii finished in 6.1056 seconds
# [INFO: run_prediction.py:  400]: Run axial prediction
# [INFO: dataset.py:   74]: Loading Axial with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:05<00:00, 44.16batch/s]
# ...
# [INFO: run_prediction.py:  744]: Creating aseg based on segmentation...
# Reducing to aseg ...
# FlipWM: rh 0 and lh 0 flipped.
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/941s1195/mri/aseg.auto_noCCseg.mgz.
# [INFO: run_prediction.py:  763]: Running volume-based QC check on segmentation...
# Checking total volume ...
# Voxel size in mm3: 1.0
# Total segmentation volume in liter: 1.09
# INFO: Running N4 bias-field correction
# python3.10 -s /fastsurfer/recon_surf/N4_bias_correct.py --in /output/941s1195/mri/orig.mgz --rescale /output/941s1195/mri/orig_nu.mgz --aseg /output/941s1195/mri/aparc.DKTatlas+aseg.deep.mgz --threads 1
#
# N4 Bias Correction Parameters:
#
# - verbosity: -1
# - input volume: /output/941s1195/mri/orig.mgz
# - output volume: do not save
# - rescaled volume: /output/941s1195/mri/orig_nu.mgz
# - mask: default (>0)
# - aseg: /output/941s1195/mri/aparc.DKTatlas+aseg.deep.mgz
# - shrink factor: 4
# - number fitting levels: 4
# - number iterations: 50
# - convergence threshold: 0.0
# - threads: 1
# read MGZ (FreeSurfer) image via nibabel...
# executing N4 correction ...
# - mask: ones (default)
# normalize WM to 105.0 (find WM from aseg)
# read MGZ (FreeSurfer) image via nibabel...
# - source white matter intensity: 51.18
# - m: 1.9929
# converting rescaled to UCHAR
# writing PosixPath: /output/941s1195/mri/orig_nu.mgz
# write MGZ (FreeSurfer) image via nibabel...
# python3.10 -s /fastsurfer/FastSurferCNN/segstats.py --segfile /output/941s1195/mri/aparc.DKTatlas+aseg.deep.mgz --segstatsfile /output/941s1195/stats/aseg+DKT.stats --normfile /output/941s1195/mri/orig_nu.mgz --threads 1 --empty --excludeid 0 --sd /output --sid 941s1195 --ids 2 4 5 7 8 10 11 12 13 14 15 16 17 18 24 26 28 31 41 43 44 46 47 49 50 51 52 53 54 58 60 63 77 251 252 253 254 255 1002 1003 1005 1006 1007 1008 1009 1010 1011 1012 1013 1014 1015 1016 1017 1018 1019 1020 1021 1022 1023 1024 1025 1026 1027 1028 1029 1030 1031 1034 1035 2002 2003 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031 2034 2035 --lut /fastsurfer/FastSurferCNN/config/FreeSurferColorLUT.txt measures --compute Mask(/output/941s1195/mri/mask.mgz) BrainSeg BrainSegNotVent SupraTentorial SupraTentorialNotVent SubCortGray rhCerebralWhiteMatter lhCerebralWhiteMatter CerebralWhiteMatter
# None of the labels [251, 252, 253, 254, 255] for merged label 10007 exist in the segmentation.
# Partial volume stats for 100 labels written to /output/941s1195/stats/aseg+DKT.stats.
# Calculation took 9.83 seconds using up to 1 threads.
# Version: 2.3.3+bd65b36
# Tue Jan  7 07:20:03 UTC 2025
#
# python3.10 -s /fastsurfer/FastSurferCNN/run_prediction.py --t1 /data/sub-073s0746/ses-201303081132280/anat/sub-073s0746_ses-201303081132280_T1w.nii --asegdkt_segfile /output/073s0746/mri/aparc.DKTatlas+aseg.deep.mgz --conformed_name /output/073s0746/mri/orig.mgz --brainmask_name /output/073s0746/mri/mask.mgz --aseg_name /output/073s0746/mri/aseg.auto_noCCseg.mgz --sid 073s0746 --seg_log /output/073s0746/scripts/deep-seg.log --vox_size min --batch_size 1 --viewagg_device auto --device auto --sd /output
# [INFO: run_prediction.py:  648]: Checking or downloading default checkpoints ...
# [INFO: common.py:  827]: Single subject with absolute file path for input.
# [INFO: common.py:  885]: Analyzing single subject /data/sub-073s0746/ses-201303081132280/anat/sub-073s0746_ses-201303081132280_T1w.nii
# [INFO: common.py:  986]: Output will be stored in Subjects Directory: /output
# [INFO: common.py:  114]: Using device: cuda
# [INFO: common.py:  114]: Using viewagg_device: cuda
# [INFO: run_prediction.py:  245]: Running view aggregation on cuda
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_coronal_v2.0.0.pkl
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_sagittal_v2.0.0.pkl
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_axial_v2.0.0.pkl
# [INFO: run_prediction.py:  324]: Successfully loaded image from /data/sub-073s0746/ses-201303081132280/anat/sub-073s0746_ses-201303081132280_T1w.nii.
# [INFO: run_prediction.py:  441]: Output image directory /output/073s0746/mri/orig does not exist. Creating it now...
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/073s0746/mri/orig/001.mgz.
# The input image is not conformed.
# A min-conformed image must satisfy the following criteria:
#  - Number of Dimensions 3        : True
#  - Dimensions 256x256x256        : BUT image dimensions (176, 240, 256)
#  - Voxel Size 1.0x1.0x1.0        : BUT image 1.1999999x1.0546875x1.0546875
#  - Orientation LIA               : BUT strict: [[ 1.2 0.04 -0.03] [-0.04 1.04 0.16] [ 0.05 -0.16 1.04]]
#  - Dtype uint8                   : BUT dtype >f4
# [INFO: run_prediction.py:  337]: Conforming image
# (1.0, 1.0, 1.0)
# Input:    min: 0.0  max: 1526.7708740234375
# rescale:  min: 0.0  max: 916.0625  scale: 0.2783652862113666
# Output:   min: 0.0  max: 255.0
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/073s0746/mri/orig.mgz.
# [INFO: run_prediction.py:  400]: Run coronal prediction
# [INFO: dataset.py:   78]: Loading Coronal with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:05<00:00, 42.79batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for coronal successful
# [INFO: inference.py:  468]: Coronal inference on /data/sub-073s0746/ses-201303081132280/anat/sub-073s0746_ses-201303081132280_T1w.nii finished in 5.9854 seconds
# [INFO: run_prediction.py:  400]: Run sagittal prediction
# [INFO: dataset.py:   69]: Loading Sagittal with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:06<00:00, 40.36batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for sagittal successful
# [INFO: inference.py:  468]: Sagittal inference on /data/sub-073s0746/ses-201303081132280/anat/sub-073s0746_ses-201303081132280_T1w.nii finished in 6.3436 seconds
# [INFO: run_prediction.py:  400]: Run axial prediction
# [INFO: dataset.py:   74]: Loading Axial with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:05<00:00, 44.23batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for axial successful
# [INFO: inference.py:  468]: Axial inference on /data/sub-073s0746/ses-201303081132280/anat/sub-073s0746_ses-201303081132280_T1w.nii finished in 5.7887 seconds
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/073s0746/mri/aparc.DKTatlas+aseg.deep.mgz.
# [INFO: run_prediction.py:  725]: Creating brainmask based on segmentation...
# Creating dilated mask ...
# Frontal region special treatment:  18012
#   Found 1 connected component(s)!
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/073s0746/mri/mask.mgz.
# [INFO: run_prediction.py:  744]: Creating aseg based on segmentation...
# Reducing to aseg ...
# FlipWM: rh 0 and lh 0 flipped.
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/073s0746/mri/aseg.auto_noCCseg.mgz.
# [INFO: run_prediction.py:  763]: Running volume-based QC check on segmentation...
# Checking total volume ...
# Voxel size in mm3: 1.0
# Total segmentation volume in liter: 1.05
# INFO: Running N4 bias-field correction
# python3.10 -s /fastsurfer/recon_surf/N4_bias_correct.py --in /output/073s0746/mri/orig.mgz --rescale /output/073s0746/mri/orig_nu.mgz --aseg /output/073s0746/mri/aparc.DKTatlas+aseg.deep.mgz --threads 1
#
# N4 Bias Correction Parameters:
#
# - verbosity: -1
# - input volume: /output/073s0746/mri/orig.mgz
# - output volume: do not save
# - rescaled volume: /output/073s0746/mri/orig_nu.mgz
# - mask: default (>0)
# - aseg: /output/073s0746/mri/aparc.DKTatlas+aseg.deep.mgz
# - shrink factor: 4
# - number fitting levels: 4
# - number iterations: 50
# - convergence threshold: 0.0
# - threads: 1
# read MGZ (FreeSurfer) image via nibabel...
# executing N4 correction ...
# - mask: ones (default)
# normalize WM to 105.0 (find WM from aseg)
# read MGZ (FreeSurfer) image via nibabel...
# - source white matter intensity: 67.46
# - m: 1.5120
# converting rescaled to UCHAR
# writing PosixPath: /output/073s0746/mri/orig_nu.mgz
# write MGZ (FreeSurfer) image via nibabel...
# python3.10 -s /fastsurfer/FastSurferCNN/segstats.py --segfile /output/073s0746/mri/aparc.DKTatlas+aseg.deep.mgz --segstatsfile /output/073s0746/stats/aseg+DKT.stats --normfile /output/073s0746/mri/orig_nu.mgz --threads 1 --empty --excludeid 0 --sd /output --sid 073s0746 --ids 2 4 5 7 8 10 11 12 13 14 15 16 17 18 24 26 28 31 41 43 44 46 47 49 50 51 52 53 54 58 60 63 77 251 252 253 254 255 1002 1003 1005 1006 1007 1008 1009 1010 1011 1012 1013 1014 1015 1016 1017 1018 1019 1020 1021 1022 1023 1024 1025 1026 1027 1028 1029 1030 1031 1034 1035 2002 2003 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031 2034 2035 --lut /fastsurfer/FastSurferCNN/config/FreeSurferColorLUT.txt measures --compute Mask(/output/073s0746/mri/mask.mgz) BrainSeg BrainSegNotVent SupraTentorial SupraTentorialNotVent SubCortGray rhCerebralWhiteMatter lhCerebralWhiteMatter CerebralWhiteMatter
# None of the labels [251, 252, 253, 254, 255] for merged label 10007 exist in the segmentation.
# Partial volume stats for 100 labels written to /output/073s0746/stats/aseg+DKT.stats.
# Calculation took 9.97 seconds using up to 1 threads.
# Version: 2.3.3+bd65b36
# Tue Jan  7 07:23:11 UTC 2025
#
# python3.10 -s /fastsurfer/FastSurferCNN/run_prediction.py --t1 /data/sub-131s0123/ses-201303211338380/anat/sub-131s0123_ses-201303211338380_T1w.nii --asegdkt_segfile /output/131s0123/mri/aparc.DKTatlas+aseg.deep.mgz --conformed_name /output/131s0123/mri/orig.mgz --brainmask_name /output/131s0123/mri/mask.mgz --aseg_name /output/131s0123/mri/aseg.auto_noCCseg.mgz --sid 131s0123 --seg_log /output/131s0123/scripts/deep-seg.log --vox_size min --batch_size 1 --viewagg_device auto --device auto --sd /output
# [INFO: run_prediction.py:  648]: Checking or downloading default checkpoints ...
# [INFO: common.py:  827]: Single subject with absolute file path for input.
# [INFO: common.py:  885]: Analyzing single subject /data/sub-131s0123/ses-201303211338380/anat/sub-131s0123_ses-201303211338380_T1w.nii
# [INFO: common.py:  986]: Output will be stored in Subjects Directory: /output
# [INFO: common.py:  114]: Using device: cuda
# [INFO: common.py:  114]: Using viewagg_device: cuda
# [INFO: run_prediction.py:  245]: Running view aggregation on cuda
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_coronal_v2.0.0.pkl
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_sagittal_v2.0.0.pkl
# [INFO: inference.py:  200]: Loading checkpoint /fastsurfer/checkpoints/aparc_vinn_axial_v2.0.0.pkl
# [INFO: run_prediction.py:  324]: Successfully loaded image from /data/sub-131s0123/ses-201303211338380/anat/sub-131s0123_ses-201303211338380_T1w.nii.
# [INFO: run_prediction.py:  441]: Output image directory /output/131s0123/mri/orig does not exist. Creating it now...
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/131s0123/mri/orig/001.mgz.
# The input image is not conformed.
# A min-conformed image must satisfy the following criteria:
#  - Number of Dimensions 3        : True
#  - Dimensions 256x256x256        : BUT image dimensions (196, 256, 256)
#  - Voxel Size 1.0x1.0x1.0        : BUT image 1.2x1.0156x1.0156
#  - Orientation LIA               : BUT strict: [[ 1.2 -0.01 -0.06] [ 0.01 1.01 0.12] [ 0.06 -0.12 1.01]]
#  - Dtype uint8                   : BUT dtype >f4
# [INFO: run_prediction.py:  337]: Conforming image
# (1.0, 1.0, 1.0)
# Input:    min: 0.0  max: 15064.845703125
# rescale:  min: 0.0  max: 5589.0576171875  scale: 0.04562486513215083
# Output:   min: 0.0  max: 255.0
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/131s0123/mri/orig.mgz.
# [INFO: run_prediction.py:  400]: Run coronal prediction
# [INFO: dataset.py:   78]: Loading Coronal with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:05<00:00, 42.67batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for coronal successful
# [INFO: inference.py:  468]: Coronal inference on /data/sub-131s0123/ses-201303211338380/anat/sub-131s0123_ses-201303211338380_T1w.nii finished in 6.0022 seconds
# [INFO: run_prediction.py:  400]: Run sagittal prediction
# [INFO: dataset.py:   69]: Loading Sagittal with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:06<00:00, 40.75batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for sagittal successful
# [INFO: inference.py:  468]: Sagittal inference on /data/sub-131s0123/ses-201303211338380/anat/sub-131s0123_ses-201303211338380_T1w.nii finished in 6.2826 seconds
# [INFO: run_prediction.py:  400]: Run axial prediction
# [INFO: dataset.py:   74]: Loading Axial with input voxelsize (1.0, 1.0)
# 100%|██████████| 256/256 [00:05<00:00, 44.26batch/s]
# [INFO: inference.py:  406]: Inference on 256 batches for axial successful
# [INFO: inference.py:  468]: Axial inference on /data/sub-131s0123/ses-201303211338380/anat/sub-131s0123_ses-201303211338380_T1w.nii finished in 5.7853 seconds
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/131s0123/mri/aparc.DKTatlas+aseg.deep.mgz.
# [INFO: run_prediction.py:  725]: Creating brainmask based on segmentation...
# Creating dilated mask ...
# Frontal region special treatment:  17872
#   Found 1 connected component(s)!
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/131s0123/mri/mask.mgz.
# [INFO: run_prediction.py:  744]: Creating aseg based on segmentation...
# Reducing to aseg ...
# FlipWM: rh 0 and lh 0 flipped.
# [INFO: run_prediction.py:  454]: Successfully saved image   as /output/131s0123/mri/aseg.auto_noCCseg.mgz.
# [INFO: run_prediction.py:  763]: Running volume-based QC check on segmentation...
# Checking total volume ...
# Voxel size in mm3: 1.0
# Total segmentation volume in liter: 0.95
# INFO: Running N4 bias-field correction
# python3.10 -s /fastsurfer/recon_surf/N4_bias_correct.py --in /output/131s0123/mri/orig.mgz --rescale /output/131s0123/mri/orig_nu.mgz --aseg /output/131s0123/mri/aparc.DKTatlas+aseg.deep.mgz --threads 1
#
# N4 Bias Correction Parameters:
#
# - verbosity: -1
# - input volume: /output/131s0123/mri/orig.mgz
# - output volume: do not save
# - rescaled volume: /output/131s0123/mri/orig_nu.mgz
# - mask: default (>0)
# - aseg: /output/131s0123/mri/aparc.DKTatlas+aseg.deep.mgz
# - shrink factor: 4
# - number fitting levels: 4
# - number iterations: 50
# - convergence threshold: 0.0
# - threads: 1
# read MGZ (FreeSurfer) image via nibabel...
# executing N4 correction ...
# - mask: ones (default)
# normalize WM to 105.0 (find WM from aseg)
# read MGZ (FreeSurfer) image via nibabel...
# - source white matter intensity: 53.16
# - m: 1.9188
# converting rescaled to UCHAR
# writing PosixPath: /output/131s0123/mri/orig_nu.mgz
# write MGZ (FreeSurfer) image via nibabel...
# python3.10 -s /fastsurfer/FastSurferCNN/segstats.py --segfile /output/131s0123/mri/aparc.DKTatlas+aseg.deep.mgz --segstatsfile /output/131s0123/stats/aseg+DKT.stats --normfile /output/131s0123/mri/orig_nu.mgz --threads 1 --empty --excludeid 0 --sd /output --sid 131s0123 --ids 2 4 5 7 8 10 11 12 13 14 15 16 17 18 24 26 28 31 41 43 44 46 47 49 50 51 52 53 54 58 60 63 77 251 252 253 254 255 1002 1003 1005 1006 1007 1008 1009 1010 1011 1012 1013 1014 1015 1016 1017 1018 1019 1020 1021 1022 1023 1024 1025 1026 1027 1028 1029 1030 1031 1034 1035 2002 2003 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031 2034 2035 --lut /fastsurfer/FastSurferCNN/config/FreeSurferColorLUT.txt measures --compute Mask(/output/131s0123/mri/mask.mgz) BrainSeg BrainSegNotVent SupraTentorial SupraTentorialNotVent SubCortGray rhCerebralWhiteMatter lhCerebralWhiteMatter CerebralWhiteMatter
# None of the labels [251, 252, 253, 254, 255] for merged label 10007 exist in the segmentation.
# Partial volume stats for 100 labels written to /output/131s0123/stats/aseg+DKT.stats.
# Calculation took 9.72 seconds using up to 1 threads.

# %%
structs_of_interest = ['Left-Cerebral-White-Matter',
 'Left-Lateral-Ventricle',
 'Left-Inf-Lat-Vent',
 'Left-Cerebellum-White-Matter',
 'Left-Cerebellum-Cortex',
 'Left-Thalamus',
 'Left-Caudate',
 'Left-Putamen',
 'Left-Pallidum',
 '3rd-Ventricle',
 '4th-Ventricle',
 'Brain-Stem',
 'Left-Hippocampus',
 'Left-Amygdala',
 'CSF',
 'Left-Accumbens-area',
 'Left-VentralDC',
 'Left-choroid-plexus',
 'Right-Cerebral-White-Matter',
 'Right-Lateral-Ventricle',
 'Right-Inf-Lat-Vent',
 'Right-Cerebellum-White-Matter',
 'Right-Cerebellum-Cortex',
 'Right-Thalamus',
 'Right-Caudate',
 'Right-Putamen',
 'Right-Pallidum',
 'Right-Hippocampus',
 'Right-Amygdala',
 'Right-Accumbens-area',
 'Right-VentralDC',
 'Right-choroid-plexus',
 'WM-hypointensities',
 'ctx-lh-caudalanteriorcingulate',
 'ctx-lh-caudalmiddlefrontal',
 'ctx-lh-cuneus',
 'ctx-lh-entorhinal',
 'ctx-lh-fusiform',
 'ctx-lh-inferiorparietal',
 'ctx-lh-inferiortemporal',
 'ctx-lh-isthmuscingulate',
 'ctx-lh-lateraloccipital',
 'ctx-lh-lateralorbitofrontal',
 'ctx-lh-lingual',
 'ctx-lh-medialorbitofrontal',
 'ctx-lh-middletemporal',
 'ctx-lh-parahippocampal',
 'ctx-lh-paracentral',
 'ctx-lh-parsopercularis',
 'ctx-lh-parsorbitalis',
 'ctx-lh-parstriangularis',
 'ctx-lh-pericalcarine',
 'ctx-lh-postcentral',
 'ctx-lh-posteriorcingulate',
 'ctx-lh-precentral',
 'ctx-lh-precuneus',
 'ctx-lh-rostralanteriorcingulate',
 'ctx-lh-rostralmiddlefrontal',
 'ctx-lh-superiorfrontal',
 'ctx-lh-superiorparietal',
 'ctx-lh-superiortemporal',
 'ctx-lh-supramarginal',
 'ctx-lh-transversetemporal',
 'ctx-lh-insula',
 'ctx-rh-caudalanteriorcingulate',
 'ctx-rh-caudalmiddlefrontal',
 'ctx-rh-cuneus',
 'ctx-rh-entorhinal',
 'ctx-rh-fusiform',
 'ctx-rh-inferiorparietal',
 'ctx-rh-inferiortemporal',
 'ctx-rh-isthmuscingulate',
 'ctx-rh-lateraloccipital',
 'ctx-rh-lateralorbitofrontal',
 'ctx-rh-lingual',
 'ctx-rh-medialorbitofrontal',
 'ctx-rh-middletemporal',
 'ctx-rh-parahippocampal',
 'ctx-rh-paracentral',
 'ctx-rh-parsopercularis',
 'ctx-rh-parsorbitalis',
 'ctx-rh-parstriangularis',
 'ctx-rh-pericalcarine',
 'ctx-rh-postcentral',
 'ctx-rh-posteriorcingulate',
 'ctx-rh-precentral',
 'ctx-rh-precuneus',
 'ctx-rh-rostralanteriorcingulate',
 'ctx-rh-rostralmiddlefrontal',
 'ctx-rh-superiorfrontal',
 'ctx-rh-superiorparietal',
 'ctx-rh-superiortemporal',
 'ctx-rh-supramarginal',
 'ctx-rh-transversetemporal',
 'ctx-rh-insula']

# %%
fs_table = pd.read_csv(f"{tables_path}/UCSFFSX7_06Jan2025.csv")
fs_table
# Out:
#        PHASE        PTID   RID VISCODE VISCODE2  IMAGEUID    EXAMDATE  \
# 0      ADNI3  002_S_4213  4213    init      m72    888008  2017-08-14
# 1      ADNI2  116_S_4453  4453     v02    scmri    281425  2012-01-18
# 2      ADNI2  099_S_4104  4104     v11      m12    322667  2012-07-11
# 3      ADNI2  073_S_2153  2153     v21      m36    417092  2014-03-03
# 4      ADNI2  137_S_4303  4303     v04      m03    288921  2012-02-27
# ...      ...         ...   ...     ...      ...       ...         ...
# 6326   ADNI2  021_S_5237  5237     v02    scmri    379938  2013-06-27
# 6327   ADNI2  100_S_4556  4556     v02    scmri    305408  2012-04-26
# 6328   ADNI3  005_S_6093  6093      sc       sc    924228  2017-10-27
# 6329   ADNI3  129_S_6852  6852      y2      m24   1547010  2022-02-21
# 6330  ADNIGO  021_S_2125  2125     m03      m03    222797  2011-01-21
#
#          RUNDATE   STATUS  FSVER  ...        ST147SV        ST148SV  \
# 0     2022-07-23  partial  7.2.0  ...  217434.885092  217173.802571
# 1     2022-10-05  partial  7.2.0  ...  224522.552452  221805.186019
# 2     2022-09-26  partial  7.2.0  ...  219930.656696  224579.475317
# 3     2022-08-14  partial  7.2.0  ...  200725.779310  201273.901030
# 4     2022-10-05  partial  7.2.0  ...  198949.362921  200313.596282
# ...          ...      ...    ...  ...            ...            ...
# 6326  2022-09-11  partial  7.2.0  ...  212252.638922  208494.814443
# 6327  2022-08-14  partial  7.2.0  ...  224566.873931  229790.009048
# 6328  2022-07-23  partial  7.2.0  ...  237455.319821  235727.874558
# 6329  2023-08-29  partial  7.2.0  ...  202401.632540  203515.760212
# 6330  2022-09-11  partial  7.2.0  ...  230069.438106  225881.860461
#
#             ST149SV   ST150SV   ST151SV   ST152SV  ST153SV        ST154SV  \
# 0     434608.687663  175240.0  171111.0  346351.0  47936.0  576920.687663
# 1     446327.738471  225291.0  221178.0  446469.0  50711.0  599707.738471
# 2     444510.132013  199702.0  200555.0  400257.0  52008.0  596412.132013
# 3     401999.680340  174186.0  176432.0  350618.0  49603.0  538118.680340
# 4     399262.959202  202949.5  196986.5  399936.0  47355.0  543084.959202
# ...             ...       ...       ...       ...      ...            ...
# 6326  420747.453366  211465.5  212177.5  423643.0  51856.0  584021.453366
# 6327  454356.882979  223665.5  227203.5  450869.0  53580.0  603257.882979
# 6328  473183.194379  214672.5  213593.5  428266.0  50758.0  630561.194379
# 6329  405917.392752  189276.5  185867.5  375144.0  48543.0  573948.392752
# 6330  455951.298567  229819.5  226962.5  456782.0  48852.0  620988.298567
#
#         ST155SV           update_stamp
# 0      874725.0  2024-12-02 08:27:54.0
# 1      984072.0  2024-12-02 08:27:54.0
# 2      928837.0  2024-12-02 08:27:54.0
# 3      846706.0  2024-12-02 08:27:54.0
# 4      902306.0  2024-12-02 08:27:54.0
# ...         ...                    ...
# 6326   937760.0  2024-12-02 08:27:54.0
# 6327   999649.0  2024-12-02 08:27:54.0
# 6328   967388.0  2024-12-02 08:27:54.0
# 6329   885358.0  2024-12-02 08:27:54.0
# 6330  1022940.0  2024-12-02 08:27:54.0
#
# [6331 rows x 346 columns]

# %%
subjects_in_order = []

with open(f'{dataset_base_path}/subjects.txt') as subjects_file:
    for line in subjects_file:
        subjects_in_order.append(line.strip())

# %%
from datetime import datetime
bids_files = glob.glob(f"{mri_bids_path}/**/*.nii", recursive=True)

session_dates = {}

for file in bids_files:
    subject_id = re.search(r'sub-(\w+)', file).group(1)
    session_id = re.search(r'ses-(\w+)', file).group(1)

    session_dates[subject_id] = datetime.strptime(session_id[:8], '%Y%m%d')

# %%
fs_table['EXAMDATE'] = pd.to_datetime(fs_table['EXAMDATE'], format='%Y-%m-%d')

# ignore all rows where the diagnosis is nan
fs_table = fs_table[fs_table['ST10CV'].notna()]

# ignore all rows where the exam date is nan
fs_table = fs_table[fs_table['EXAMDATE'].notna()]

etiv_per_subject = {}

# for each subject, get the diagnosis where the date is closest to the session date
for subject_id in subjects_in_order:
    etiv = fs_table[fs_table['PTID'].map(lambda x: clean_id(x)) == subject_id]
    if etiv.empty:
        print(f"Subject {subject_id} has no ETIV")
        continue
    # remove NA values

    closest_date = etiv.iloc[(etiv['EXAMDATE'] - session_dates[subject_id]).abs().argsort()[:1]]
    etiv_per_subject[subject_id] = closest_date['ST10CV'].values[0]

# %%
# collect all processed files and generate feature vectors with volume information

processed_folders = glob.glob(f"{mri_fastsurfer_out}/*")

volumes_per_subject = {}
for processed_folder in processed_folders:
    subject_id = processed_folder.split("/")[-1]
    stats_path = os.path.join(processed_folder, "stats/aseg+DKT.stats")
    if not os.path.exists(stats_path):
        print(f"Stats folder does not exist for {processed_folder}")
        continue

    aseg_csv = pd.read_csv(stats_path, sep=r'\s+', skiprows=65, names=["Index", "SegId", "NVoxels", "Volume_mm3", "StructName", "normMean", "normStdDev", "normMin", "normMax", "normRange"])

    if subject_id not in etiv_per_subject:
        print(f"No etiv found for subject {subject_id}")
        continue

    etiv_volume = etiv_per_subject[subject_id]
    volumes = []
    for structure in structs_of_interest:
        try:
            volume = aseg_csv.loc[aseg_csv["StructName"] == structure, "Volume_mm3"].iloc[0]
            if volume > etiv_volume:
                print(f"Volume for structure {structure} and subject {subject_id} is larger than etiv {etiv_volume}")
            volumes.append(volume / etiv_volume)
        except:
            print(f"Volume not found for structure {structure} in {subject_id}")
    volumes_per_subject[subject_id] = volumes
# Out:
# Stats folder does not exist for /media/jfallmann/T9/University/master_thesis/dataset/mri/processed/024s4169
# Stats folder does not exist for /media/jfallmann/T9/University/master_thesis/dataset/mri/processed/137s4331
# No etiv found for subject 023s4035
# No etiv found for subject 003s4373

# %%
# create a numpy array in order of subjects with all volumes
import numpy as np
final_volumes = np.zeros((len(subjects_in_order), len(structs_of_interest)))

for i, subject in enumerate(subjects_in_order):
    if subject not in volumes_per_subject:
        print(f"subject {subject} not found")
        continue
    volumes = volumes_per_subject[subject]
    final_volumes[i] = np.asarray(volumes)
# Out:
# subject 024s4169 not found
# subject 137s4331 not found

# %%
final_volumes
# Out:
# array([[0.1527678 , 0.0123619 , 0.00023059, ..., 0.00552149, 0.00054639,
#         0.00358952],
#        [0.07733025, 0.00861479, 0.00097355, ..., 0.00307814, 0.00037573,
#         0.00244975],
#        [0.1372052 , 0.02000124, 0.00037388, ..., 0.00546184, 0.00047201,
#         0.00430054],
#        ...,
#        [0.1456701 , 0.01478447, 0.00153851, ..., 0.00553334, 0.0007862 ,
#         0.0036883 ],
#        [0.16584519, 0.01207906, 0.00039125, ..., 0.00491391, 0.00052085,
#         0.00389304],
#        [0.17378866, 0.00530221, 0.00031831, ..., 0.007226  , 0.0005726 ,
#         0.0040541 ]])

# %%
np.save(f"{mri_base_path}/processed_volumes.npy", final_volumes)
